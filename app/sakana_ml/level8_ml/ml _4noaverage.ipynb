# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
x = x.select(~ pl.selectors.contains("Lon"))
x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

# x = x.select(~ pl.selectors.ends_with("Associate_Floating object"))
# x = x.select(~ pl.selectors.ends_with("Associate_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba, optimize=False):
        self.val = val
        self.proba = proba

        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            self.pred = self.proba[:, 1] >= threshold
            self.th = threshold
        else:
            self.pred = proba.argmax(axis=1)
            self.th = 0.5

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        # return a["f1"][0]
        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-18 14:33:51,498] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-18 14:33:51,762] Trial 0 finished with value: 0.5831493766611409 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8380583425206862, 'num_leaves': 60, 'subsample': 0.8218656259685919}. Best is trial 0 with value: 0.5831493766611409.
# [I 2024-04-18 14:33:52,029] Trial 1 finished with value: 0.5763213720728692 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9040708814402473, 'num_leaves': 31, 'subsample': 0.5653182479728497}. Best is trial 1 with value: 0.5763213720728692.
# [I 2024-04-18 14:33:52,309] Trial 2 finished with value: 0.5707280782507832 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5374575413546706, 'num_leaves': 51, 'subsample': 0.5994583895042737}. Best is trial 2 with value: 0.5707280782507832.
# [I 2024-04-18 14:33:52,592] Trial 3 finished with value: 0.5889566636956531 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6719569888239767, 'num_leaves': 40, 'subsample': 0.5385477615593206}. Best is trial 2 with value: 0.5707280782507832.
# [I 2024-04-18 14:33:52,891] Trial 4 finished with value: 0.6000732935094243 and parameters: {'max_depth': 6, 'colsample_bytree': 0.6889972515160228, 'num_leaves': 45, 'subsample': 0.5123029967332124}. Best is trial 2 with value: 0.5707280782507832.
# [I 2024-04-18 14:33:53,080] Trial 5 finished with value: 0.5080229212826949 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4814098058995878, 'num_leaves': 31, 'subsample': 0.46881359645678866}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:53,309] Trial 6 finished with value: 0.5315625303703992 and parameters: {'max_depth': 3, 'colsample_bytree': 0.47260721838234965, 'num_leaves': 34, 'subsample': 0.7564177774482124}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:53,490] Trial 7 finished with value: 0.5084291547144073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4374146512131005, 'num_leaves': 59, 'subsample': 0.6104727278872055}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:53,803] Trial 8 finished with value: 0.6380726017678193 and parameters: {'max_depth': 7, 'colsample_bytree': 0.9171274815051005, 'num_leaves': 43, 'subsample': 0.5044211387335696}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:54,097] Trial 9 finished with value: 0.616571247392842 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8704518889659989, 'num_leaves': 37, 'subsample': 0.6042321024176182}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:54,293] Trial 10 finished with value: 0.5097714928548714 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5832197812265771, 'num_leaves': 27, 'subsample': 0.9839971245918595}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:54,499] Trial 11 finished with value: 0.5084702195714962 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4023903647444746, 'num_leaves': 59, 'subsample': 0.41331157917321654}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:54,735] Trial 12 finished with value: 0.5084920474727619 and parameters: {'max_depth': 2, 'colsample_bytree': 0.42536724276166227, 'num_leaves': 49, 'subsample': 0.4119062120197119}. Best is trial 5 with value: 0.5080229212826949.
# [I 2024-04-18 14:33:54,958] Trial 13 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5585955763693181, 'num_leaves': 54, 'subsample': 0.6835552984821301}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:55,187] Trial 14 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5589968252335732, 'num_leaves': 25, 'subsample': 0.7147770835218212}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:55,427] Trial 15 finished with value: 0.5530030562653225 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6040018295805999, 'num_leaves': 53, 'subsample': 0.7175757756611768}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:55,648] Trial 16 finished with value: 0.5120231833999758 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7784053325257089, 'num_leaves': 54, 'subsample': 0.8447186559272751}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:55,886] Trial 17 finished with value: 0.5530030562653225 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6091512587933872, 'num_leaves': 26, 'subsample': 0.6642537862927355}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:56,103] Trial 18 finished with value: 0.5115663148643073 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7484209947147038, 'num_leaves': 48, 'subsample': 0.8139216961988184}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:56,317] Trial 19 finished with value: 0.5151706699375871 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9819201572671037, 'num_leaves': 40, 'subsample': 0.9306186891346726}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:56,588] Trial 20 finished with value: 0.5556385538616567 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5443858660142007, 'num_leaves': 45, 'subsample': 0.6886428281774621}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:56,787] Trial 21 finished with value: 0.5080229212826949 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5106109238258311, 'num_leaves': 30, 'subsample': 0.7705339677985825}. Best is trial 13 with value: 0.5070056228205084.
# [I 2024-04-18 14:33:57,019] Trial 22 finished with value: 0.5059118265170536 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4878700462803292, 'num_leaves': 25, 'subsample': 0.46211078341402173}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:57,258] Trial 23 finished with value: 0.5454743201703934 and parameters: {'max_depth': 3, 'colsample_bytree': 0.646341447414487, 'num_leaves': 26, 'subsample': 0.6419574875686754}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:57,481] Trial 24 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5437842662716408, 'num_leaves': 34, 'subsample': 0.8784550867454521}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:57,721] Trial 25 finished with value: 0.5391801024614001 and parameters: {'max_depth': 3, 'colsample_bytree': 0.48010299927844524, 'num_leaves': 28, 'subsample': 0.729194478838939}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:57,939] Trial 26 finished with value: 0.512048971496786 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6373680421785982, 'num_leaves': 25, 'subsample': 0.4506514666739288}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:58,191] Trial 27 finished with value: 0.5464708833448887 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7331826352364595, 'num_leaves': 36, 'subsample': 0.6698335594972481}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:58,409] Trial 28 finished with value: 0.5107027397130346 and parameters: {'max_depth': 2, 'colsample_bytree': 0.591729706764079, 'num_leaves': 54, 'subsample': 0.7683715008859412}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:58,618] Trial 29 finished with value: 0.5080229212826949 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5185689437270208, 'num_leaves': 29, 'subsample': 0.8072926954052898}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:58,914] Trial 30 finished with value: 0.5707280782507832 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5748575324436009, 'num_leaves': 57, 'subsample': 0.8767218322457361}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:59,140] Trial 31 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5440938009644644, 'num_leaves': 33, 'subsample': 0.8188682410286687}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:59,372] Trial 32 finished with value: 0.5084920474727619 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4568410496625523, 'num_leaves': 33, 'subsample': 0.8795826119288619}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:59,642] Trial 33 finished with value: 0.554765408090529 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5009010702697835, 'num_leaves': 37, 'subsample': 0.9539299337397781}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:33:59,898] Trial 34 finished with value: 0.5399429582734969 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5516874683661582, 'num_leaves': 31, 'subsample': 0.554939232846017}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:00,177] Trial 35 finished with value: 0.5728629238264354 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6625945329341041, 'num_leaves': 40, 'subsample': 0.9101697311335917}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:00,396] Trial 36 finished with value: 0.512048971496786 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6313139940724313, 'num_leaves': 25, 'subsample': 0.5829112802438379}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:00,590] Trial 37 finished with value: 0.5095487352972338 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6995136008274361, 'num_leaves': 28, 'subsample': 0.6373973799320053}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:00,835] Trial 38 finished with value: 0.5399429582734969 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5699944458317153, 'num_leaves': 33, 'subsample': 0.5125340119470804}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:01,035] Trial 39 finished with value: 0.5080229212826949 and parameters: {'max_depth': 1, 'colsample_bytree': 0.49920052708416146, 'num_leaves': 39, 'subsample': 0.473563292449842}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:01,271] Trial 40 finished with value: 0.5084920474727619 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4376145727647526, 'num_leaves': 43, 'subsample': 0.9931107392013377}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:01,503] Trial 41 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5351886761478211, 'num_leaves': 35, 'subsample': 0.8474487209364352}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:01,724] Trial 42 finished with value: 0.5070056228205084 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5514915756028349, 'num_leaves': 32, 'subsample': 0.7913919228004243}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:01,932] Trial 43 finished with value: 0.5084291547144073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.47174061565711445, 'num_leaves': 30, 'subsample': 0.732018422365871}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:02,184] Trial 44 finished with value: 0.5391801024614001 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5219589275535144, 'num_leaves': 38, 'subsample': 0.857917047967885}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:02,412] Trial 45 finished with value: 0.5107027397130346 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6035510771370695, 'num_leaves': 47, 'subsample': 0.9172825669377674}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:02,706] Trial 46 finished with value: 0.5632068134894446 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4116880443535116, 'num_leaves': 27, 'subsample': 0.6932669213715669}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:03,021] Trial 47 finished with value: 0.5830333529286229 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4515968763563961, 'num_leaves': 34, 'subsample': 0.7548859628476281}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:03,223] Trial 48 finished with value: 0.5075074859616804 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5562968946242202, 'num_leaves': 42, 'subsample': 0.824814678839458}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:03,447] Trial 49 finished with value: 0.5107027397130346 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6156568046644945, 'num_leaves': 50, 'subsample': 0.8955489198665315}. Best is trial 22 with value: 0.5059118265170536.
# [I 2024-04-18 14:34:03,468] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-18 14:34:03,754] Trial 0 finished with value: 0.3980291646085716 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4030430443119536, 'num_leaves': 54, 'subsample': 0.45606722158932567}. Best is trial 0 with value: 0.3980291646085716.
# [I 2024-04-18 14:34:03,939] Trial 1 finished with value: 0.34530632220082086 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8592759925437192, 'num_leaves': 40, 'subsample': 0.5543209405928518}. Best is trial 1 with value: 0.34530632220082086.
# [I 2024-04-18 14:34:04,254] Trial 2 finished with value: 0.4290634411548174 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9379224877475585, 'num_leaves': 31, 'subsample': 0.4952071958263632}. Best is trial 1 with value: 0.34530632220082086.
# [I 2024-04-18 14:34:04,541] Trial 3 finished with value: 0.4214347725246571 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5607202105318599, 'num_leaves': 37, 'subsample': 0.8484622362714056}. Best is trial 1 with value: 0.34530632220082086.
# [I 2024-04-18 14:34:04,849] Trial 4 finished with value: 0.4116784326627443 and parameters: {'max_depth': 6, 'colsample_bytree': 0.4428013245265572, 'num_leaves': 42, 'subsample': 0.8487336056535346}. Best is trial 1 with value: 0.34530632220082086.
# [I 2024-04-18 14:34:05,043] Trial 5 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6926744348757613, 'num_leaves': 47, 'subsample': 0.8882361878186895}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:05,227] Trial 6 finished with value: 0.3316306636297047 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7790861501234186, 'num_leaves': 55, 'subsample': 0.9201190165001992}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:05,410] Trial 7 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7090656238236599, 'num_leaves': 53, 'subsample': 0.9129112633031663}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:05,654] Trial 8 finished with value: 0.3534564683777245 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4492468651560336, 'num_leaves': 54, 'subsample': 0.4903570820574439}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:05,854] Trial 9 finished with value: 0.3448413277581161 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9653506770187129, 'num_leaves': 59, 'subsample': 0.7763471887993514}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:06,133] Trial 10 finished with value: 0.39066083119707484 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6018449644019858, 'num_leaves': 48, 'subsample': 0.6883586217287344}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:06,335] Trial 11 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6878983441804157, 'num_leaves': 47, 'subsample': 0.981173704052468}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:06,557] Trial 12 finished with value: 0.3444554585767408 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7104608216753477, 'num_leaves': 48, 'subsample': 0.6708919958714316}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:06,753] Trial 13 finished with value: 0.33162051794849895 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6204662849272804, 'num_leaves': 47, 'subsample': 0.9893215735501939}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:07,007] Trial 14 finished with value: 0.37097609978126916 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8005023067240237, 'num_leaves': 59, 'subsample': 0.8109851650651873}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:07,254] Trial 15 finished with value: 0.3703272455602671 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7106514136869516, 'num_leaves': 26, 'subsample': 0.9065980416632905}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:07,567] Trial 16 finished with value: 0.42624912044414964 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5280887442138942, 'num_leaves': 51, 'subsample': 0.7455821974109724}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:07,763] Trial 17 finished with value: 0.3313046554042107 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8607247520777583, 'num_leaves': 37, 'subsample': 0.6178361199595698}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:07,985] Trial 18 finished with value: 0.3428233753035054 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6574542322010569, 'num_leaves': 45, 'subsample': 0.9093590941256198}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:08,272] Trial 19 finished with value: 0.3944439739908005 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7696260285302258, 'num_leaves': 53, 'subsample': 0.8584802963530993}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:08,519] Trial 20 finished with value: 0.3695587376287745 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5312996796497027, 'num_leaves': 57, 'subsample': 0.7376698946752314}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:08,713] Trial 21 finished with value: 0.33183161846716785 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6742886415217797, 'num_leaves': 51, 'subsample': 0.9805605277057056}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:08,909] Trial 22 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.722556577320196, 'num_leaves': 44, 'subsample': 0.9492025711963574}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:09,128] Trial 23 finished with value: 0.3428233753035054 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6289443014900096, 'num_leaves': 50, 'subsample': 0.9981307614056172}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:09,332] Trial 24 finished with value: 0.3316306636297047 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8123688107321557, 'num_leaves': 41, 'subsample': 0.906669774603196}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:09,553] Trial 25 finished with value: 0.34295024729892787 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7465477878198917, 'num_leaves': 46, 'subsample': 0.8054806401246926}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:09,759] Trial 26 finished with value: 0.33183161846716785 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6642037446243084, 'num_leaves': 38, 'subsample': 0.9478920782358643}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:09,975] Trial 27 finished with value: 0.3370425148773092 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5768605712775168, 'num_leaves': 50, 'subsample': 0.8701093605900075}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:10,179] Trial 28 finished with value: 0.331715157085207 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8771611547407725, 'num_leaves': 44, 'subsample': 0.9496391387542922}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:10,428] Trial 29 finished with value: 0.3703272455602671 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6816831062229554, 'num_leaves': 33, 'subsample': 0.8697256592045499}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:10,730] Trial 30 finished with value: 0.41772536141187144 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7414041856303435, 'num_leaves': 56, 'subsample': 0.8111769443056661}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:10,926] Trial 31 finished with value: 0.331970483536289 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7267520151733193, 'num_leaves': 43, 'subsample': 0.9536889021817347}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:11,116] Trial 32 finished with value: 0.3313046554042107 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8309371751269884, 'num_leaves': 52, 'subsample': 0.9460045528525116}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:11,342] Trial 33 finished with value: 0.3428233753035054 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6490235790369293, 'num_leaves': 48, 'subsample': 0.42701703263640123}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:11,533] Trial 34 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7011317323860728, 'num_leaves': 45, 'subsample': 0.9032604278968779}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:11,753] Trial 35 finished with value: 0.34295024729892787 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7665387766186419, 'num_leaves': 41, 'subsample': 0.5894043508276474}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:12,014] Trial 36 finished with value: 0.39066083119707484 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5851631840105699, 'num_leaves': 39, 'subsample': 0.9698959694899076}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:12,206] Trial 37 finished with value: 0.331715157085207 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9125817563167649, 'num_leaves': 34, 'subsample': 0.8884064843973474}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:12,535] Trial 38 finished with value: 0.4303496287889512 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5288659071250922, 'num_leaves': 43, 'subsample': 0.8303915312130515}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:12,759] Trial 39 finished with value: 0.3428417444239601 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7940945575658381, 'num_leaves': 49, 'subsample': 0.9245555300501815}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:12,960] Trial 40 finished with value: 0.331970483536289 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7528415572221188, 'num_leaves': 54, 'subsample': 0.7624914813446386}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:13,160] Trial 41 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6955989511265254, 'num_leaves': 45, 'subsample': 0.9288750422631079}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:13,357] Trial 42 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7158149198794134, 'num_leaves': 46, 'subsample': 0.8844642536772734}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:13,577] Trial 43 finished with value: 0.3428233753035054 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6349591592425708, 'num_leaves': 42, 'subsample': 0.833967058988104}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:13,787] Trial 44 finished with value: 0.33128668945377143 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6904177546194178, 'num_leaves': 47, 'subsample': 0.9764598927051691}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:14,025] Trial 45 finished with value: 0.3370425148773092 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6089387277522388, 'num_leaves': 45, 'subsample': 0.8915858279427153}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:14,227] Trial 46 finished with value: 0.331970483536289 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7254083936032842, 'num_leaves': 40, 'subsample': 0.9974176768189887}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:14,436] Trial 47 finished with value: 0.3316306636297047 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7819703328808351, 'num_leaves': 49, 'subsample': 0.9377062365407234}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:14,682] Trial 48 finished with value: 0.36876899374411204 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8354513510362175, 'num_leaves': 60, 'subsample': 0.9626075640097896}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:14,986] Trial 49 finished with value: 0.42032052418661103 and parameters: {'max_depth': 5, 'colsample_bytree': 0.476922230639503, 'num_leaves': 26, 'subsample': 0.5104842504565463}. Best is trial 5 with value: 0.33128668945377143.
# [I 2024-04-18 14:34:15,011] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-18 14:34:15,224] Trial 0 finished with value: 0.3504271805701693 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9832226826333783, 'num_leaves': 59, 'subsample': 0.6341739434500089}. Best is trial 0 with value: 0.3504271805701693.
# [I 2024-04-18 14:34:15,437] Trial 1 finished with value: 0.350780203835678 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9669925594855875, 'num_leaves': 56, 'subsample': 0.9922060560941626}. Best is trial 0 with value: 0.3504271805701693.
# [I 2024-04-18 14:34:15,723] Trial 2 finished with value: 0.4220823939724241 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5818537052734983, 'num_leaves': 55, 'subsample': 0.9216827721152275}. Best is trial 0 with value: 0.3504271805701693.
# [I 2024-04-18 14:34:15,913] Trial 3 finished with value: 0.31823306063612317 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7439663634707698, 'num_leaves': 49, 'subsample': 0.7552571500673321}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:16,153] Trial 4 finished with value: 0.3757922797190081 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7262530375703593, 'num_leaves': 59, 'subsample': 0.8202318412451207}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:16,376] Trial 5 finished with value: 0.3424588381149993 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4829101438048029, 'num_leaves': 54, 'subsample': 0.7659217731223553}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:16,684] Trial 6 finished with value: 0.45906565368924124 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7327280323415228, 'num_leaves': 60, 'subsample': 0.8176611741079787}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:16,929] Trial 7 finished with value: 0.3782396261927408 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8837538478545921, 'num_leaves': 48, 'subsample': 0.42865149881799225}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:17,172] Trial 8 finished with value: 0.37124058755680633 and parameters: {'max_depth': 3, 'colsample_bytree': 0.48445682716557054, 'num_leaves': 49, 'subsample': 0.6622599911950312}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:17,482] Trial 9 finished with value: 0.4360735085361874 and parameters: {'max_depth': 6, 'colsample_bytree': 0.6581062505545816, 'num_leaves': 27, 'subsample': 0.7799316054861255}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:17,685] Trial 10 finished with value: 0.3186720935480142 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8045911091580262, 'num_leaves': 37, 'subsample': 0.547332344437849}. Best is trial 3 with value: 0.31823306063612317.
# [I 2024-04-18 14:34:17,882] Trial 11 finished with value: 0.31797031108227036 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8320819042229005, 'num_leaves': 36, 'subsample': 0.5346764440365971}. Best is trial 11 with value: 0.31797031108227036.
# [I 2024-04-18 14:34:18,077] Trial 12 finished with value: 0.3186720935480142 and parameters: {'max_depth': 1, 'colsample_bytree': 0.805851677088953, 'num_leaves': 38, 'subsample': 0.5309160720870384}. Best is trial 11 with value: 0.31797031108227036.
# [I 2024-04-18 14:34:18,287] Trial 13 finished with value: 0.31797031108227036 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8422933186536318, 'num_leaves': 30, 'subsample': 0.5591452713314813}. Best is trial 11 with value: 0.31797031108227036.
# [I 2024-04-18 14:34:18,571] Trial 14 finished with value: 0.40231032263717453 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8978387773556915, 'num_leaves': 28, 'subsample': 0.43978525333497864}. Best is trial 11 with value: 0.31797031108227036.
# [I 2024-04-18 14:34:18,909] Trial 15 finished with value: 0.4793404530052183 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8665602719397766, 'num_leaves': 33, 'subsample': 0.561320097421145}. Best is trial 11 with value: 0.31797031108227036.
# [I 2024-04-18 14:34:19,109] Trial 16 finished with value: 0.3175761723328012 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6283086274287721, 'num_leaves': 32, 'subsample': 0.4935922596886478}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:19,394] Trial 17 finished with value: 0.4042426641263293 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6220250545722728, 'num_leaves': 41, 'subsample': 0.4874885375717514}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:19,614] Trial 18 finished with value: 0.3422267410767907 and parameters: {'max_depth': 2, 'colsample_bytree': 0.551863272668349, 'num_leaves': 33, 'subsample': 0.6237581725652727}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:19,863] Trial 19 finished with value: 0.36555938049678605 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4209214961071067, 'num_leaves': 43, 'subsample': 0.4085396638897944}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:20,143] Trial 20 finished with value: 0.39056386645628066 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6738340827703128, 'num_leaves': 25, 'subsample': 0.4732796153773437}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:20,335] Trial 21 finished with value: 0.3186720935480142 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7948614699432324, 'num_leaves': 32, 'subsample': 0.5817893633090173}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:20,539] Trial 22 finished with value: 0.31788925020700676 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9192693470344196, 'num_leaves': 30, 'subsample': 0.49004958985962793}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:20,755] Trial 23 finished with value: 0.350780203835678 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9330740739600081, 'num_leaves': 36, 'subsample': 0.49422930780648877}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:20,949] Trial 24 finished with value: 0.31794750938437827 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9287363440426284, 'num_leaves': 41, 'subsample': 0.7108655372182174}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:21,176] Trial 25 finished with value: 0.34903039742735287 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9169692221324484, 'num_leaves': 43, 'subsample': 0.6820742638095468}. Best is trial 16 with value: 0.3175761723328012.
# [I 2024-04-18 14:34:21,382] Trial 26 finished with value: 0.31688329743191745 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9942187734012123, 'num_leaves': 40, 'subsample': 0.7172199133605607}. Best is trial 26 with value: 0.31688329743191745.
# [I 2024-04-18 14:34:21,598] Trial 27 finished with value: 0.3504271805701693 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9933248727739857, 'num_leaves': 30, 'subsample': 0.6044142397910509}. Best is trial 26 with value: 0.31688329743191745.
# [I 2024-04-18 14:34:21,805] Trial 28 finished with value: 0.3167964315975277 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5969483617403788, 'num_leaves': 25, 'subsample': 0.7089836821468135}. Best is trial 28 with value: 0.3167964315975277.
# [I 2024-04-18 14:34:22,023] Trial 29 finished with value: 0.3422267410767907 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5722443743327957, 'num_leaves': 26, 'subsample': 0.7131481328269945}. Best is trial 28 with value: 0.3167964315975277.
# [I 2024-04-18 14:34:22,268] Trial 30 finished with value: 0.36454999448712466 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6209216437937325, 'num_leaves': 46, 'subsample': 0.8901500483057386}. Best is trial 28 with value: 0.3167964315975277.
# [I 2024-04-18 14:34:22,469] Trial 31 finished with value: 0.31702470843113784 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5341132107184711, 'num_leaves': 29, 'subsample': 0.6537752808499246}. Best is trial 28 with value: 0.3167964315975277.
# [I 2024-04-18 14:34:22,668] Trial 32 finished with value: 0.31627772944048915 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5173439377718488, 'num_leaves': 29, 'subsample': 0.6635712747456044}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:22,893] Trial 33 finished with value: 0.3424588381149993 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5215361859642427, 'num_leaves': 28, 'subsample': 0.668143625220347}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:23,097] Trial 34 finished with value: 0.3180388519621833 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4142723987713575, 'num_leaves': 25, 'subsample': 0.6394706227950333}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:23,320] Trial 35 finished with value: 0.3424588381149993 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5078064138962304, 'num_leaves': 29, 'subsample': 0.7233692115304989}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:23,620] Trial 36 finished with value: 0.4220823939724241 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5876039757154704, 'num_leaves': 53, 'subsample': 0.8106118649782963}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:23,814] Trial 37 finished with value: 0.31702470843113784 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5362042418453828, 'num_leaves': 34, 'subsample': 0.7328749676682053}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:24,034] Trial 38 finished with value: 0.3450174704055904 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4603678568783768, 'num_leaves': 52, 'subsample': 0.7812760193835024}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:24,287] Trial 39 finished with value: 0.3672003243697747 and parameters: {'max_depth': 3, 'colsample_bytree': 0.45675085542579696, 'num_leaves': 39, 'subsample': 0.8627905180124493}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:24,486] Trial 40 finished with value: 0.31852822712446677 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6866635451126083, 'num_leaves': 35, 'subsample': 0.7489506873415439}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:24,685] Trial 41 finished with value: 0.31702470843113784 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5341017629517156, 'num_leaves': 27, 'subsample': 0.6881997606254054}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:24,884] Trial 42 finished with value: 0.31702470843113784 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5747258221954297, 'num_leaves': 34, 'subsample': 0.6492489377778404}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:25,108] Trial 43 finished with value: 0.3424588381149993 and parameters: {'max_depth': 2, 'colsample_bytree': 0.494007155860857, 'num_leaves': 31, 'subsample': 0.9875142428040491}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:25,308] Trial 44 finished with value: 0.31702470843113784 and parameters: {'max_depth': 1, 'colsample_bytree': 0.54415689083722, 'num_leaves': 27, 'subsample': 0.7342835340387948}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:25,508] Trial 45 finished with value: 0.31823306063612317 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7615930772486124, 'num_leaves': 29, 'subsample': 0.6003515048827562}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:25,719] Trial 46 finished with value: 0.3167964315975277 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5994269269765801, 'num_leaves': 39, 'subsample': 0.793171013072513}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:26,023] Trial 47 finished with value: 0.42917198141593954 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6523101106418587, 'num_leaves': 45, 'subsample': 0.7946900645250901}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:26,240] Trial 48 finished with value: 0.3437945889576482 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7205839921475976, 'num_leaves': 39, 'subsample': 0.8445268836534325}. Best is trial 32 with value: 0.31627772944048915.
# [I 2024-04-18 14:34:26,583] Trial 49 finished with value: 0.44114688746030273 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6038711143698945, 'num_leaves': 45, 'subsample': 0.7611825512988902}. Best is trial 32 with value: 0.31627772944048915.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None



for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            # r = Result(y_val, y_proba, optimize=False)
            r = Result(y_val, y_proba, optimize=True)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["th"].append(r.th)
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=a["th"][0], color='r', linestyle='--')
    axs[1].axvline(x=a["th"][0], color='r', linestyle='--')

# Remove space between subplots
    plt.subplots_adjust(hspace=0)

# Show the plot
    plt.show()
# Out:
# acc     :0.7883352370074242
# f1      :0.7551261295741041
# th      :0.47656250000000006
# logloss :0.5059118265170536
# Lat0_Top                      :30.0
# NDepth_Bottom                 :27.75
# Behavior0_Average             :26.5
# Lat0_Bottom                   :20.75
# DDepth_midPoint               :20.0
# Habitat0_Top                  :18.75
# DDepth_Bottom                 :18.25
# Behavior0_Bottom              :17.75
# DDepth_Top                    :17.25
# Habitat0_Average              :13.0
# TemperatureT0_Top             :11.25
# NDepth_midPoint               :9.0
# Habitat0_Bottom               :8.5
# NDepth_Top                    :7.5
# TemperatureT0_Average         :7.25
# TemperatureT0_Bottom          :5.5
# Behavior0_Top                 :5.0
# Associate_Floating object     :2.0
# Salinity0_Bottom              :0.25
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8344517418617933
# f1      :0.7441966364361797
# th      :0.4312499999999999
# logloss :0.33128668945377143
# DDepth_midPoint               :18.5
# TemperatureT0_Average         :12.5
# Associate_Floating object     :10.5
# Habitat0_Average              :9.25
# TemperatureT0_Bottom          :8.0
# Lat0_Top                      :7.0
# Lat0_Bottom                   :6.75
# DDepth_Top                    :6.0
# Habitat0_Top                  :6.0
# NDepth_midPoint               :4.0
# Behavior0_Average             :4.0
# TemperatureT0_Top             :2.75
# DDepth_Bottom                 :2.5
# Habitat0_Bottom               :2.0
# Salinity0_Bottom              :0.25
# NDepth_Top                    :0.0
# NDepth_Bottom                 :0.0
# Behavior0_Bottom              :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8685513040167524
# f1      :0.5917941141663965
# th      :0.496875
# logloss :0.31627772944048915
# DDepth_Bottom                 :11.0
# Lat0_Top                      :10.75
# DDepth_midPoint               :9.75
# Habitat0_Top                  :9.5
# Habitat0_Bottom               :9.0
# Lat0_Bottom                   :7.5
# Habitat0_Average              :6.5
# DDepth_Top                    :6.0
# Salinity0_Bottom              :5.75
# NDepth_midPoint               :5.0
# NDepth_Bottom                 :4.5
# Behavior0_Average             :4.5
# TemperatureT0_Average         :4.0
# Salinity0_Average             :3.0
# TemperatureT0_Bottom          :3.0
# TemperatureT0_Top             :0.25
# NDepth_Top                    :0.0
# Behavior0_Bottom              :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")
