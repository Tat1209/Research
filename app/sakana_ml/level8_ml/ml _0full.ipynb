# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
# x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
# x = x.select(~ pl.selectors.contains("Lon"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

x = x.select(~ pl.selectors.ends_with("Associate0_Floating object"))
x = x.select(~ pl.selectors.ends_with("Associate0_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba, optimize=False):
        self.val = val
        self.proba = proba

        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            self.pred = self.proba[:, 1] >= threshold
            self.th = threshold
        else:
            self.pred = proba.argmax(axis=1)
            self.th = 0.5

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        # return a["f1"][0]
        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-18 16:43:05,255] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-18 16:43:05,593] Trial 0 finished with value: 0.35638870050514093 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8501902144173293, 'num_leaves': 36, 'subsample': 0.5579291838060854}. Best is trial 0 with value: 0.35638870050514093.
# [I 2024-04-18 16:43:05,802] Trial 1 finished with value: 0.29291956282303894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7277798015161031, 'num_leaves': 53, 'subsample': 0.4633552316214833}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:06,130] Trial 2 finished with value: 0.3148624637567906 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5053482237305738, 'num_leaves': 27, 'subsample': 0.4322501332099012}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:06,384] Trial 3 finished with value: 0.2935389700013911 and parameters: {'max_depth': 2, 'colsample_bytree': 0.566508129822616, 'num_leaves': 53, 'subsample': 0.7204300063847924}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:06,650] Trial 4 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5136259044652947, 'num_leaves': 58, 'subsample': 0.8666110788514243}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:06,922] Trial 5 finished with value: 0.29382823638656763 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6276652589172325, 'num_leaves': 52, 'subsample': 0.5442455913344587}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:07,266] Trial 6 finished with value: 0.31033800016520185 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5707162185648061, 'num_leaves': 58, 'subsample': 0.8170718606625595}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:07,694] Trial 7 finished with value: 0.3301752230225831 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7957888943815077, 'num_leaves': 50, 'subsample': 0.5734777489085263}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:07,979] Trial 8 finished with value: 0.3142799833561709 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6250647442184826, 'num_leaves': 41, 'subsample': 0.42533791312536967}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:08,298] Trial 9 finished with value: 0.32016944988510687 and parameters: {'max_depth': 6, 'colsample_bytree': 0.6313165980000554, 'num_leaves': 47, 'subsample': 0.9717932053935412}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:08,495] Trial 10 finished with value: 0.29512801203534966 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9343380824808801, 'num_leaves': 40, 'subsample': 0.6782144573290625}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:08,753] Trial 11 finished with value: 0.3159451266446346 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7642550631731041, 'num_leaves': 54, 'subsample': 0.7128010875140172}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:08,975] Trial 12 finished with value: 0.29291956282303894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7165074779169817, 'num_leaves': 46, 'subsample': 0.6799430491219451}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:09,231] Trial 13 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.41365770707261634, 'num_leaves': 46, 'subsample': 0.6335246158349586}. Best is trial 1 with value: 0.29291956282303894.
# [I 2024-04-18 16:43:09,462] Trial 14 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6972653648880007, 'num_leaves': 30, 'subsample': 0.7988100209626635}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:09,731] Trial 15 finished with value: 0.32550970175689303 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9953160364413998, 'num_leaves': 28, 'subsample': 0.7732156985636087}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:09,931] Trial 16 finished with value: 0.2939626090937922 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7144268213450521, 'num_leaves': 34, 'subsample': 0.9210532647186632}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:10,155] Trial 17 finished with value: 0.3024140046012087 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8547728005870009, 'num_leaves': 31, 'subsample': 0.7990705646198814}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:10,423] Trial 18 finished with value: 0.3159451266446346 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7795823322127491, 'num_leaves': 25, 'subsample': 0.49916712199865704}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:10,620] Trial 19 finished with value: 0.29360641280109556 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6774797429326905, 'num_leaves': 36, 'subsample': 0.8879887354405201}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:10,912] Trial 20 finished with value: 0.33342728106230285 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8563974619037907, 'num_leaves': 60, 'subsample': 0.6163079583748436}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:11,143] Trial 21 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6966620654067446, 'num_leaves': 45, 'subsample': 0.47426148219793857}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:11,374] Trial 22 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6877090666780937, 'num_leaves': 44, 'subsample': 0.4810627176491988}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:11,638] Trial 23 finished with value: 0.3091344046686758 and parameters: {'max_depth': 3, 'colsample_bytree': 0.666757456123753, 'num_leaves': 44, 'subsample': 0.49979817615905997}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:11,881] Trial 24 finished with value: 0.2935389700013911 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5842576961542532, 'num_leaves': 39, 'subsample': 0.7534214110557569}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:12,080] Trial 25 finished with value: 0.29465058307266445 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8186799514874167, 'num_leaves': 44, 'subsample': 0.4027317353456474}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:12,367] Trial 26 finished with value: 0.3216162159301252 and parameters: {'max_depth': 4, 'colsample_bytree': 0.73716973674746, 'num_leaves': 33, 'subsample': 0.49750831560879416}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:12,596] Trial 27 finished with value: 0.29356887704595014 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6670686753542299, 'num_leaves': 38, 'subsample': 0.623909685348804}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:12,853] Trial 28 finished with value: 0.30787139861612633 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5231810377116073, 'num_leaves': 49, 'subsample': 0.8198638516156833}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:13,056] Trial 29 finished with value: 0.293903455490301 and parameters: {'max_depth': 1, 'colsample_bytree': 0.445348324676111, 'num_leaves': 42, 'subsample': 0.5516462330356561}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:13,394] Trial 30 finished with value: 0.3651757713041949 and parameters: {'max_depth': 7, 'colsample_bytree': 0.901096047688893, 'num_leaves': 36, 'subsample': 0.5943723759159257}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:13,613] Trial 31 finished with value: 0.2970916046365246 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7569549275823939, 'num_leaves': 49, 'subsample': 0.47503336584026595}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:13,845] Trial 32 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6885480319266332, 'num_leaves': 43, 'subsample': 0.44295474700302856}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:14,070] Trial 33 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.68296646292775, 'num_leaves': 43, 'subsample': 0.4619117644839809}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:14,337] Trial 34 finished with value: 0.31295263841123877 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6114884160861384, 'num_leaves': 45, 'subsample': 0.5279850983535457}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:14,574] Trial 35 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7029911687612358, 'num_leaves': 42, 'subsample': 0.44826194992539287}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:14,898] Trial 36 finished with value: 0.3274105435052009 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6510712143355429, 'num_leaves': 38, 'subsample': 0.42366029723295484}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:15,102] Trial 37 finished with value: 0.29465058307266445 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8121876603094652, 'num_leaves': 48, 'subsample': 0.5276740220556138}. Best is trial 14 with value: 0.29287263369913735.
# [I 2024-04-18 16:43:15,344] Trial 38 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5346713826421976, 'num_leaves': 30, 'subsample': 0.8573207399007622}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:15,609] Trial 39 finished with value: 0.3028920681336184 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4709921051972775, 'num_leaves': 30, 'subsample': 0.858137024532366}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:15,924] Trial 40 finished with value: 0.3170489516856637 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5803537934891653, 'num_leaves': 26, 'subsample': 0.952543709159085}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:16,163] Trial 41 finished with value: 0.29291956282303894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7334626058157269, 'num_leaves': 30, 'subsample': 0.8502070481791288}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:16,408] Trial 42 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5293961978644102, 'num_leaves': 51, 'subsample': 0.7651245092177762}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:16,641] Trial 43 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5407970621299051, 'num_leaves': 52, 'subsample': 0.7669837837087085}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:16,852] Trial 44 finished with value: 0.2939537633573278 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5297662703501786, 'num_leaves': 55, 'subsample': 0.7527961458693428}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:17,110] Trial 45 finished with value: 0.30787139861612633 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5493246116629042, 'num_leaves': 57, 'subsample': 0.7867026723570271}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:17,340] Trial 46 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4825808476831731, 'num_leaves': 53, 'subsample': 0.7348241125858633}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:17,565] Trial 47 finished with value: 0.29382823638656763 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6075699573638113, 'num_leaves': 51, 'subsample': 0.8265497957730176}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:17,818] Trial 48 finished with value: 0.30112077689655176 and parameters: {'max_depth': 3, 'colsample_bytree': 0.48543667023212456, 'num_leaves': 51, 'subsample': 0.6653033592514811}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:18,050] Trial 49 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5475047713844278, 'num_leaves': 56, 'subsample': 0.8862941921306235}. Best is trial 38 with value: 0.29074219790368894.
# [I 2024-04-18 16:43:18,071] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-18 16:43:18,299] Trial 0 finished with value: 0.2807812387416828 and parameters: {'max_depth': 2, 'colsample_bytree': 0.594663178963031, 'num_leaves': 52, 'subsample': 0.8863759595744927}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:18,491] Trial 1 finished with value: 0.2932880767714162 and parameters: {'max_depth': 1, 'colsample_bytree': 0.607719672486363, 'num_leaves': 58, 'subsample': 0.8415459572490587}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:18,685] Trial 2 finished with value: 0.29110782771496346 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4042359683244039, 'num_leaves': 57, 'subsample': 0.5580827756450887}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:19,009] Trial 3 finished with value: 0.3347535650907453 and parameters: {'max_depth': 6, 'colsample_bytree': 0.43906397883705595, 'num_leaves': 41, 'subsample': 0.6487237620019328}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:19,201] Trial 4 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8575331537069901, 'num_leaves': 31, 'subsample': 0.745607316215245}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:19,426] Trial 5 finished with value: 0.2864896676447074 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6715246311059597, 'num_leaves': 43, 'subsample': 0.9387392105774292}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:19,705] Trial 6 finished with value: 0.322119167201752 and parameters: {'max_depth': 4, 'colsample_bytree': 0.40485241134071365, 'num_leaves': 36, 'subsample': 0.5899498175605353}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:20,042] Trial 7 finished with value: 0.34989259477517354 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5678477868914034, 'num_leaves': 37, 'subsample': 0.6662753556972647}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:20,389] Trial 8 finished with value: 0.37119262280461174 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6272960865397001, 'num_leaves': 43, 'subsample': 0.6851574389152952}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:20,572] Trial 9 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8526003027245963, 'num_leaves': 58, 'subsample': 0.9675431541323509}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:20,827] Trial 10 finished with value: 0.31898432893793627 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9820619589689404, 'num_leaves': 51, 'subsample': 0.40044242951154224}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:21,090] Trial 11 finished with value: 0.3147551193969834 and parameters: {'max_depth': 3, 'colsample_bytree': 0.735845901797783, 'num_leaves': 48, 'subsample': 0.975821308240731}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:21,361] Trial 12 finished with value: 0.3147551193969834 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7279039583867511, 'num_leaves': 50, 'subsample': 0.8593803453947727}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:21,599] Trial 13 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4987378936848744, 'num_leaves': 45, 'subsample': 0.8607325864963761}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:21,832] Trial 14 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5016024093193762, 'num_leaves': 53, 'subsample': 0.8157140637707423}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:22,143] Trial 15 finished with value: 0.3335901637513766 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5239325215594802, 'num_leaves': 46, 'subsample': 0.8869214745686681}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:22,384] Trial 16 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5262515086285517, 'num_leaves': 54, 'subsample': 0.7718178158772433}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:22,719] Trial 17 finished with value: 0.3355446826992854 and parameters: {'max_depth': 5, 'colsample_bytree': 0.48045056936676744, 'num_leaves': 27, 'subsample': 0.8985237685292314}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:22,954] Trial 18 finished with value: 0.28672520394662726 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7828168129104702, 'num_leaves': 39, 'subsample': 0.7867204829776685}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:23,226] Trial 19 finished with value: 0.3098734765167938 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5863533453976275, 'num_leaves': 46, 'subsample': 0.9976859302054494}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:23,554] Trial 20 finished with value: 0.34360838416187905 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6561413180149194, 'num_leaves': 32, 'subsample': 0.7337734640230748}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:23,790] Trial 21 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5080516856867584, 'num_leaves': 53, 'subsample': 0.8197321924588593}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:24,013] Trial 22 finished with value: 0.28106111370747944 and parameters: {'max_depth': 2, 'colsample_bytree': 0.47071948689080156, 'num_leaves': 54, 'subsample': 0.8958548149784621}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:24,274] Trial 23 finished with value: 0.3103711784986798 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4541853451722726, 'num_leaves': 47, 'subsample': 0.9251602167515371}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:24,513] Trial 24 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.55625604105844, 'num_leaves': 60, 'subsample': 0.8717113643350661}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:24,722] Trial 25 finished with value: 0.2930571382352376 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4572568962726957, 'num_leaves': 55, 'subsample': 0.9149610620740168}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:25,022] Trial 26 finished with value: 0.3335901637513766 and parameters: {'max_depth': 4, 'colsample_bytree': 0.555769639863067, 'num_leaves': 50, 'subsample': 0.8041937332946738}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:25,290] Trial 27 finished with value: 0.31773146000189667 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6427080472128386, 'num_leaves': 44, 'subsample': 0.9562141892176452}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:25,507] Trial 28 finished with value: 0.2807812387416828 and parameters: {'max_depth': 2, 'colsample_bytree': 0.594909019962669, 'num_leaves': 51, 'subsample': 0.4117787466792421}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:25,719] Trial 29 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5926818054502043, 'num_leaves': 57, 'subsample': 0.4168026479212909}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:25,920] Trial 30 finished with value: 0.2932880767714162 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6187379102957715, 'num_leaves': 51, 'subsample': 0.4681284932800084}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:26,138] Trial 31 finished with value: 0.28925056482937217 and parameters: {'max_depth': 2, 'colsample_bytree': 0.687115321745427, 'num_leaves': 49, 'subsample': 0.5210936298478319}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:26,373] Trial 32 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5492208928043631, 'num_leaves': 56, 'subsample': 0.8409202500928566}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:26,573] Trial 33 finished with value: 0.2930571382352376 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4692654488144352, 'num_leaves': 52, 'subsample': 0.5966759696547705}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:26,818] Trial 34 finished with value: 0.2867970025236389 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4097513933610037, 'num_leaves': 60, 'subsample': 0.7160868125745901}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:27,088] Trial 35 finished with value: 0.31643478939096037 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6009065132582302, 'num_leaves': 45, 'subsample': 0.7702972625751144}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:27,394] Trial 36 finished with value: 0.322119167201752 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4342866757469867, 'num_leaves': 41, 'subsample': 0.8489755074266748}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:27,614] Trial 37 finished with value: 0.29261129036898964 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4862647545946375, 'num_leaves': 49, 'subsample': 0.6299573440612398}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:27,848] Trial 38 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5313847925609828, 'num_leaves': 56, 'subsample': 0.9336866156271684}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:28,165] Trial 39 finished with value: 0.3657844546925347 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7253484409974719, 'num_leaves': 41, 'subsample': 0.4685727777915907}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:28,519] Trial 40 finished with value: 0.3675043170195614 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5737445993730733, 'num_leaves': 54, 'subsample': 0.5395030432523629}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:28,745] Trial 41 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5057059780821973, 'num_leaves': 53, 'subsample': 0.8177583511030957}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:28,978] Trial 42 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.49552362834826474, 'num_leaves': 52, 'subsample': 0.8946347371449004}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:29,188] Trial 43 finished with value: 0.29110782771496346 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4371873442151232, 'num_leaves': 58, 'subsample': 0.8355825681422847}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:29,458] Trial 44 finished with value: 0.30031865938706814 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4001116958043841, 'num_leaves': 48, 'subsample': 0.8683307030951047}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:29,680] Trial 45 finished with value: 0.2895652742717456 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6272368427649808, 'num_leaves': 55, 'subsample': 0.7499034471462156}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:29,949] Trial 46 finished with value: 0.31395295148708446 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9518678516054129, 'num_leaves': 51, 'subsample': 0.6889229309534491}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:30,166] Trial 47 finished with value: 0.2918452347380769 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5229022328959784, 'num_leaves': 35, 'subsample': 0.9068265152422265}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:30,428] Trial 48 finished with value: 0.3169806235693687 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7766992529350241, 'num_leaves': 47, 'subsample': 0.9516461592173109}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:30,656] Trial 49 finished with value: 0.2864896676447074 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6683228847903484, 'num_leaves': 44, 'subsample': 0.9848538532270865}. Best is trial 0 with value: 0.2807812387416828.
# [I 2024-04-18 16:43:30,677] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-18 16:43:30,961] Trial 0 finished with value: 0.35384750554141076 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6509721992000835, 'num_leaves': 52, 'subsample': 0.8215669131084423}. Best is trial 0 with value: 0.35384750554141076.
# [I 2024-04-18 16:43:31,259] Trial 1 finished with value: 0.34288957986431534 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4404216787161238, 'num_leaves': 40, 'subsample': 0.7658258750287497}. Best is trial 1 with value: 0.34288957986431534.
# [I 2024-04-18 16:43:31,473] Trial 2 finished with value: 0.31677584620726074 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6918104537244837, 'num_leaves': 46, 'subsample': 0.4909839289475588}. Best is trial 2 with value: 0.31677584620726074.
# [I 2024-04-18 16:43:31,711] Trial 3 finished with value: 0.34649901971891933 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5922680040043726, 'num_leaves': 41, 'subsample': 0.807734382664848}. Best is trial 2 with value: 0.31677584620726074.
# [I 2024-04-18 16:43:32,027] Trial 4 finished with value: 0.29944305758570755 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5953823371679248, 'num_leaves': 41, 'subsample': 0.9421532854079016}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:32,246] Trial 5 finished with value: 0.31776734792865013 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8994670364938298, 'num_leaves': 55, 'subsample': 0.6767639792785485}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:32,496] Trial 6 finished with value: 0.3321116286073666 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5537927443789714, 'num_leaves': 45, 'subsample': 0.7626893424679462}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:32,823] Trial 7 finished with value: 0.3683316858988278 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4091278742815777, 'num_leaves': 42, 'subsample': 0.8784368282841445}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:33,155] Trial 8 finished with value: 0.401127427976694 and parameters: {'max_depth': 7, 'colsample_bytree': 0.90567097728359, 'num_leaves': 25, 'subsample': 0.5426100746825334}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:33,441] Trial 9 finished with value: 0.34261211686122234 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4205623966677751, 'num_leaves': 37, 'subsample': 0.5136773071080342}. Best is trial 4 with value: 0.29944305758570755.
# [I 2024-04-18 16:43:33,649] Trial 10 finished with value: 0.298769400255129 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7854055431566699, 'num_leaves': 32, 'subsample': 0.9903751942124445}. Best is trial 10 with value: 0.298769400255129.
# [I 2024-04-18 16:43:33,842] Trial 11 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8042334298558937, 'num_leaves': 31, 'subsample': 0.9775726153546067}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:34,042] Trial 12 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8013606606056288, 'num_leaves': 30, 'subsample': 0.9700568869325288}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:34,240] Trial 13 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.799180862601166, 'num_leaves': 25, 'subsample': 0.9019841256220337}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:34,465] Trial 14 finished with value: 0.32036635530439644 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9955536199334583, 'num_leaves': 32, 'subsample': 0.9983269583783083}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:34,721] Trial 15 finished with value: 0.33733181171250776 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7789060276249318, 'num_leaves': 31, 'subsample': 0.6589251835431514}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:35,037] Trial 16 finished with value: 0.3809414526292172 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8605633448261554, 'num_leaves': 36, 'subsample': 0.9033037322981221}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:35,234] Trial 17 finished with value: 0.29952678421646073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7283627690940916, 'num_leaves': 29, 'subsample': 0.5868575135542053}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:35,485] Trial 18 finished with value: 0.32010575210447 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9634972098399457, 'num_leaves': 36, 'subsample': 0.8440247590658417}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:35,819] Trial 19 finished with value: 0.39699440609853565 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8586880014325459, 'num_leaves': 28, 'subsample': 0.439629988376958}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:36,076] Trial 20 finished with value: 0.3464322443656972 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7316523293855127, 'num_leaves': 47, 'subsample': 0.9590534385335585}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:36,278] Trial 21 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8003380958834226, 'num_leaves': 27, 'subsample': 0.9156059427289814}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:36,482] Trial 22 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8196185897929433, 'num_leaves': 25, 'subsample': 0.8740909688859823}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:36,708] Trial 23 finished with value: 0.32306758680035746 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7530176988176377, 'num_leaves': 60, 'subsample': 0.9468620052436738}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:36,915] Trial 24 finished with value: 0.2988414659094317 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6784808552836634, 'num_leaves': 33, 'subsample': 0.9971374012624006}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:37,158] Trial 25 finished with value: 0.3195657558922965 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8444981112727977, 'num_leaves': 29, 'subsample': 0.7468959520918601}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:37,361] Trial 26 finished with value: 0.29912145562336256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9318265328667403, 'num_leaves': 35, 'subsample': 0.9217163312689785}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:37,579] Trial 27 finished with value: 0.31949423169679136 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6346851269572878, 'num_leaves': 25, 'subsample': 0.8639584852334846}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:37,779] Trial 28 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.824182676117185, 'num_leaves': 30, 'subsample': 0.803745494676448}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:38,063] Trial 29 finished with value: 0.36816342152832093 and parameters: {'max_depth': 4, 'colsample_bytree': 0.755700417319303, 'num_leaves': 38, 'subsample': 0.6222068748314291}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:38,330] Trial 30 finished with value: 0.346465686256543 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8781099248372417, 'num_leaves': 34, 'subsample': 0.833958281072532}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:38,524] Trial 31 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7977210344650899, 'num_leaves': 27, 'subsample': 0.905935473236012}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:38,717] Trial 32 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8154541269466271, 'num_leaves': 27, 'subsample': 0.9665447564073325}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:38,942] Trial 33 finished with value: 0.31677584620726074 and parameters: {'max_depth': 2, 'colsample_bytree': 0.686294995814133, 'num_leaves': 27, 'subsample': 0.7296046181727801}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:39,139] Trial 34 finished with value: 0.29952678421646073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7175021658247419, 'num_leaves': 30, 'subsample': 0.9178864781611233}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:39,366] Trial 35 finished with value: 0.30956175551925 and parameters: {'max_depth': 2, 'colsample_bytree': 0.477676682161873, 'num_leaves': 39, 'subsample': 0.7872110983522594}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:39,563] Trial 36 finished with value: 0.298769400255129 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7662086952671268, 'num_leaves': 27, 'subsample': 0.9569835292584637}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:39,882] Trial 37 finished with value: 0.3791247472324294 and parameters: {'max_depth': 5, 'colsample_bytree': 0.9106050223426554, 'num_leaves': 33, 'subsample': 0.8879566571381294}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:40,137] Trial 38 finished with value: 0.33964601919987153 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6662678326808845, 'num_leaves': 50, 'subsample': 0.930640844169176}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:40,360] Trial 39 finished with value: 0.3195657558922965 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8402322573700048, 'num_leaves': 25, 'subsample': 0.8535777051372497}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:40,704] Trial 40 finished with value: 0.3744220360126401 and parameters: {'max_depth': 6, 'colsample_bytree': 0.627455453804391, 'num_leaves': 44, 'subsample': 0.970790460443404}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:40,902] Trial 41 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8126705276779804, 'num_leaves': 25, 'subsample': 0.8800132472654735}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:41,104] Trial 42 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.791362451431167, 'num_leaves': 29, 'subsample': 0.9347342996013634}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:41,316] Trial 43 finished with value: 0.29840108338741267 and parameters: {'max_depth': 1, 'colsample_bytree': 0.875416519807216, 'num_leaves': 31, 'subsample': 0.8841580683342998}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:41,553] Trial 44 finished with value: 0.3199502544425482 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7435951683182238, 'num_leaves': 26, 'subsample': 0.8169976642093661}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:41,750] Trial 45 finished with value: 0.2988414659094317 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7089587056823182, 'num_leaves': 28, 'subsample': 0.9703240949744671}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:41,955] Trial 46 finished with value: 0.29860935829621327 and parameters: {'max_depth': 1, 'colsample_bytree': 0.834981790120399, 'num_leaves': 31, 'subsample': 0.9042115255333775}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:42,199] Trial 47 finished with value: 0.3177449604173863 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9237948530704977, 'num_leaves': 26, 'subsample': 0.9947775930047497}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:42,397] Trial 48 finished with value: 0.29840108338741267 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8867369557246961, 'num_leaves': 29, 'subsample': 0.704239226716649}. Best is trial 11 with value: 0.297940831222988.
# [I 2024-04-18 16:43:42,623] Trial 49 finished with value: 0.32010575210447 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9556626703811169, 'num_leaves': 33, 'subsample': 0.940217535483798}. Best is trial 11 with value: 0.297940831222988.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None



for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            # r = Result(y_val, y_proba, optimize=False)
            r = Result(y_val, y_proba, optimize=True)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["th"].append(r.th)
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=a["th"][0], color='r', linestyle='--')
    axs[1].axvline(x=a["th"][0], color='r', linestyle='--')

# Remove space between subplots
    plt.subplots_adjust(hspace=0)

# Show the plot
    plt.show()
# Out:
# acc     :0.8880877593755948
# f1      :0.8722441312266132
# th      :0.509375
# logloss :0.29074219790368894
# max size0_midPoint            :63.75
# Lat0_Top                      :22.0
# NDepth_Bottom                 :17.25
# Habitat0_Average              :17.25
# Lon0_Top                      :17.0
# Behavior0_Average             :13.75
# Behavior0_Bottom              :12.0
# DDepth_Bottom                 :11.5
# DDepth_midPoint               :11.5
# Habitat0_Top                  :11.0
# Lat0_Bottom                   :10.75
# Lon0_Bottom                   :8.75
# Associate0_Top                :8.5
# DDepth_Top                    :7.5
# Associate0_Bottom             :7.25
# NDepth_midPoint               :6.25
# Behavior0_Top                 :5.5
# NDepth_Top                    :5.0
# Associate0_Average            :4.5
# Habitat0_Bottom               :3.25
# TemperatureT0_Top             :2.75
# TemperatureT0_Average         :2.0
# TemperatureT0_Bottom          :1.25
# Salinity0_Average             :1.0
# Salinity0_Bottom              :0.5
# Salinity0_Top                 :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8686226917951647
# f1      :0.7804404658245073
# th      :0.5125
# logloss :0.2807812387416828
# max size0_midPoint            :42.5
# DDepth_midPoint               :24.5
# Lon0_Top                      :24.5
# TemperatureT0_Average         :21.0
# Lat0_Bottom                   :19.25
# Lat0_Top                      :18.0
# Habitat0_Average              :17.75
# NDepth_midPoint               :16.5
# Lon0_Bottom                   :12.0
# Associate_Floating object     :10.0
# Behavior0_Average             :9.25
# Habitat0_Bottom               :9.25
# DDepth_Bottom                 :8.75
# Associate0_Average            :8.0
# Behavior0_Bottom              :7.75
# TemperatureT0_Bottom          :7.0
# NDepth_Bottom                 :5.25
# DDepth_Top                    :5.0
# Associate0_Top                :4.75
# Habitat0_Top                  :3.25
# Associate0_Bottom             :3.25
# Behavior0_Top                 :3.0
# TemperatureT0_Top             :2.75
# NDepth_Top                    :0.25
# Salinity0_Bottom              :0.25
# Salinity0_Average             :0.25
# Salinity0_Top                 :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8807824100513992
# f1      :0.6508195657214702
# th      :0.51875
# logloss :0.297940831222988
# max size0_midPoint            :19.25
# Lon0_Bottom                   :12.0
# DDepth_midPoint               :8.5
# Salinity0_Bottom              :7.5
# NDepth_midPoint               :7.0
# Lat0_Bottom                   :6.75
# Habitat0_Average              :5.75
# Habitat0_Bottom               :5.5
# Habitat0_Top                  :5.0
# DDepth_Bottom                 :3.75
# NDepth_Bottom                 :3.25
# Lat0_Top                      :3.0
# Associate0_Bottom             :2.75
# TemperatureT0_Average         :2.25
# DDepth_Top                    :2.0
# TemperatureT0_Bottom          :2.0
# Behavior0_Average             :1.5
# Salinity0_Average             :1.5
# Associate0_Top                :0.5
# Lon0_Top                      :0.25
# NDepth_Top                    :0.0
# Behavior0_Bottom              :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# TemperatureT0_Top             :0.0
# Associate0_Average            :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")
