# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
# x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
# x = x.select(~ pl.selectors.contains("Lon"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

x = x.select(~ pl.selectors.ends_with("Associate0_Floating object"))
x = x.select(~ pl.selectors.ends_with("Associate0_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba):
        self.val = val
        self.proba = proba
        self.pred = proba.argmax(axis=1)

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self, optimize=False):
        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            return (f1_score(self.val, self.proba[:, 1] >= threshold, average="macro"), threshold)
        else:
            return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                # s["f1"].append(r.f1(optimize=True))
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        # return a["f1"][0]
        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-18 13:38:32,807] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-18 13:38:33,008] Trial 0 finished with value: 0.2951581154256814 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9551995635204542, 'num_leaves': 47, 'subsample': 0.44584885949008607}. Best is trial 0 with value: 0.2951581154256814.
# [I 2024-04-18 13:38:33,329] Trial 1 finished with value: 0.3191541346241069 and parameters: {'max_depth': 6, 'colsample_bytree': 0.47493369378619477, 'num_leaves': 42, 'subsample': 0.5994063553017042}. Best is trial 0 with value: 0.2951581154256814.
# [I 2024-04-18 13:38:33,549] Trial 2 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6181966621334485, 'num_leaves': 36, 'subsample': 0.5093812333904425}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:33,880] Trial 3 finished with value: 0.3651757713041949 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8998386733275722, 'num_leaves': 40, 'subsample': 0.9005807427716276}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:34,185] Trial 4 finished with value: 0.3523932943143055 and parameters: {'max_depth': 5, 'colsample_bytree': 0.9775041953399067, 'num_leaves': 35, 'subsample': 0.48698394033824377}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:34,461] Trial 5 finished with value: 0.3301752230225831 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8236360460768832, 'num_leaves': 43, 'subsample': 0.8799818490760244}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:34,785] Trial 6 finished with value: 0.3540551987424828 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9901507581750436, 'num_leaves': 48, 'subsample': 0.5517870194144773}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:35,064] Trial 7 finished with value: 0.2982338216967807 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4301449368682855, 'num_leaves': 31, 'subsample': 0.47035098992076163}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:35,294] Trial 8 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.554063178954443, 'num_leaves': 29, 'subsample': 0.6980688245176694}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:35,537] Trial 9 finished with value: 0.32641823659449487 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9652750021400583, 'num_leaves': 38, 'subsample': 0.6783897463814855}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:35,737] Trial 10 finished with value: 0.2932427471938546 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6627269522973733, 'num_leaves': 60, 'subsample': 0.7950191747800698}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:35,966] Trial 11 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5962953023689692, 'num_leaves': 25, 'subsample': 0.7188892738462822}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:36,193] Trial 12 finished with value: 0.29356887704595014 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6693653424759908, 'num_leaves': 25, 'subsample': 0.8056466914469321}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:36,479] Trial 13 finished with value: 0.31033800016520185 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5671481262908029, 'num_leaves': 25, 'subsample': 0.6029531936532158}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:36,713] Trial 14 finished with value: 0.2970916046365246 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7682711165924934, 'num_leaves': 33, 'subsample': 0.7799973406508807}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:36,976] Trial 15 finished with value: 0.31295263841123877 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6037560989983684, 'num_leaves': 55, 'subsample': 0.9752063063453629}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:37,175] Trial 16 finished with value: 0.2939626090937922 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7294464369738498, 'num_leaves': 28, 'subsample': 0.40331790030734943}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:37,420] Trial 17 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4977318502301682, 'num_leaves': 36, 'subsample': 0.638396887242243}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:37,684] Trial 18 finished with value: 0.31295263841123877 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6319139489119487, 'num_leaves': 46, 'subsample': 0.5412812501154773}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:38,024] Trial 19 finished with value: 0.3357110613677333 and parameters: {'max_depth': 5, 'colsample_bytree': 0.786020171961356, 'num_leaves': 52, 'subsample': 0.7114374514897629}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:38,236] Trial 20 finished with value: 0.2939537633573278 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5283020869191782, 'num_leaves': 31, 'subsample': 0.7432550601887633}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:38,469] Trial 21 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5547751705315452, 'num_leaves': 28, 'subsample': 0.6895991070785157}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:38,700] Trial 22 finished with value: 0.29067897317620467 and parameters: {'max_depth': 2, 'colsample_bytree': 0.40199227840722895, 'num_leaves': 29, 'subsample': 0.865268065719512}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:38,957] Trial 23 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.408010167097634, 'num_leaves': 33, 'subsample': 0.8628682642577793}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:39,181] Trial 24 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.707609365652228, 'num_leaves': 25, 'subsample': 0.977788088533917}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:39,398] Trial 25 finished with value: 0.293903455490301 and parameters: {'max_depth': 1, 'colsample_bytree': 0.47568084698817537, 'num_leaves': 36, 'subsample': 0.8378241976084496}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:39,695] Trial 26 finished with value: 0.3064655866939506 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6017377562859453, 'num_leaves': 30, 'subsample': 0.9312000181719492}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:39,957] Trial 27 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4322702606511727, 'num_leaves': 33, 'subsample': 0.7475969836463066}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:40,182] Trial 28 finished with value: 0.3024140046012087 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8461279737336307, 'num_leaves': 39, 'subsample': 0.6458053996093969}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:40,399] Trial 29 finished with value: 0.2932427471938546 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6536158120449713, 'num_leaves': 28, 'subsample': 0.517389226199699}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:40,605] Trial 30 finished with value: 0.29382823638656763 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6043624386143238, 'num_leaves': 27, 'subsample': 0.4068321124118248}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:40,821] Trial 31 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5248324650329907, 'num_leaves': 30, 'subsample': 0.5991182119574426}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:41,050] Trial 32 finished with value: 0.2935389700013911 and parameters: {'max_depth': 2, 'colsample_bytree': 0.561292548263781, 'num_leaves': 34, 'subsample': 0.9251733908088234}. Best is trial 2 with value: 0.29054432537716135.
# [I 2024-04-18 13:38:41,275] Trial 33 finished with value: 0.29040540446754665 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4641689968883351, 'num_leaves': 27, 'subsample': 0.827237888071573}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:41,539] Trial 34 finished with value: 0.3028920681336184 and parameters: {'max_depth': 3, 'colsample_bytree': 0.46778777161725044, 'num_leaves': 26, 'subsample': 0.8275040255623731}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:41,867] Trial 35 finished with value: 0.31887721200984553 and parameters: {'max_depth': 5, 'colsample_bytree': 0.46902978838907333, 'num_leaves': 32, 'subsample': 0.7536791964567726}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:42,200] Trial 36 finished with value: 0.3240885041361792 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4056812128291248, 'num_leaves': 41, 'subsample': 0.8741481062302826}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:42,482] Trial 37 finished with value: 0.31439987920332435 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5079708882420685, 'num_leaves': 37, 'subsample': 0.9102624543184569}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:42,810] Trial 38 finished with value: 0.31528852574763033 and parameters: {'max_depth': 6, 'colsample_bytree': 0.43980978425330813, 'num_leaves': 43, 'subsample': 0.8417688576997705}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:43,103] Trial 39 finished with value: 0.3058413359501414 and parameters: {'max_depth': 4, 'colsample_bytree': 0.44765469287357834, 'num_leaves': 27, 'subsample': 0.7263660478899097}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:43,307] Trial 40 finished with value: 0.29360641280109556 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6920412650487345, 'num_leaves': 29, 'subsample': 0.7765346211409684}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:43,540] Trial 41 finished with value: 0.2935389700013911 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5802829801503128, 'num_leaves': 30, 'subsample': 0.6579799796754611}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:43,778] Trial 42 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5451567799995511, 'num_leaves': 27, 'subsample': 0.6183564572313185}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:44,010] Trial 43 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6305537545817952, 'num_leaves': 31, 'subsample': 0.4655834731418025}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:44,270] Trial 44 finished with value: 0.31295263841123877 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6265563200068321, 'num_leaves': 35, 'subsample': 0.46374051307759123}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:44,499] Trial 45 finished with value: 0.30182793687703513 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9126940801775824, 'num_leaves': 31, 'subsample': 0.5056954146903577}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:44,704] Trial 46 finished with value: 0.2939626090937922 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7293022000556747, 'num_leaves': 25, 'subsample': 0.5651361905730845}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:44,968] Trial 47 finished with value: 0.30112077689655176 and parameters: {'max_depth': 3, 'colsample_bytree': 0.48793008289172296, 'num_leaves': 32, 'subsample': 0.42227086310267353}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:45,198] Trial 48 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6320375775517763, 'num_leaves': 29, 'subsample': 0.4793043110947392}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:45,408] Trial 49 finished with value: 0.2932427471938546 and parameters: {'max_depth': 1, 'colsample_bytree': 0.641351304742897, 'num_leaves': 35, 'subsample': 0.4489920141115879}. Best is trial 33 with value: 0.29040540446754665.
# [I 2024-04-18 13:38:45,433] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-18 13:38:45,703] Trial 0 finished with value: 0.3103711784986798 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4434090777234344, 'num_leaves': 29, 'subsample': 0.7413727458407546}. Best is trial 0 with value: 0.3103711784986798.
# [I 2024-04-18 13:38:46,014] Trial 1 finished with value: 0.3355446826992854 and parameters: {'max_depth': 5, 'colsample_bytree': 0.46073430689547334, 'num_leaves': 27, 'subsample': 0.7954354287418623}. Best is trial 0 with value: 0.3103711784986798.
# [I 2024-04-18 13:38:46,342] Trial 2 finished with value: 0.357178858186529 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5215129449960308, 'num_leaves': 27, 'subsample': 0.6599598324086777}. Best is trial 0 with value: 0.3103711784986798.
# [I 2024-04-18 13:38:46,629] Trial 3 finished with value: 0.3291528470741418 and parameters: {'max_depth': 4, 'colsample_bytree': 0.637157651892788, 'num_leaves': 31, 'subsample': 0.4755292043646946}. Best is trial 0 with value: 0.3103711784986798.
# [I 2024-04-18 13:38:46,961] Trial 4 finished with value: 0.3736972087126178 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7881389435390829, 'num_leaves': 36, 'subsample': 0.7054085925056479}. Best is trial 0 with value: 0.3103711784986798.
# [I 2024-04-18 13:38:47,180] Trial 5 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4921729808475552, 'num_leaves': 41, 'subsample': 0.9797910916300494}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:47,523] Trial 6 finished with value: 0.3777083975412874 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7969522234164508, 'num_leaves': 59, 'subsample': 0.9000899504837834}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:47,856] Trial 7 finished with value: 0.36774301663305464 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9393389618473519, 'num_leaves': 39, 'subsample': 0.46463020489653806}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:48,140] Trial 8 finished with value: 0.322119167201752 and parameters: {'max_depth': 4, 'colsample_bytree': 0.42401524225441056, 'num_leaves': 28, 'subsample': 0.5330675400106718}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:48,382] Trial 9 finished with value: 0.3169806235693687 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7737332095288515, 'num_leaves': 44, 'subsample': 0.5376667047389402}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:48,588] Trial 10 finished with value: 0.2932880767714162 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5986433294519973, 'num_leaves': 49, 'subsample': 0.9993950435892943}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:48,795] Trial 11 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5958935278283541, 'num_leaves': 49, 'subsample': 0.9844693194059657}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:49,007] Trial 12 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5776217161326225, 'num_leaves': 51, 'subsample': 0.9961387192698514}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:49,226] Trial 13 finished with value: 0.28925056482937217 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6898285408916175, 'num_leaves': 47, 'subsample': 0.8901672283220977}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:49,455] Trial 14 finished with value: 0.28925056482937217 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7013034400689314, 'num_leaves': 45, 'subsample': 0.861386718228433}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:49,687] Trial 15 finished with value: 0.285264783179608 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9891645605893442, 'num_leaves': 37, 'subsample': 0.9014635737934359}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:49,910] Trial 16 finished with value: 0.285264783179608 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9932848227038671, 'num_leaves': 36, 'subsample': 0.8184174716681982}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:50,159] Trial 17 finished with value: 0.3110017841004018 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8802320760261447, 'num_leaves': 39, 'subsample': 0.9237009310926496}. Best is trial 5 with value: 0.28489412786464885.
# [I 2024-04-18 13:38:50,383] Trial 18 finished with value: 0.2831536615362852 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8804217301086501, 'num_leaves': 54, 'subsample': 0.655563660186785}. Best is trial 18 with value: 0.2831536615362852.
# [I 2024-04-18 13:38:50,645] Trial 19 finished with value: 0.31702807316149473 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8647930735394754, 'num_leaves': 55, 'subsample': 0.6157687121051261}. Best is trial 18 with value: 0.2831536615362852.
# [I 2024-04-18 13:38:50,856] Trial 20 finished with value: 0.29261129036898964 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5099378912819816, 'num_leaves': 60, 'subsample': 0.5989461253945044}. Best is trial 18 with value: 0.2831536615362852.
# [I 2024-04-18 13:38:51,084] Trial 21 finished with value: 0.285264783179608 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9991528627458679, 'num_leaves': 41, 'subsample': 0.776345154645933}. Best is trial 18 with value: 0.2831536615362852.
# [I 2024-04-18 13:38:51,321] Trial 22 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9218649887191913, 'num_leaves': 34, 'subsample': 0.9469851899870975}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:51,586] Trial 23 finished with value: 0.3110017841004018 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8763273978022843, 'num_leaves': 34, 'subsample': 0.9456097933162289}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:51,809] Trial 24 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.914935862793659, 'num_leaves': 32, 'subsample': 0.8394276400357066}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:52,107] Trial 25 finished with value: 0.34800154504376657 and parameters: {'max_depth': 4, 'colsample_bytree': 0.923523832508352, 'num_leaves': 25, 'subsample': 0.8475268587869458}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:52,302] Trial 26 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8309217250184975, 'num_leaves': 32, 'subsample': 0.6665187384679421}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:52,620] Trial 27 finished with value: 0.34986788568880295 and parameters: {'max_depth': 5, 'colsample_bytree': 0.9352177204064548, 'num_leaves': 55, 'subsample': 0.7325523538155256}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:52,877] Trial 28 finished with value: 0.3147551193969834 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7335485773857165, 'num_leaves': 32, 'subsample': 0.767881748365661}. Best is trial 22 with value: 0.2819761247521899.
# [I 2024-04-18 13:38:53,106] Trial 29 finished with value: 0.27881679911000856 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8369363260864292, 'num_leaves': 30, 'subsample': 0.8300888143255425}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:53,361] Trial 30 finished with value: 0.31702807316149473 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8307603471272283, 'num_leaves': 30, 'subsample': 0.8342129521974103}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:53,594] Trial 31 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9125284005070663, 'num_leaves': 34, 'subsample': 0.7387390443663867}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:53,817] Trial 32 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9153052303398544, 'num_leaves': 34, 'subsample': 0.7374516501624462}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:54,029] Trial 33 finished with value: 0.2941701740569328 and parameters: {'max_depth': 1, 'colsample_bytree': 0.96168235366446, 'num_leaves': 25, 'subsample': 0.7966814572481725}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:54,297] Trial 34 finished with value: 0.31702807316149473 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8360568913589845, 'num_leaves': 29, 'subsample': 0.8717731512780349}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:54,530] Trial 35 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9053472665097592, 'num_leaves': 34, 'subsample': 0.9452749785582146}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:54,827] Trial 36 finished with value: 0.3345818942962731 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9638286308897307, 'num_leaves': 27, 'subsample': 0.8015332448563899}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:55,161] Trial 37 finished with value: 0.3717780637044955 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8017634817425263, 'num_leaves': 31, 'subsample': 0.7072366782345896}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:55,390] Trial 38 finished with value: 0.28672520394662726 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7599216876061918, 'num_leaves': 38, 'subsample': 0.9376262668059838}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:55,591] Trial 39 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8513548707788824, 'num_leaves': 34, 'subsample': 0.7611831290339511}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:55,860] Trial 40 finished with value: 0.31395295148708446 and parameters: {'max_depth': 3, 'colsample_bytree': 0.955573851813906, 'num_leaves': 41, 'subsample': 0.8328135865456259}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:56,089] Trial 41 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9117681377954092, 'num_leaves': 35, 'subsample': 0.40313335587767113}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:56,320] Trial 42 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.909999442407659, 'num_leaves': 32, 'subsample': 0.7303856376570793}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:56,681] Trial 43 finished with value: 0.3777083975412874 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8090310884826153, 'num_leaves': 27, 'subsample': 0.6876178548321732}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:56,881] Trial 44 finished with value: 0.29425616859845927 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8937354355318445, 'num_leaves': 29, 'subsample': 0.7472261782782574}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:57,110] Trial 45 finished with value: 0.2819761247521899 and parameters: {'max_depth': 2, 'colsample_bytree': 0.941461053752766, 'num_leaves': 33, 'subsample': 0.7869315157866833}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:57,375] Trial 46 finished with value: 0.31395295148708446 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9719146428784738, 'num_leaves': 36, 'subsample': 0.6967969446775194}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:57,576] Trial 47 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8550642557700019, 'num_leaves': 30, 'subsample': 0.8751988740835626}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:57,869] Trial 48 finished with value: 0.34800154504376657 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9279803007227193, 'num_leaves': 38, 'subsample': 0.8095351200371887}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:58,101] Trial 49 finished with value: 0.2831536615362852 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8974117975426494, 'num_leaves': 40, 'subsample': 0.9165994307037388}. Best is trial 29 with value: 0.27881679911000856.
# [I 2024-04-18 13:38:58,125] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-18 13:38:58,490] Trial 0 finished with value: 0.40628745186456944 and parameters: {'max_depth': 7, 'colsample_bytree': 0.645265501415642, 'num_leaves': 32, 'subsample': 0.9746943978885225}. Best is trial 0 with value: 0.40628745186456944.
# [I 2024-04-18 13:38:58,820] Trial 1 finished with value: 0.3605887589767839 and parameters: {'max_depth': 6, 'colsample_bytree': 0.4270205673009993, 'num_leaves': 36, 'subsample': 0.5381197758271143}. Best is trial 1 with value: 0.3605887589767839.
# [I 2024-04-18 13:38:59,067] Trial 2 finished with value: 0.3464322443656972 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7161760769350892, 'num_leaves': 38, 'subsample': 0.7990879319988087}. Best is trial 2 with value: 0.3464322443656972.
# [I 2024-04-18 13:38:59,382] Trial 3 finished with value: 0.3809414526292172 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8610428241227454, 'num_leaves': 58, 'subsample': 0.8643084977308695}. Best is trial 2 with value: 0.3464322443656972.
# [I 2024-04-18 13:38:59,634] Trial 4 finished with value: 0.33526375291507604 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6761334941542536, 'num_leaves': 44, 'subsample': 0.6554491668172817}. Best is trial 4 with value: 0.33526375291507604.
# [I 2024-04-18 13:38:59,824] Trial 5 finished with value: 0.29944305758570755 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5664285945014504, 'num_leaves': 56, 'subsample': 0.814956012139822}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:00,105] Trial 6 finished with value: 0.34261211686122234 and parameters: {'max_depth': 4, 'colsample_bytree': 0.40459259814303977, 'num_leaves': 39, 'subsample': 0.4701837875583937}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:00,384] Trial 7 finished with value: 0.36999489660540996 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8966534815960232, 'num_leaves': 27, 'subsample': 0.8950885018248986}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:00,608] Trial 8 finished with value: 0.31021598633873304 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4294324381992332, 'num_leaves': 37, 'subsample': 0.8888252023276567}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:00,952] Trial 9 finished with value: 0.39208003255494794 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7802682273488355, 'num_leaves': 28, 'subsample': 0.811130410072427}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:01,158] Trial 10 finished with value: 0.29944305758570755 and parameters: {'max_depth': 1, 'colsample_bytree': 0.560069472171823, 'num_leaves': 60, 'subsample': 0.6544160294254942}. Best is trial 5 with value: 0.29944305758570755.
# [I 2024-04-18 13:39:01,374] Trial 11 finished with value: 0.2975442918710522 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5439928733510124, 'num_leaves': 60, 'subsample': 0.6679128555373549}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:01,589] Trial 12 finished with value: 0.29944305758570755 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5718228868276833, 'num_leaves': 53, 'subsample': 0.7111779070186788}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:01,822] Trial 13 finished with value: 0.3017035323445973 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5492115639918234, 'num_leaves': 50, 'subsample': 0.5779708949951214}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:02,032] Trial 14 finished with value: 0.2981521514004204 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5071435608358011, 'num_leaves': 54, 'subsample': 0.7219851483546774}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:02,265] Trial 15 finished with value: 0.3109997696667044 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5001478130493653, 'num_leaves': 47, 'subsample': 0.7047542487583628}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:02,532] Trial 16 finished with value: 0.3331976826922912 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4972424448169521, 'num_leaves': 53, 'subsample': 0.5661761388577241}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:02,738] Trial 17 finished with value: 0.29826400128009606 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6218690052836445, 'num_leaves': 55, 'subsample': 0.7529751515331338}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:02,961] Trial 18 finished with value: 0.3199502544425482 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7294093703930076, 'num_leaves': 50, 'subsample': 0.4376386728661603}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:03,216] Trial 19 finished with value: 0.3487314383498711 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9893188940209783, 'num_leaves': 60, 'subsample': 0.6328891873144346}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:03,422] Trial 20 finished with value: 0.2980684061654866 and parameters: {'max_depth': 1, 'colsample_bytree': 0.47157433090959394, 'num_leaves': 44, 'subsample': 0.5072633337771759}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:03,626] Trial 21 finished with value: 0.2981521514004204 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4829537873352417, 'num_leaves': 43, 'subsample': 0.502928078046002}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:03,860] Trial 22 finished with value: 0.3109997696667044 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4925487324306603, 'num_leaves': 47, 'subsample': 0.6026439495418041}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:04,064] Trial 23 finished with value: 0.29826400128009606 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6156578207082564, 'num_leaves': 50, 'subsample': 0.4038155166484179}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:04,299] Trial 24 finished with value: 0.30956175551925 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4657560340285481, 'num_leaves': 56, 'subsample': 0.7458056239738161}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:04,509] Trial 25 finished with value: 0.2975442918710522 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5271599651285505, 'num_leaves': 41, 'subsample': 0.5331976024063312}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:04,745] Trial 26 finished with value: 0.3017035323445973 and parameters: {'max_depth': 2, 'colsample_bytree': 0.538148611716559, 'num_leaves': 33, 'subsample': 0.5145569589233263}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:05,005] Trial 27 finished with value: 0.34649901971891933 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5924010881623133, 'num_leaves': 41, 'subsample': 0.47656294550851047}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:05,217] Trial 28 finished with value: 0.2980684061654866 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4516544111829467, 'num_leaves': 46, 'subsample': 0.5510263725585347}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:05,587] Trial 29 finished with value: 0.40628745186456944 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6597836823185643, 'num_leaves': 41, 'subsample': 0.6140721633928145}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:05,824] Trial 30 finished with value: 0.3017035323445973 and parameters: {'max_depth': 2, 'colsample_bytree': 0.528931151217341, 'num_leaves': 34, 'subsample': 0.9936274490492782}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:06,037] Trial 31 finished with value: 0.2980684061654866 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4572425958338554, 'num_leaves': 45, 'subsample': 0.5648422088988276}. Best is trial 11 with value: 0.2975442918710522.
# [I 2024-04-18 13:39:06,250] Trial 32 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.43660902503351334, 'num_leaves': 46, 'subsample': 0.5314691299221956}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:06,457] Trial 33 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.41145195488006653, 'num_leaves': 40, 'subsample': 0.5223532859515072}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:06,788] Trial 34 finished with value: 0.348828997607748 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4019590108698091, 'num_leaves': 31, 'subsample': 0.4439516909099502}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:07,031] Trial 35 finished with value: 0.31021598633873304 and parameters: {'max_depth': 2, 'colsample_bytree': 0.42964692855474956, 'num_leaves': 40, 'subsample': 0.661266161482518}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:07,236] Trial 36 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4365625308694219, 'num_leaves': 35, 'subsample': 0.5330524197296662}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:07,501] Trial 37 finished with value: 0.33799461619629306 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4021289923936614, 'num_leaves': 35, 'subsample': 0.6016326848213264}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:07,717] Trial 38 finished with value: 0.2980684061654866 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4427363103626526, 'num_leaves': 25, 'subsample': 0.4781545768301988}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:08,046] Trial 39 finished with value: 0.3704920277369418 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6933448861940505, 'num_leaves': 30, 'subsample': 0.9377089745356725}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:08,269] Trial 40 finished with value: 0.32306758680035746 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7519788251771864, 'num_leaves': 38, 'subsample': 0.6731659885442149}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:08,478] Trial 41 finished with value: 0.2975442918710522 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5220227735293701, 'num_leaves': 36, 'subsample': 0.5308104910058209}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:08,685] Trial 42 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4362913895007581, 'num_leaves': 42, 'subsample': 0.5316399770370029}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:08,901] Trial 43 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4242836878398383, 'num_leaves': 38, 'subsample': 0.41013064178778746}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:09,104] Trial 44 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4354408526853154, 'num_leaves': 39, 'subsample': 0.42329047243527074}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:09,403] Trial 45 finished with value: 0.34261211686122234 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4145645692649312, 'num_leaves': 37, 'subsample': 0.46060345208528886}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:09,651] Trial 46 finished with value: 0.30956175551925 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4643485436212619, 'num_leaves': 42, 'subsample': 0.40163554139528057}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:09,859] Trial 47 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8254634623682869, 'num_leaves': 39, 'subsample': 0.5065838039029366}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:10,068] Trial 48 finished with value: 0.2974429145191798 and parameters: {'max_depth': 1, 'colsample_bytree': 0.42452817373141244, 'num_leaves': 43, 'subsample': 0.4863913798940084}. Best is trial 32 with value: 0.2974429145191798.
# [I 2024-04-18 13:39:10,313] Trial 49 finished with value: 0.31021598633873304 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4415816582665568, 'num_leaves': 36, 'subsample': 0.5928223228941337}. Best is trial 32 with value: 0.2974429145191798.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None



for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            r = Result(y_val, y_proba)
            s["acc"].append(r.acc())
            f1_s, th = r.f1(optimize=True)
            s["f1"].append(f1_s)
            s["th"].append(th)
            # s["f1"].append(r.f1(optimize=True))
            # s["f1"].append(r.f1())
            # s["auc"].append(r.auc())
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=0.4, color='r', linestyle='--')
    axs[1].axvline(x=0.4, color='r', linestyle='--')

# Remove space between subplots
    plt.subplots_adjust(hspace=0)

# Show the plot
    plt.show()
# Out:
# acc     :0.8784028174376547
# f1      :0.8650318711936352
# th      :0.49375
# logloss :0.29040540446754665
# max size0_midPoint            :61.5
# Lat0_Top                      :21.5
# NDepth_Bottom                 :17.5
# Habitat0_Average              :17.25
# Behavior0_Average             :16.0
# Lon0_Top                      :15.0
# Habitat0_Top                  :12.0
# Behavior0_Bottom              :11.5
# DDepth_Bottom                 :11.25
# DDepth_midPoint               :10.25
# Lat0_Bottom                   :10.0
# DDepth_Top                    :9.75
# Associate0_Top                :9.5
# Associate0_Bottom             :7.75
# Lon0_Bottom                   :6.5
# NDepth_midPoint               :6.0
# Behavior0_Top                 :5.5
# Associate0_Average            :5.5
# NDepth_Top                    :4.0
# Habitat0_Bottom               :3.5
# TemperatureT0_Top             :3.25
# TemperatureT0_Average         :2.75
# Salinity0_Bottom              :1.5
# TemperatureT0_Bottom          :1.5
# Salinity0_Average             :0.75
# Salinity0_Top                 :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8710974681134589
# f1      :0.8052193415218021
# th      :0.49531250000000004
# logloss :0.27881679911000856
# max size0_midPoint            :45.75
# DDepth_midPoint               :27.0
# Lon0_Top                      :23.75
# Lat0_Top                      :19.25
# Habitat0_Average              :18.75
# TemperatureT0_Average         :18.75
# Lat0_Bottom                   :17.0
# NDepth_midPoint               :15.0
# Lon0_Bottom                   :13.25
# Habitat0_Bottom               :11.75
# Associate_Floating object     :9.75
# Associate0_Average            :8.5
# Behavior0_Average             :8.25
# Behavior0_Bottom              :7.5
# NDepth_Bottom                 :7.0
# TemperatureT0_Bottom          :7.0
# DDepth_Bottom                 :6.5
# DDepth_Top                    :5.25
# Associate0_Bottom             :3.75
# Associate0_Top                :3.25
# Behavior0_Top                 :2.75
# Habitat0_Top                  :2.75
# TemperatureT0_Top             :2.5
# Salinity0_Bottom              :0.5
# NDepth_Top                    :0.25
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Associate_Large pelagics      :0.0
# acc     :0.875904245193223
# f1      :0.6783073982455408
# th      :0.49687499999999996
# logloss :0.2974429145191798
# max size0_midPoint            :21.25
# Lon0_Bottom                   :12.25
# DDepth_midPoint               :7.0
# Lat0_Bottom                   :7.0
# NDepth_midPoint               :6.5
# Habitat0_Top                  :5.5
# Habitat0_Average              :5.5
# Habitat0_Bottom               :5.0
# Salinity0_Average             :5.0
# DDepth_Bottom                 :3.75
# NDepth_Bottom                 :3.75
# Salinity0_Bottom              :3.5
# Lat0_Top                      :2.75
# Associate0_Bottom             :2.5
# TemperatureT0_Bottom          :2.0
# TemperatureT0_Average         :2.0
# DDepth_Top                    :1.75
# Behavior0_Average             :1.25
# Associate0_Top                :0.75
# Lon0_Top                      :0.5
# TemperatureT0_Top             :0.5
# NDepth_Top                    :0.0
# Behavior0_Bottom              :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# Associate0_Average            :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")
