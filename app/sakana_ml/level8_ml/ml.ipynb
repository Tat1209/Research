# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

# x = x.select(~ pl.selectors.ends_with("Associate0_Floating object"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

# テストデータの評価
class Result:
    def __init__(self, val, proba):
        self.val = val
        self.proba = proba
        self.pred = proba.argmax(axis=1)

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=1)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-15 21:47:58,985] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-15 21:47:59,198] Trial 0 finished with value: 0.4902019918060341 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7496018602642913, 'num_leaves': 25, 'subsample': 0.6138040052583076}. Best is trial 0 with value: 0.4902019918060341.
# [I 2024-04-15 21:47:59,460] Trial 1 finished with value: 0.5308595033265362 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5959895609769068, 'num_leaves': 41, 'subsample': 0.6742169659987536}. Best is trial 0 with value: 0.4902019918060341.
# [I 2024-04-15 21:47:59,768] Trial 2 finished with value: 0.5417011450136004 and parameters: {'max_depth': 7, 'colsample_bytree': 0.516695057406654, 'num_leaves': 35, 'subsample': 0.7569764768252312}. Best is trial 0 with value: 0.4902019918060341.
# [I 2024-04-15 21:48:00,079] Trial 3 finished with value: 0.5799410431637262 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9996456369618707, 'num_leaves': 54, 'subsample': 0.43667650459598406}. Best is trial 0 with value: 0.4902019918060341.
# [I 2024-04-15 21:48:00,382] Trial 4 finished with value: 0.532042597138005 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4097148961168018, 'num_leaves': 43, 'subsample': 0.5896611696013065}. Best is trial 0 with value: 0.4902019918060341.
# [I 2024-04-15 21:48:00,587] Trial 5 finished with value: 0.48684770345472 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6027364452492008, 'num_leaves': 41, 'subsample': 0.7059433377236595}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:00,805] Trial 6 finished with value: 0.4875785636892864 and parameters: {'max_depth': 2, 'colsample_bytree': 0.45340088308237736, 'num_leaves': 43, 'subsample': 0.943953512713631}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:01,058] Trial 7 finished with value: 0.49083720109894124 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8125781487789441, 'num_leaves': 52, 'subsample': 0.9701010488093642}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:01,240] Trial 8 finished with value: 0.5034929367645137 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7731442446235289, 'num_leaves': 34, 'subsample': 0.8522418128767943}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:01,451] Trial 9 finished with value: 0.4902019918060341 and parameters: {'max_depth': 2, 'colsample_bytree': 0.752399338521273, 'num_leaves': 53, 'subsample': 0.8737639964832218}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:01,743] Trial 10 finished with value: 0.5289374381820052 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6147586838762863, 'num_leaves': 60, 'subsample': 0.48684267143599375}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:01,945] Trial 11 finished with value: 0.5030134426956705 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4166597907961272, 'num_leaves': 44, 'subsample': 0.9521423134109436}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:02,190] Trial 12 finished with value: 0.5045351041661306 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5446161615664411, 'num_leaves': 37, 'subsample': 0.7786426552332358}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:02,431] Trial 13 finished with value: 0.5111430580704559 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4873315111419766, 'num_leaves': 47, 'subsample': 0.8621567459214272}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:02,646] Trial 14 finished with value: 0.4873239208861494 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6508068450326823, 'num_leaves': 28, 'subsample': 0.5649423962458984}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:02,917] Trial 15 finished with value: 0.5274845486855431 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6547660736831397, 'num_leaves': 27, 'subsample': 0.5394891193384698}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:03,104] Trial 16 finished with value: 0.5032608021816669 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8802298269862443, 'num_leaves': 30, 'subsample': 0.6762045107802349}. Best is trial 5 with value: 0.48684770345472.
# [I 2024-04-15 21:48:03,323] Trial 17 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6842169400691269, 'num_leaves': 31, 'subsample': 0.5892119405277757}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:03,622] Trial 18 finished with value: 0.5398993777113977 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5605019756700713, 'num_leaves': 32, 'subsample': 0.750706521753392}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:03,885] Trial 19 finished with value: 0.5160259528889563 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6973744189278153, 'num_leaves': 37, 'subsample': 0.6556648119617485}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:04,091] Trial 20 finished with value: 0.5032608021816669 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8958464271744929, 'num_leaves': 39, 'subsample': 0.5053790063258807}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:04,323] Trial 21 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6642492941279369, 'num_leaves': 30, 'subsample': 0.5789516979749934}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:04,550] Trial 22 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6760785096640397, 'num_leaves': 30, 'subsample': 0.6362617552222041}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:04,829] Trial 23 finished with value: 0.5296281156099116 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7020010570841465, 'num_leaves': 31, 'subsample': 0.6116299734131703}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:05,059] Trial 24 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.694467585602511, 'num_leaves': 28, 'subsample': 0.4123707832446056}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:05,320] Trial 25 finished with value: 0.5075862373655936 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8420799837077673, 'num_leaves': 25, 'subsample': 0.49071085810349585}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:05,526] Trial 26 finished with value: 0.5042348317744788 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6544126500827658, 'num_leaves': 33, 'subsample': 0.6457042834666284}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:05,840] Trial 27 finished with value: 0.5120030172854712 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7276453030403343, 'num_leaves': 30, 'subsample': 0.5443310796981672}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:06,147] Trial 28 finished with value: 0.5557502508926151 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6291042244194742, 'num_leaves': 36, 'subsample': 0.7126434271488817}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:06,368] Trial 29 finished with value: 0.4878039607622146 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7866109338347872, 'num_leaves': 25, 'subsample': 0.6210935055041946}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:06,565] Trial 30 finished with value: 0.5032328813881516 and parameters: {'max_depth': 1, 'colsample_bytree': 0.565742331654238, 'num_leaves': 29, 'subsample': 0.57987158069466}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:06,800] Trial 31 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6837378982640653, 'num_leaves': 27, 'subsample': 0.4068437623931141}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:07,031] Trial 32 finished with value: 0.48347735046235407 and parameters: {'max_depth': 2, 'colsample_bytree': 0.736662574009276, 'num_leaves': 32, 'subsample': 0.42576206125230065}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:07,287] Trial 33 finished with value: 0.5160259528889563 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6884304139787614, 'num_leaves': 27, 'subsample': 0.4576366476741356}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:07,511] Trial 34 finished with value: 0.48347735046235407 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7162950356629487, 'num_leaves': 34, 'subsample': 0.5298316904799871}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:07,792] Trial 35 finished with value: 0.5308595033265362 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5854677919304341, 'num_leaves': 25, 'subsample': 0.6183267850484273}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:08,018] Trial 36 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6671123549596218, 'num_leaves': 29, 'subsample': 0.747047108139945}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:08,226] Trial 37 finished with value: 0.5042348317744788 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6342944733192402, 'num_leaves': 39, 'subsample': 0.4499472429794795}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:08,482] Trial 38 finished with value: 0.5074056422866063 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5100224979878608, 'num_leaves': 35, 'subsample': 0.5946086554477903}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:08,821] Trial 39 finished with value: 0.5761311663111767 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7698420185368742, 'num_leaves': 31, 'subsample': 0.6923995487531749}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:09,045] Trial 40 finished with value: 0.4821890459855238 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8228545020932441, 'num_leaves': 33, 'subsample': 0.7949384434842661}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:09,275] Trial 41 finished with value: 0.48061936220765095 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6844149942073361, 'num_leaves': 27, 'subsample': 0.4116953886238001}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:09,518] Trial 42 finished with value: 0.48684770345472 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5994876111760437, 'num_leaves': 28, 'subsample': 0.4589634680420531}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:09,745] Trial 43 finished with value: 0.4902019918060341 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7439710850486755, 'num_leaves': 27, 'subsample': 0.4040734868397475}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:09,966] Trial 44 finished with value: 0.5033927184596382 and parameters: {'max_depth': 1, 'colsample_bytree': 0.675129131062917, 'num_leaves': 50, 'subsample': 0.5127691387074268}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:10,231] Trial 45 finished with value: 0.511302217601879 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9985558756118114, 'num_leaves': 58, 'subsample': 0.4843650259199055}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:10,439] Trial 46 finished with value: 0.5042348317744788 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6235512112990097, 'num_leaves': 26, 'subsample': 0.5576162680333077}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:10,760] Trial 47 finished with value: 0.5509539576093172 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7125801961314885, 'num_leaves': 30, 'subsample': 0.6523829056026922}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:10,984] Trial 48 finished with value: 0.4878039607622146 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7889425878192843, 'num_leaves': 45, 'subsample': 0.5906538618417523}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:11,211] Trial 49 finished with value: 0.4873239208861494 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6384656575678408, 'num_leaves': 29, 'subsample': 0.7190925046744454}. Best is trial 17 with value: 0.48061936220765095.
# [I 2024-04-15 21:48:11,236] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-15 21:48:11,579] Trial 0 finished with value: 0.3710235221252723 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8349361667247264, 'num_leaves': 31, 'subsample': 0.7504565587308338}. Best is trial 0 with value: 0.3710235221252723.
# [I 2024-04-15 21:48:11,916] Trial 1 finished with value: 0.35771250983110214 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7204730659656262, 'num_leaves': 25, 'subsample': 0.9292866577158064}. Best is trial 1 with value: 0.35771250983110214.
# [I 2024-04-15 21:48:12,243] Trial 2 finished with value: 0.3726953850343496 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8880604966001655, 'num_leaves': 27, 'subsample': 0.7532125722854321}. Best is trial 1 with value: 0.35771250983110214.
# [I 2024-04-15 21:48:12,553] Trial 3 finished with value: 0.3547397230467201 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5886407995127596, 'num_leaves': 47, 'subsample': 0.6582214340264649}. Best is trial 3 with value: 0.3547397230467201.
# [I 2024-04-15 21:48:12,739] Trial 4 finished with value: 0.31108909334709844 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6643117290655227, 'num_leaves': 29, 'subsample': 0.4542955594441857}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:13,010] Trial 5 finished with value: 0.3294686288907986 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8500221537558195, 'num_leaves': 42, 'subsample': 0.5735544887941689}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:13,340] Trial 6 finished with value: 0.35153128021348434 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6877983999818993, 'num_leaves': 49, 'subsample': 0.8198919201272465}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:13,534] Trial 7 finished with value: 0.31108909334709844 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6835088550253454, 'num_leaves': 37, 'subsample': 0.6994350423138496}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:13,826] Trial 8 finished with value: 0.3267661366114033 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9850896034185394, 'num_leaves': 43, 'subsample': 0.5265417044374352}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:14,154] Trial 9 finished with value: 0.36318581716391185 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9386466865424046, 'num_leaves': 47, 'subsample': 0.8943168430685633}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:14,362] Trial 10 finished with value: 0.31240180098075715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.409072174746426, 'num_leaves': 59, 'subsample': 0.40086805875547327}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:14,563] Trial 11 finished with value: 0.31221499700889904 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5866238154447745, 'num_leaves': 35, 'subsample': 0.41698912999724885}. Best is trial 4 with value: 0.31108909334709844.
# [I 2024-04-15 21:48:14,791] Trial 12 finished with value: 0.3064634541913502 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6780571959082473, 'num_leaves': 36, 'subsample': 0.6157971566651247}. Best is trial 12 with value: 0.3064634541913502.
# [I 2024-04-15 21:48:15,018] Trial 13 finished with value: 0.30514469269182765 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5511379164136144, 'num_leaves': 33, 'subsample': 0.5300985615721859}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:15,274] Trial 14 finished with value: 0.32094821497020737 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4652635425059888, 'num_leaves': 36, 'subsample': 0.5892935515650165}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:15,528] Trial 15 finished with value: 0.3163093217350598 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5303914180608356, 'num_leaves': 33, 'subsample': 0.5274187326996836}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:15,757] Trial 16 finished with value: 0.3071672924736607 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7499075241089467, 'num_leaves': 40, 'subsample': 0.6596546122786264}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:15,988] Trial 17 finished with value: 0.30565010011060423 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5924222203065351, 'num_leaves': 54, 'subsample': 0.6092150586680283}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:16,217] Trial 18 finished with value: 0.30514469269182765 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5679850220478687, 'num_leaves': 58, 'subsample': 0.9964473834573069}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:16,490] Trial 19 finished with value: 0.3163093217350598 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5110840876778352, 'num_leaves': 60, 'subsample': 0.9770872825633358}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:16,719] Trial 20 finished with value: 0.3076823568830264 and parameters: {'max_depth': 2, 'colsample_bytree': 0.42510323080532286, 'num_leaves': 54, 'subsample': 0.7947313899395478}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:16,951] Trial 21 finished with value: 0.30565010011060423 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5947952584940389, 'num_leaves': 55, 'subsample': 0.5015232655737087}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:17,220] Trial 22 finished with value: 0.3163093217350598 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5362298331674685, 'num_leaves': 54, 'subsample': 0.8683847659505328}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:17,451] Trial 23 finished with value: 0.3088137206832842 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6252217481161966, 'num_leaves': 57, 'subsample': 0.48089162805820346}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:17,721] Trial 24 finished with value: 0.32094821497020737 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4991574992367413, 'num_leaves': 51, 'subsample': 0.5698590026708504}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:17,955] Trial 25 finished with value: 0.30514469269182765 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5614540665102619, 'num_leaves': 51, 'subsample': 0.6367378265787099}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:18,252] Trial 26 finished with value: 0.3375193249811689 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7574434657125861, 'num_leaves': 50, 'subsample': 0.9858493504974816}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:18,455] Trial 27 finished with value: 0.3128051711808397 and parameters: {'max_depth': 1, 'colsample_bytree': 0.45616736712763956, 'num_leaves': 45, 'subsample': 0.653885606802933}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:18,752] Trial 28 finished with value: 0.3377690246036151 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5646126978210021, 'num_leaves': 58, 'subsample': 0.7152612171108435}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:18,977] Trial 29 finished with value: 0.3088137206832842 and parameters: {'max_depth': 2, 'colsample_bytree': 0.621945344317216, 'num_leaves': 52, 'subsample': 0.7707718999823522}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:19,305] Trial 30 finished with value: 0.35649468339407336 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4706349305585842, 'num_leaves': 39, 'subsample': 0.5330318167814431}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:19,523] Trial 31 finished with value: 0.3088137206832842 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6293415032026075, 'num_leaves': 56, 'subsample': 0.6187752282934037}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:19,786] Trial 32 finished with value: 0.32076243084172534 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5513796302149272, 'num_leaves': 52, 'subsample': 0.7250565618974794}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:20,023] Trial 33 finished with value: 0.3108584654138066 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7355303026257293, 'num_leaves': 32, 'subsample': 0.6885106944078715}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:20,230] Trial 34 finished with value: 0.3103770487547894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.501199286884649, 'num_leaves': 25, 'subsample': 0.6236919366150732}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:20,458] Trial 35 finished with value: 0.3088137206832842 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6522667194153667, 'num_leaves': 48, 'subsample': 0.5616238101475808}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:20,667] Trial 36 finished with value: 0.31221499700889904 and parameters: {'max_depth': 1, 'colsample_bytree': 0.581574173808491, 'num_leaves': 30, 'subsample': 0.45786942025564836}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:20,937] Trial 37 finished with value: 0.31900284904904996 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7871161949777479, 'num_leaves': 45, 'subsample': 0.8273228337143735}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:21,262] Trial 38 finished with value: 0.3547397230467201 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6187107269957752, 'num_leaves': 53, 'subsample': 0.7484431802522535}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:21,500] Trial 39 finished with value: 0.31136438952250917 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5379876958296378, 'num_leaves': 57, 'subsample': 0.6720606967433788}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:21,716] Trial 40 finished with value: 0.31137277507053224 and parameters: {'max_depth': 1, 'colsample_bytree': 0.574394614776612, 'num_leaves': 27, 'subsample': 0.5930252842962869}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:21,950] Trial 41 finished with value: 0.30565010011060423 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6004799805816649, 'num_leaves': 55, 'subsample': 0.4861266405339171}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:22,229] Trial 42 finished with value: 0.31975162983844796 and parameters: {'max_depth': 3, 'colsample_bytree': 0.713903263039119, 'num_leaves': 56, 'subsample': 0.5056096751169643}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:22,480] Trial 43 finished with value: 0.3088137206832842 and parameters: {'max_depth': 2, 'colsample_bytree': 0.654394104339167, 'num_leaves': 58, 'subsample': 0.5491915825762068}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:22,694] Trial 44 finished with value: 0.31221499700889904 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6025339642126213, 'num_leaves': 60, 'subsample': 0.44964820827976426}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:22,932] Trial 45 finished with value: 0.30514469269182765 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5630913985520424, 'num_leaves': 49, 'subsample': 0.9528482600571644}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:23,215] Trial 46 finished with value: 0.32094821497020737 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4842318706615807, 'num_leaves': 50, 'subsample': 0.945038181577879}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:23,434] Trial 47 finished with value: 0.3128051711808397 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4341207212588677, 'num_leaves': 47, 'subsample': 0.9281577393465971}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:23,668] Trial 48 finished with value: 0.31136438952250917 and parameters: {'max_depth': 2, 'colsample_bytree': 0.520768360239813, 'num_leaves': 45, 'subsample': 0.9478630470437908}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:23,955] Trial 49 finished with value: 0.3377690246036151 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5534925084230309, 'num_leaves': 49, 'subsample': 0.9111228859976612}. Best is trial 13 with value: 0.30514469269182765.
# [I 2024-04-15 21:48:23,979] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-15 21:48:24,301] Trial 0 finished with value: 0.4056701477388904 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6779568990556152, 'num_leaves': 56, 'subsample': 0.6135817686267336}. Best is trial 0 with value: 0.4056701477388904.
# [I 2024-04-15 21:48:24,518] Trial 1 finished with value: 0.33974495336489513 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5727392109484715, 'num_leaves': 27, 'subsample': 0.9989015626507867}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:24,766] Trial 2 finished with value: 0.35928396765972564 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8512227331723106, 'num_leaves': 27, 'subsample': 0.5346427901030448}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:25,101] Trial 3 finished with value: 0.4404020220307552 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9916708995155621, 'num_leaves': 41, 'subsample': 0.9350475724807651}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:25,428] Trial 4 finished with value: 0.4061380690230794 and parameters: {'max_depth': 7, 'colsample_bytree': 0.41957873385579364, 'num_leaves': 33, 'subsample': 0.7084143750768535}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:25,676] Trial 5 finished with value: 0.3627295460605868 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7564393167760732, 'num_leaves': 60, 'subsample': 0.9404757711358924}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:26,000] Trial 6 finished with value: 0.42032550412245856 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5136117390264869, 'num_leaves': 34, 'subsample': 0.49902136087364146}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:26,276] Trial 7 finished with value: 0.3880361670933758 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5546618038551994, 'num_leaves': 39, 'subsample': 0.8785139783849917}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:26,618] Trial 8 finished with value: 0.44441936955910266 and parameters: {'max_depth': 7, 'colsample_bytree': 0.9245382890108264, 'num_leaves': 39, 'subsample': 0.8469449901621845}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:26,937] Trial 9 finished with value: 0.4090532768319868 and parameters: {'max_depth': 6, 'colsample_bytree': 0.4634266252670651, 'num_leaves': 45, 'subsample': 0.8894688775185915}. Best is trial 1 with value: 0.33974495336489513.
# [I 2024-04-15 21:48:27,140] Trial 10 finished with value: 0.3110520707031469 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6123608047479973, 'num_leaves': 25, 'subsample': 0.750017074566595}. Best is trial 10 with value: 0.3110520707031469.
# [I 2024-04-15 21:48:27,347] Trial 11 finished with value: 0.3107240837084211 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6267158242349148, 'num_leaves': 26, 'subsample': 0.7355213458483457}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:27,557] Trial 12 finished with value: 0.3107240837084211 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6522754583554268, 'num_leaves': 25, 'subsample': 0.7325204399001047}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:27,762] Trial 13 finished with value: 0.3116978497504815 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7185255429524956, 'num_leaves': 32, 'subsample': 0.7804737897456636}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:27,993] Trial 14 finished with value: 0.33259140051847474 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7894026562188364, 'num_leaves': 48, 'subsample': 0.6305892819270396}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:28,207] Trial 15 finished with value: 0.3107240837084211 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6429400604395542, 'num_leaves': 30, 'subsample': 0.6377562119304692}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:28,437] Trial 16 finished with value: 0.337410164975118 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6440782007866711, 'num_leaves': 36, 'subsample': 0.7935457604039864}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:28,705] Trial 17 finished with value: 0.35928396765972564 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8211937081784826, 'num_leaves': 49, 'subsample': 0.6916317980949777}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:28,989] Trial 18 finished with value: 0.38824995023750564 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7138702908670747, 'num_leaves': 29, 'subsample': 0.4026143277224266}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:29,220] Trial 19 finished with value: 0.3289278649799839 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5170137661020103, 'num_leaves': 25, 'subsample': 0.5654931002487797}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:29,428] Trial 20 finished with value: 0.3110520707031469 and parameters: {'max_depth': 1, 'colsample_bytree': 0.587994351296186, 'num_leaves': 36, 'subsample': 0.7096305997572184}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:29,635] Trial 21 finished with value: 0.3107240837084211 and parameters: {'max_depth': 1, 'colsample_bytree': 0.648024460856976, 'num_leaves': 30, 'subsample': 0.6470955432572632}. Best is trial 11 with value: 0.3107240837084211.
# [I 2024-04-15 21:48:29,841] Trial 22 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6684226847734474, 'num_leaves': 30, 'subsample': 0.8128996910900835}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:30,079] Trial 23 finished with value: 0.33863594659711616 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7436219449914185, 'num_leaves': 25, 'subsample': 0.8155764541134265}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:30,282] Trial 24 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6878054919943679, 'num_leaves': 29, 'subsample': 0.758148798176875}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:30,544] Trial 25 finished with value: 0.3619627345042672 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8718783147382302, 'num_leaves': 30, 'subsample': 0.7725825777038484}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:30,779] Trial 26 finished with value: 0.3343245064597964 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6917909075404626, 'num_leaves': 34, 'subsample': 0.8256898194902875}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:30,992] Trial 27 finished with value: 0.3110366195918589 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7693396789309048, 'num_leaves': 28, 'subsample': 0.6786759977677014}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:31,226] Trial 28 finished with value: 0.3371290349117002 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6083853336321852, 'num_leaves': 36, 'subsample': 0.857389716942069}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:31,552] Trial 29 finished with value: 0.4056701477388904 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6838281008755236, 'num_leaves': 52, 'subsample': 0.5768936587050817}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:31,821] Trial 30 finished with value: 0.3618309830125605 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5460175126377063, 'num_leaves': 32, 'subsample': 0.9140949784160715}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:32,045] Trial 31 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6635600877708221, 'num_leaves': 28, 'subsample': 0.7409247567398249}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:32,257] Trial 32 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6797710310957528, 'num_leaves': 28, 'subsample': 0.7453737223813706}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:32,488] Trial 33 finished with value: 0.3343245064597964 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6892261804483119, 'num_leaves': 29, 'subsample': 0.9960362426535421}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:32,702] Trial 34 finished with value: 0.3116978497504815 and parameters: {'max_depth': 1, 'colsample_bytree': 0.733997195070532, 'num_leaves': 28, 'subsample': 0.808626659722041}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:32,935] Trial 35 finished with value: 0.33259140051847474 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7812054379948437, 'num_leaves': 31, 'subsample': 0.7602957439942504}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:33,144] Trial 36 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6663138858040765, 'num_leaves': 27, 'subsample': 0.6859104274369946}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:33,410] Trial 37 finished with value: 0.35928396765972564 and parameters: {'max_depth': 3, 'colsample_bytree': 0.828813283523577, 'num_leaves': 34, 'subsample': 0.7243222736929733}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:33,616] Trial 38 finished with value: 0.3116978497504815 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7128202365534677, 'num_leaves': 39, 'subsample': 0.6629216960971618}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:33,941] Trial 39 finished with value: 0.4028694266032491 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5913953381462149, 'num_leaves': 43, 'subsample': 0.8339335344613704}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:34,237] Trial 40 finished with value: 0.3880361670933758 and parameters: {'max_depth': 4, 'colsample_bytree': 0.554536345568186, 'num_leaves': 57, 'subsample': 0.7818502083702044}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:34,450] Trial 41 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6721277697215102, 'num_leaves': 28, 'subsample': 0.6873710304027572}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:34,656] Trial 42 finished with value: 0.31062831855861706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6636813982552819, 'num_leaves': 27, 'subsample': 0.6074993842212281}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:34,879] Trial 43 finished with value: 0.3371290349117002 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6158002072900326, 'num_leaves': 27, 'subsample': 0.7074484929386792}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:35,093] Trial 44 finished with value: 0.3110366195918589 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7478363928779453, 'num_leaves': 32, 'subsample': 0.756707297903915}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:35,296] Trial 45 finished with value: 0.3116978497504815 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7014024926673903, 'num_leaves': 33, 'subsample': 0.750314334944296}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:35,527] Trial 46 finished with value: 0.33259140051847474 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8076674745440099, 'num_leaves': 27, 'subsample': 0.881401928496185}. Best is trial 22 with value: 0.31062831855861706.
# [I 2024-04-15 21:48:35,740] Trial 47 finished with value: 0.30982836975324024 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4129604877182927, 'num_leaves': 31, 'subsample': 0.8591115469201099}. Best is trial 47 with value: 0.30982836975324024.
# [I 2024-04-15 21:48:35,954] Trial 48 finished with value: 0.31045080972779443 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4352771783194333, 'num_leaves': 37, 'subsample': 0.8515703542461284}. Best is trial 47 with value: 0.30982836975324024.
# [I 2024-04-15 21:48:36,184] Trial 49 finished with value: 0.33446139787472845 and parameters: {'max_depth': 2, 'colsample_bytree': 0.40005895768010385, 'num_leaves': 40, 'subsample': 0.9455252131396262}. Best is trial 47 with value: 0.30982836975324024.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None

for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            r = Result(y_val, y_proba)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["auc"].append(r.auc())
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")
# Out:
# acc     :0.7809347039786788
# f1      :0.746104206049785
# auc     :0.740094647755094
# logloss :0.48061936220765095
# Behavior0_Average             :27.0
# NDepth_Bottom                 :25.5
# Lat0_Top                      :23.25
# DDepth_midPoint               :21.75
# Habitat0_Top                  :18.5
# DDepth_Top                    :16.25
# Lat0_Bottom                   :14.25
# Lon0_Top                      :12.75
# Behavior0_Bottom              :12.0
# Lon0_Bottom                   :11.5
# Habitat0_Average              :11.5
# DDepth_Bottom                 :9.5
# Habitat0_Bottom               :9.5
# Associate0_Top                :9.5
# Associate0_Bottom             :9.0
# TemperatureT0_Top             :8.25
# TemperatureT0_Average         :7.5
# NDepth_midPoint               :6.5
# Behavior0_Top                 :4.5
# NDepth_Top                    :3.0
# TemperatureT0_Bottom          :2.5
# Associate0_Average            :0.75
# Salinity0_Bottom              :0.0
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8613411383971064
# f1      :0.7716365571440401
# auc     :0.759732144759409
# logloss :0.30514469269182765
# DDepth_midPoint               :32.75
# Habitat0_Average              :25.75
# Lat0_Bottom                   :24.0
# TemperatureT0_Average         :23.25
# Lon0_Top                      :21.5
# Lat0_Top                      :17.5
# Lon0_Bottom                   :15.75
# NDepth_midPoint               :14.5
# Behavior0_Average             :12.5
# Habitat0_Bottom               :12.25
# DDepth_Bottom                 :10.75
# TemperatureT0_Bottom          :10.5
# NDepth_Bottom                 :8.75
# Associate0_Average            :8.75
# DDepth_Top                    :7.5
# Associate_Floating object     :7.5
# Associate0_Top                :6.5
# Habitat0_Top                  :6.0
# Associate0_Bottom             :5.5
# Behavior0_Bottom              :4.0
# TemperatureT0_Top             :4.0
# Behavior0_Top                 :3.0
# NDepth_Top                    :2.25
# Salinity0_Bottom              :1.5
# Salinity0_Average             :0.5
# Salinity0_Top                 :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8636969350847136
# f1      :0.5686845362394082
# auc     :0.5629372156185036
# logloss :0.30982836975324024
# Lon0_Bottom                   :12.75
# Habitat0_Top                  :11.0
# DDepth_midPoint               :9.25
# Habitat0_Bottom               :8.75
# DDepth_Bottom                 :8.0
# Lat0_Top                      :6.5
# Salinity0_Bottom              :5.0
# NDepth_midPoint               :4.75
# Behavior0_Average             :4.75
# DDepth_Top                    :4.25
# Associate0_Bottom             :4.25
# Salinity0_Average             :3.75
# Habitat0_Average              :3.5
# NDepth_Bottom                 :3.25
# TemperatureT0_Average         :3.25
# Lat0_Bottom                   :3.0
# Lon0_Top                      :2.0
# TemperatureT0_Bottom          :1.25
# Behavior0_Bottom              :0.5
# Associate0_Top                :0.25
# NDepth_Top                    :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# TemperatureT0_Top             :0.0
# Associate0_Average            :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")

# %%
print(a)
# Create a figure and a set of subplots
fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

# Plot the first data on the first subplot
sns.histplot(a.proba[0], ax=axs[0], color='blue', bins=10, kde=True)
axs[0].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
axs[0].xaxis.tick_top()  # and move the X-Axis
axs[0].set_ylabel('Data 1')

# Plot the second data on the second subplot
sns.histplot(data2, ax=axs[1], color='red', bins=10, kde=True)
axs[1].set_ylabel('Data 2')

# Remove space between subplots
plt.subplots_adjust(hspace=0)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 5
#       2 fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})
#       4 # Plot the first data on the first subplot
# ----> 5 sns.histplot(a.proba[0], ax=axs[0], color='blue', bins=10, kde=True)
#       6 axs[0].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
#       7 axs[0].xaxis.tick_top()  # and move the X-Axis
#
# AttributeError: 'Scores' object has no attribute 'proba'
