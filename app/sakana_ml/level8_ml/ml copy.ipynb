# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
# x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
# x = x.select(~ pl.selectors.contains("Lon"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
# x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

x = x.select(~ pl.selectors.ends_with("Associate0_Floating object"))
x = x.select(~ pl.selectors.ends_with("Associate0_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba, optimize=False):
        self.val = val
        self.proba = proba

        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            self.pred = self.proba[:, 1] >= threshold
            self.th = threshold
        else:
            self.pred = proba.argmax(axis=1)
            self.th = 0.5

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        # return a["f1"][0]
        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-18 13:51:27,427] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-18 13:51:27,721] Trial 0 finished with value: 0.3231340019038581 and parameters: {'max_depth': 5, 'colsample_bytree': 0.49769756302936585, 'num_leaves': 45, 'subsample': 0.8976853289890163}. Best is trial 0 with value: 0.3231340019038581.
# [I 2024-04-18 13:51:27,903] Trial 1 finished with value: 0.29463614001178706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.862423985323855, 'num_leaves': 58, 'subsample': 0.7677414901932904}. Best is trial 1 with value: 0.29463614001178706.
# [I 2024-04-18 13:51:28,218] Trial 2 finished with value: 0.3260383372361632 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5237027462496897, 'num_leaves': 46, 'subsample': 0.40572325543240373}. Best is trial 1 with value: 0.29463614001178706.
# [I 2024-04-18 13:51:28,538] Trial 3 finished with value: 0.3353381790611458 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7034760524655719, 'num_leaves': 29, 'subsample': 0.8865592517114804}. Best is trial 1 with value: 0.29463614001178706.
# [I 2024-04-18 13:51:28,847] Trial 4 finished with value: 0.3357110613677333 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7579704449376891, 'num_leaves': 26, 'subsample': 0.7852830314135217}. Best is trial 1 with value: 0.29463614001178706.
# [I 2024-04-18 13:51:29,169] Trial 5 finished with value: 0.3148624637567906 and parameters: {'max_depth': 6, 'colsample_bytree': 0.4854610732227734, 'num_leaves': 54, 'subsample': 0.7563679937849443}. Best is trial 1 with value: 0.29463614001178706.
# [I 2024-04-18 13:51:29,390] Trial 6 finished with value: 0.29291956282303894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7136879377086884, 'num_leaves': 28, 'subsample': 0.8847055559612998}. Best is trial 6 with value: 0.29291956282303894.
# [I 2024-04-18 13:51:29,614] Trial 7 finished with value: 0.29291956282303894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7227880835415945, 'num_leaves': 25, 'subsample': 0.9752662650199856}. Best is trial 6 with value: 0.29291956282303894.
# [I 2024-04-18 13:51:29,839] Trial 8 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5339246093460628, 'num_leaves': 25, 'subsample': 0.7668136473627476}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:30,176] Trial 9 finished with value: 0.313208149482114 and parameters: {'max_depth': 7, 'colsample_bytree': 0.48718026107647805, 'num_leaves': 36, 'subsample': 0.6684136831685414}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:30,433] Trial 10 finished with value: 0.31295263841123877 and parameters: {'max_depth': 3, 'colsample_bytree': 0.614573868359338, 'num_leaves': 37, 'subsample': 0.5653118900992058}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:30,684] Trial 11 finished with value: 0.3219994411865773 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8783472411284037, 'num_leaves': 34, 'subsample': 0.6370900571408904}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:30,885] Trial 12 finished with value: 0.29382823638656763 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6100006439756857, 'num_leaves': 31, 'subsample': 0.8736888914917486}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:31,139] Trial 13 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4145583016653683, 'num_leaves': 38, 'subsample': 0.9822700797959337}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:31,374] Trial 14 finished with value: 0.2980300365217891 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9805926887377789, 'num_leaves': 31, 'subsample': 0.8316486612796965}. Best is trial 8 with value: 0.29074219790368894.
# [I 2024-04-18 13:51:31,599] Trial 15 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6125067788495915, 'num_leaves': 41, 'subsample': 0.5009638103681511}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:31,890] Trial 16 finished with value: 0.3064655866939506 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5990845477694657, 'num_leaves': 50, 'subsample': 0.4921896580222841}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:32,089] Trial 17 finished with value: 0.29281758169708105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.586385135872273, 'num_leaves': 40, 'subsample': 0.5734682847090226}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:32,384] Trial 18 finished with value: 0.2982338216967807 and parameters: {'max_depth': 4, 'colsample_bytree': 0.41844523013266666, 'num_leaves': 44, 'subsample': 0.4113177759386427}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:32,610] Trial 19 finished with value: 0.29356887704595014 and parameters: {'max_depth': 2, 'colsample_bytree': 0.662308375876488, 'num_leaves': 60, 'subsample': 0.7213803003102983}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:32,862] Trial 20 finished with value: 0.3159451266446346 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7779054741140509, 'num_leaves': 49, 'subsample': 0.5994699437624806}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:33,069] Trial 21 finished with value: 0.2939537633573278 and parameters: {'max_depth': 1, 'colsample_bytree': 0.557300429716856, 'num_leaves': 40, 'subsample': 0.546641654688521}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:33,283] Trial 22 finished with value: 0.29281758169708105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5625886333366346, 'num_leaves': 34, 'subsample': 0.4899966404474695}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:33,518] Trial 23 finished with value: 0.29356887704595014 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6437642899961199, 'num_leaves': 41, 'subsample': 0.507577926352516}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:33,749] Trial 24 finished with value: 0.2939537633573278 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5497820420647722, 'num_leaves': 48, 'subsample': 0.6850073842115403}. Best is trial 15 with value: 0.29054432537716135.
# [I 2024-04-18 13:51:33,984] Trial 25 finished with value: 0.29040540446754665 and parameters: {'max_depth': 2, 'colsample_bytree': 0.44587471557172687, 'num_leaves': 42, 'subsample': 0.6168503657829857}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:34,279] Trial 26 finished with value: 0.3058413359501414 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4467196381695471, 'num_leaves': 53, 'subsample': 0.6278489212754952}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:34,553] Trial 27 finished with value: 0.3028920681336184 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4552170647225562, 'num_leaves': 43, 'subsample': 0.4553794376663307}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:34,784] Trial 28 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5177476651733635, 'num_leaves': 52, 'subsample': 0.528721955424517}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:35,075] Trial 29 finished with value: 0.3058413359501414 and parameters: {'max_depth': 4, 'colsample_bytree': 0.46439509171725735, 'num_leaves': 45, 'subsample': 0.7268414706716145}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:35,311] Trial 30 finished with value: 0.29356887704595014 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6571913367877797, 'num_leaves': 56, 'subsample': 0.8177094237886633}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:35,521] Trial 31 finished with value: 0.29281758169708105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.580850608972556, 'num_leaves': 40, 'subsample': 0.5927504274199646}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:35,731] Trial 32 finished with value: 0.2939537633573278 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5212853610581827, 'num_leaves': 42, 'subsample': 0.6607626953216877}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:35,958] Trial 33 finished with value: 0.29074219790368894 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5398331519802324, 'num_leaves': 47, 'subsample': 0.5885510379082052}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:36,227] Trial 34 finished with value: 0.30787139861612633 and parameters: {'max_depth': 3, 'colsample_bytree': 0.521123185786078, 'num_leaves': 46, 'subsample': 0.4511108750293771}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:36,469] Trial 35 finished with value: 0.29054432537716135 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6342793596998431, 'num_leaves': 47, 'subsample': 0.6225903797667007}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:36,783] Trial 36 finished with value: 0.3142799833561709 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6250062627915018, 'num_leaves': 34, 'subsample': 0.7110822129444274}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:37,020] Trial 37 finished with value: 0.29287263369913735 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6781999111537266, 'num_leaves': 28, 'subsample': 0.7764079744923176}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:37,281] Trial 38 finished with value: 0.3037613378847738 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7937296662257073, 'num_leaves': 50, 'subsample': 0.637875405466378}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:37,516] Trial 39 finished with value: 0.29040540446754665 and parameters: {'max_depth': 2, 'colsample_bytree': 0.47686606603124426, 'num_leaves': 56, 'subsample': 0.7476050452728756}. Best is trial 25 with value: 0.29040540446754665.
# [I 2024-04-18 13:51:37,742] Trial 40 finished with value: 0.28728928289149736 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4053887004395072, 'num_leaves': 55, 'subsample': 0.9358062643900628}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:37,982] Trial 41 finished with value: 0.28728928289149736 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4127863057567331, 'num_leaves': 57, 'subsample': 0.9549625281295556}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:38,214] Trial 42 finished with value: 0.29067897317620467 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4003475939731444, 'num_leaves': 57, 'subsample': 0.9388445948304179}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:38,482] Trial 43 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4369712023455867, 'num_leaves': 60, 'subsample': 0.9363775363350435}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:38,833] Trial 44 finished with value: 0.313208149482114 and parameters: {'max_depth': 7, 'colsample_bytree': 0.48276591063665764, 'num_leaves': 54, 'subsample': 0.9396645564731632}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:39,055] Trial 45 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4879066560039854, 'num_leaves': 56, 'subsample': 0.8584678292731671}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:39,319] Trial 46 finished with value: 0.30310618358654784 and parameters: {'max_depth': 3, 'colsample_bytree': 0.44044694490043773, 'num_leaves': 58, 'subsample': 0.9253612119058754}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:39,634] Trial 47 finished with value: 0.31389006002574404 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4245397704286431, 'num_leaves': 52, 'subsample': 0.9927221474848589}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:39,848] Trial 48 finished with value: 0.293903455490301 and parameters: {'max_depth': 1, 'colsample_bytree': 0.46786525542224544, 'num_leaves': 55, 'subsample': 0.9625520759668925}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:40,089] Trial 49 finished with value: 0.2940571425557453 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5017485548202432, 'num_leaves': 59, 'subsample': 0.9019572408036095}. Best is trial 40 with value: 0.28728928289149736.
# [I 2024-04-18 13:51:40,113] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-18 13:51:40,437] Trial 0 finished with value: 0.3615990608667081 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8998057339491827, 'num_leaves': 54, 'subsample': 0.6250005145688924}. Best is trial 0 with value: 0.3615990608667081.
# [I 2024-04-18 13:51:40,776] Trial 1 finished with value: 0.36070102008635696 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8168822023644895, 'num_leaves': 47, 'subsample': 0.8932427919729824}. Best is trial 1 with value: 0.36070102008635696.
# [I 2024-04-18 13:51:41,114] Trial 2 finished with value: 0.37119262280461174 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6140762051549162, 'num_leaves': 35, 'subsample': 0.53987154135642}. Best is trial 1 with value: 0.36070102008635696.
# [I 2024-04-18 13:51:41,367] Trial 3 finished with value: 0.32460790118889843 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9095708703368699, 'num_leaves': 47, 'subsample': 0.8377420067670884}. Best is trial 3 with value: 0.32460790118889843.
# [I 2024-04-18 13:51:41,687] Trial 4 finished with value: 0.3717780637044955 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8030464769020922, 'num_leaves': 58, 'subsample': 0.5137634563924351}. Best is trial 3 with value: 0.32460790118889843.
# [I 2024-04-18 13:51:41,935] Trial 5 finished with value: 0.3169806235693687 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7843348817927713, 'num_leaves': 44, 'subsample': 0.9976404247976592}. Best is trial 5 with value: 0.3169806235693687.
# [I 2024-04-18 13:51:42,260] Trial 6 finished with value: 0.3355446826992854 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4573432671662443, 'num_leaves': 35, 'subsample': 0.5312329845121955}. Best is trial 5 with value: 0.3169806235693687.
# [I 2024-04-18 13:51:42,510] Trial 7 finished with value: 0.31395295148708446 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9431415208893954, 'num_leaves': 43, 'subsample': 0.7380900785105062}. Best is trial 7 with value: 0.31395295148708446.
# [I 2024-04-18 13:51:42,757] Trial 8 finished with value: 0.31395295148708446 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9563816662298535, 'num_leaves': 31, 'subsample': 0.5250217623963487}. Best is trial 7 with value: 0.31395295148708446.
# [I 2024-04-18 13:51:43,036] Trial 9 finished with value: 0.3291528470741418 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6717408337691951, 'num_leaves': 37, 'subsample': 0.627311575052406}. Best is trial 7 with value: 0.31395295148708446.
# [I 2024-04-18 13:51:43,239] Trial 10 finished with value: 0.2918452347380769 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5448989040316727, 'num_leaves': 25, 'subsample': 0.7778725995500817}. Best is trial 10 with value: 0.2918452347380769.
# [I 2024-04-18 13:51:43,452] Trial 11 finished with value: 0.29261129036898964 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5163267601196075, 'num_leaves': 29, 'subsample': 0.7692165134263855}. Best is trial 10 with value: 0.2918452347380769.
# [I 2024-04-18 13:51:43,662] Trial 12 finished with value: 0.29261129036898964 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5004070006192762, 'num_leaves': 25, 'subsample': 0.7724292600554564}. Best is trial 10 with value: 0.2918452347380769.
# [I 2024-04-18 13:51:43,878] Trial 13 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.565163515853029, 'num_leaves': 25, 'subsample': 0.8417942805367203}. Best is trial 10 with value: 0.2918452347380769.
# [I 2024-04-18 13:51:44,087] Trial 14 finished with value: 0.29110782771496346 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4198305963179953, 'num_leaves': 29, 'subsample': 0.6658019939133777}. Best is trial 14 with value: 0.29110782771496346.
# [I 2024-04-18 13:51:44,328] Trial 15 finished with value: 0.2867970025236389 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4287492073470552, 'num_leaves': 30, 'subsample': 0.4153085763626507}. Best is trial 15 with value: 0.2867970025236389.
# [I 2024-04-18 13:51:44,567] Trial 16 finished with value: 0.2877498435126473 and parameters: {'max_depth': 2, 'colsample_bytree': 0.40338977318019115, 'num_leaves': 39, 'subsample': 0.403557924474086}. Best is trial 15 with value: 0.2867970025236389.
# [I 2024-04-18 13:51:44,804] Trial 17 finished with value: 0.2867970025236389 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4137832976660339, 'num_leaves': 40, 'subsample': 0.40912511854416495}. Best is trial 15 with value: 0.2867970025236389.
# [I 2024-04-18 13:51:45,041] Trial 18 finished with value: 0.2895652742717456 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6281902133647703, 'num_leaves': 51, 'subsample': 0.4002935094340475}. Best is trial 15 with value: 0.2867970025236389.
# [I 2024-04-18 13:51:45,277] Trial 19 finished with value: 0.28106111370747944 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4789844861930831, 'num_leaves': 33, 'subsample': 0.45940121904953024}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:45,574] Trial 20 finished with value: 0.34226195528825837 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7185673694017374, 'num_leaves': 31, 'subsample': 0.46738943806947153}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:45,810] Trial 21 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.48258842751068615, 'num_leaves': 39, 'subsample': 0.44451998381487956}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:46,047] Trial 22 finished with value: 0.28106111370747944 and parameters: {'max_depth': 2, 'colsample_bytree': 0.47230891514482404, 'num_leaves': 33, 'subsample': 0.46893204438335856}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:46,283] Trial 23 finished with value: 0.28106111370747944 and parameters: {'max_depth': 2, 'colsample_bytree': 0.47779239669297546, 'num_leaves': 34, 'subsample': 0.47370079936386134}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:46,588] Trial 24 finished with value: 0.3323151452499057 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5780244773347807, 'num_leaves': 34, 'subsample': 0.47935099711015683}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:46,859] Trial 25 finished with value: 0.3103711784986798 and parameters: {'max_depth': 3, 'colsample_bytree': 0.472195450024263, 'num_leaves': 32, 'subsample': 0.602424916028992}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:47,090] Trial 26 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5274526922653859, 'num_leaves': 34, 'subsample': 0.5593870779513717}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:47,316] Trial 27 finished with value: 0.2895652742717456 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6172113051953841, 'num_leaves': 37, 'subsample': 0.579961226300045}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:47,609] Trial 28 finished with value: 0.3240924308865545 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4536819913748465, 'num_leaves': 27, 'subsample': 0.4840538050421826}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:47,865] Trial 29 finished with value: 0.3147551193969834 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7170160017449115, 'num_leaves': 41, 'subsample': 0.684190063296157}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:48,056] Trial 30 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5840458893030478, 'num_leaves': 33, 'subsample': 0.6057064942071708}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:48,289] Trial 31 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4849144958528101, 'num_leaves': 38, 'subsample': 0.4573104514004582}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:48,519] Trial 32 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.507131692420935, 'num_leaves': 36, 'subsample': 0.4462786292936725}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:48,869] Trial 33 finished with value: 0.3481484160380778 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4519910203515558, 'num_leaves': 41, 'subsample': 0.5001519458040694}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:49,126] Trial 34 finished with value: 0.3114048881714012 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5396151984532088, 'num_leaves': 46, 'subsample': 0.4399385672625957}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:49,471] Trial 35 finished with value: 0.36823016421930754 and parameters: {'max_depth': 6, 'colsample_bytree': 0.652161480694902, 'num_leaves': 28, 'subsample': 0.5419704339060458}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:49,702] Trial 36 finished with value: 0.28106111370747944 and parameters: {'max_depth': 2, 'colsample_bytree': 0.464658855180277, 'num_leaves': 33, 'subsample': 0.5005855432667923}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:49,971] Trial 37 finished with value: 0.3103711784986798 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4436732174815305, 'num_leaves': 33, 'subsample': 0.6417004923884582}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:50,173] Trial 38 finished with value: 0.29322229034241715 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8431981196140863, 'num_leaves': 54, 'subsample': 0.5052328101066446}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:50,406] Trial 39 finished with value: 0.2863627483368194 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5576778454701882, 'num_leaves': 35, 'subsample': 0.5481123184318883}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:50,674] Trial 40 finished with value: 0.3169806235693687 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7563590272653437, 'num_leaves': 27, 'subsample': 0.5774486293592316}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:51,028] Trial 41 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.48241043616673074, 'num_leaves': 36, 'subsample': 0.43290885538294843}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:51,279] Trial 42 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4888833937953665, 'num_leaves': 32, 'subsample': 0.5012646602672718}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:51,474] Trial 43 finished with value: 0.29276628526616894 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5877401123554158, 'num_leaves': 45, 'subsample': 0.983206845551112}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:51,803] Trial 44 finished with value: 0.3562970694757631 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5177210046308709, 'num_leaves': 38, 'subsample': 0.46265482974732186}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:52,075] Trial 45 finished with value: 0.3103711784986798 and parameters: {'max_depth': 3, 'colsample_bytree': 0.45737114533811457, 'num_leaves': 43, 'subsample': 0.5248711039041307}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:52,274] Trial 46 finished with value: 0.292079299028556 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4011998507345913, 'num_leaves': 60, 'subsample': 0.4317858059081255}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:52,590] Trial 47 finished with value: 0.3308358036061366 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4359534767199689, 'num_leaves': 31, 'subsample': 0.48504576378356024}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:52,849] Trial 48 finished with value: 0.3114048881714012 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5389858974217091, 'num_leaves': 35, 'subsample': 0.5139363507741559}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:53,078] Trial 49 finished with value: 0.28489412786464885 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5031728970524606, 'num_leaves': 40, 'subsample': 0.7338572515487749}. Best is trial 19 with value: 0.28106111370747944.
# [I 2024-04-18 13:51:53,102] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-18 13:51:53,300] Trial 0 finished with value: 0.29840108338741267 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8998345401209946, 'num_leaves': 52, 'subsample': 0.99802035457666}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:53,490] Trial 1 finished with value: 0.29947244629708547 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9578593657806652, 'num_leaves': 36, 'subsample': 0.49698567020530016}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:53,822] Trial 2 finished with value: 0.3896788318262844 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7122632037035506, 'num_leaves': 60, 'subsample': 0.5671877610459922}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:54,036] Trial 3 finished with value: 0.3195657558922965 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8441406702238838, 'num_leaves': 27, 'subsample': 0.9479825717371462}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:54,284] Trial 4 finished with value: 0.333551492176254 and parameters: {'max_depth': 3, 'colsample_bytree': 0.47683587766369384, 'num_leaves': 42, 'subsample': 0.5024867819271642}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:54,614] Trial 5 finished with value: 0.39208003255494794 and parameters: {'max_depth': 6, 'colsample_bytree': 0.7519080026550449, 'num_leaves': 39, 'subsample': 0.88879248833073}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:54,826] Trial 6 finished with value: 0.30956175551925 and parameters: {'max_depth': 2, 'colsample_bytree': 0.46604241786396333, 'num_leaves': 51, 'subsample': 0.6564778035998104}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:55,050] Trial 7 finished with value: 0.32010575210447 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9623475716135701, 'num_leaves': 41, 'subsample': 0.48524915248963535}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:55,388] Trial 8 finished with value: 0.3913610662138993 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5297563578205853, 'num_leaves': 26, 'subsample': 0.7632503757072966}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:55,717] Trial 9 finished with value: 0.37755060801154905 and parameters: {'max_depth': 7, 'colsample_bytree': 0.4642484656112684, 'num_leaves': 46, 'subsample': 0.6223830880396756}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:55,992] Trial 10 finished with value: 0.3665840310394677 and parameters: {'max_depth': 4, 'colsample_bytree': 0.837644568247041, 'num_leaves': 57, 'subsample': 0.79245082317923}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:56,188] Trial 11 finished with value: 0.29881808476044885 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9972785493288105, 'num_leaves': 32, 'subsample': 0.4076159815897111}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:56,388] Trial 12 finished with value: 0.29860935829621327 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8647651727343042, 'num_leaves': 32, 'subsample': 0.4058070382719602}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:56,672] Trial 13 finished with value: 0.3665840310394677 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8625996572288537, 'num_leaves': 49, 'subsample': 0.991360327907174}. Best is trial 0 with value: 0.29840108338741267.
# [I 2024-04-18 13:51:56,878] Trial 14 finished with value: 0.29826400128009606 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6188690865521828, 'num_leaves': 53, 'subsample': 0.8483920968109119}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:57,155] Trial 15 finished with value: 0.34286915427476516 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6056128016888879, 'num_leaves': 54, 'subsample': 0.8648335894102384}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:57,419] Trial 16 finished with value: 0.34286915427476516 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6169429662196347, 'num_leaves': 48, 'subsample': 0.8691144182172071}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:57,629] Trial 17 finished with value: 0.29826400128009606 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6206361512996058, 'num_leaves': 54, 'subsample': 0.7712461130944305}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:57,863] Trial 18 finished with value: 0.3169279354258547 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6214069437738536, 'num_leaves': 56, 'subsample': 0.75918605947639}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:58,165] Trial 19 finished with value: 0.36342843586432577 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5753462568205466, 'num_leaves': 60, 'subsample': 0.7002960381585865}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:58,484] Trial 20 finished with value: 0.3704920277369418 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6791352201083576, 'num_leaves': 45, 'subsample': 0.7987482102574373}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:58,689] Trial 21 finished with value: 0.298769400255129 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7532672219851201, 'num_leaves': 53, 'subsample': 0.9351254581948621}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:58,898] Trial 22 finished with value: 0.2988414659094317 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6844488009026672, 'num_leaves': 51, 'subsample': 0.828528973099672}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:59,125] Trial 23 finished with value: 0.3017035323445973 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5302499102557343, 'num_leaves': 56, 'subsample': 0.9974105430024228}. Best is trial 14 with value: 0.29826400128009606.
# [I 2024-04-18 13:51:59,340] Trial 24 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7901383692075808, 'num_leaves': 52, 'subsample': 0.7221675124945336}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:51:59,566] Trial 25 finished with value: 0.32306758680035746 and parameters: {'max_depth': 2, 'colsample_bytree': 0.778290673099842, 'num_leaves': 45, 'subsample': 0.7111776074456232}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:51:59,826] Trial 26 finished with value: 0.33964601919987153 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6546953533748375, 'num_leaves': 48, 'subsample': 0.7341382152515019}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:00,038] Trial 27 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7965412923534089, 'num_leaves': 55, 'subsample': 0.6585136423278899}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:00,252] Trial 28 finished with value: 0.3214505378954481 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7914391067307718, 'num_leaves': 59, 'subsample': 0.6547374919016321}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:00,456] Trial 29 finished with value: 0.29912145562336256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9182148033941413, 'num_leaves': 50, 'subsample': 0.5840566433848637}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:00,716] Trial 30 finished with value: 0.3464322443656972 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7350569883782858, 'num_leaves': 53, 'subsample': 0.6594704692382083}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:00,918] Trial 31 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7954374074088254, 'num_leaves': 56, 'subsample': 0.8323031585018622}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:01,117] Trial 32 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8013702873154461, 'num_leaves': 57, 'subsample': 0.827317179086904}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:01,319] Trial 33 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8033877119690005, 'num_leaves': 58, 'subsample': 0.9073081815938759}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:01,527] Trial 34 finished with value: 0.29840108338741267 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8987303260961415, 'num_leaves': 56, 'subsample': 0.8209934740632782}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:01,748] Trial 35 finished with value: 0.3214505378954481 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8259995912363042, 'num_leaves': 55, 'subsample': 0.5977355630475714}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:01,978] Trial 36 finished with value: 0.3199502544425482 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7198331023550821, 'num_leaves': 58, 'subsample': 0.727124280107174}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:02,315] Trial 37 finished with value: 0.3815157342135141 and parameters: {'max_depth': 5, 'colsample_bytree': 0.892936581481829, 'num_leaves': 60, 'subsample': 0.5599974199264244}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:02,542] Trial 38 finished with value: 0.32306758680035746 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7687049490745794, 'num_leaves': 51, 'subsample': 0.6631186502563711}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:02,747] Trial 39 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8046011221954604, 'num_leaves': 38, 'subsample': 0.9121485451908977}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:02,947] Trial 40 finished with value: 0.29912145562336256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9330858039273486, 'num_leaves': 57, 'subsample': 0.6886680176730967}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:03,148] Trial 41 finished with value: 0.297940831222988 and parameters: {'max_depth': 1, 'colsample_bytree': 0.800565726245544, 'num_leaves': 58, 'subsample': 0.8896861419971532}. Best is trial 24 with value: 0.297940831222988.
# [I 2024-04-18 13:52:03,347] Trial 42 finished with value: 0.29729447932277886 and parameters: {'max_depth': 1, 'colsample_bytree': 0.40181715187804806, 'num_leaves': 58, 'subsample': 0.9670110531111736}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:03,579] Trial 43 finished with value: 0.31021598633873304 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4095755388979914, 'num_leaves': 55, 'subsample': 0.951526822836091}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:03,781] Trial 44 finished with value: 0.29860935829621327 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8322335295041903, 'num_leaves': 60, 'subsample': 0.6155873619327138}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:04,150] Trial 45 finished with value: 0.3946711600087949 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8680771525681918, 'num_leaves': 52, 'subsample': 0.7965419203216404}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:04,351] Trial 46 finished with value: 0.29952678421646073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7171235411865566, 'num_leaves': 57, 'subsample': 0.5412635788378906}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:04,568] Trial 47 finished with value: 0.32306758680035746 and parameters: {'max_depth': 2, 'colsample_bytree': 0.767554664531942, 'num_leaves': 55, 'subsample': 0.7397065554593563}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:04,773] Trial 48 finished with value: 0.29952678421646073 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7411392052696377, 'num_leaves': 43, 'subsample': 0.9642754862197662}. Best is trial 42 with value: 0.29729447932277886.
# [I 2024-04-18 13:52:05,003] Trial 49 finished with value: 0.3214505378954481 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8205200789957022, 'num_leaves': 30, 'subsample': 0.8391559313069602}. Best is trial 42 with value: 0.29729447932277886.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None



for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            # r = Result(y_val, y_proba, optimize=False)
            r = Result(y_val, y_proba, optimize=True)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["th"].append(r.th)
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=a["th"][0], color='r', linestyle='--')
    axs[1].axvline(x=a["th"][0], color='r', linestyle='--')

# Remove space between subplots
    plt.subplots_adjust(hspace=0)

# Show the plot
    plt.show()
# Out:
# acc     :0.880830001903674
# f1      :0.8650445479379942
# th      :0.5
# logloss :0.28728928289149736
# max size0_midPoint            :62.25
# Lat0_Top                      :20.25
# Habitat0_Average              :18.0
# NDepth_Bottom                 :17.0
# Behavior0_Average             :16.0
# Lon0_Top                      :15.75
# Habitat0_Top                  :13.75
# Behavior0_Bottom              :12.0
# DDepth_Bottom                 :11.0
# DDepth_midPoint               :10.25
# Lat0_Bottom                   :10.25
# DDepth_Top                    :9.75
# NDepth_midPoint               :7.5
# Lon0_Bottom                   :7.5
# Associate0_Bottom             :7.0
# Associate0_Top                :7.0
# Associate0_Average            :6.25
# NDepth_Top                    :4.5
# Behavior0_Top                 :4.25
# Habitat0_Bottom               :3.5
# TemperatureT0_Average         :3.0
# TemperatureT0_Top             :2.5
# TemperatureT0_Bottom          :2.25
# Salinity0_Bottom              :1.5
# Salinity0_Average             :0.5
# Salinity0_Top                 :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8808062059775367
# f1      :0.8029075367056924
# th      :0.503125
# logloss :0.28106111370747944
# max size0_midPoint            :41.75
# DDepth_midPoint               :23.5
# Lon0_Top                      :22.25
# TemperatureT0_Average         :21.25
# NDepth_midPoint               :19.0
# Lat0_Bottom                   :19.0
# Lat0_Top                      :18.25
# Habitat0_Average              :18.0
# Habitat0_Bottom               :12.25
# Lon0_Bottom                   :11.75
# DDepth_Bottom                 :9.75
# Associate0_Average            :9.25
# Associate_Floating object     :9.0
# Behavior0_Average             :8.25
# TemperatureT0_Bottom          :7.25
# DDepth_Top                    :6.75
# Behavior0_Bottom              :6.75
# NDepth_Bottom                 :5.75
# Associate0_Top                :4.5
# Associate0_Bottom             :3.5
# Behavior0_Top                 :2.75
# Habitat0_Top                  :2.25
# TemperatureT0_Top             :1.75
# Salinity0_Average             :1.0
# NDepth_Top                    :0.75
# Salinity0_Bottom              :0.0
# Salinity0_Top                 :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8832095945174187
# f1      :0.6765414963499985
# th      :0.49687499999999996
# logloss :0.29729447932277886
# max size0_midPoint            :21.5
# Lon0_Bottom                   :11.5
# DDepth_midPoint               :6.75
# NDepth_midPoint               :6.75
# Lat0_Bottom                   :6.75
# Habitat0_Bottom               :6.5
# Habitat0_Top                  :5.5
# Habitat0_Average              :4.5
# Salinity0_Bottom              :4.25
# Salinity0_Average             :4.25
# DDepth_Bottom                 :4.0
# NDepth_Bottom                 :3.5
# Lat0_Top                      :3.0
# DDepth_Top                    :2.25
# TemperatureT0_Bottom          :2.25
# Associate0_Bottom             :2.0
# TemperatureT0_Average         :1.75
# Behavior0_Average             :1.25
# Associate0_Top                :0.75
# TemperatureT0_Top             :0.5
# Lon0_Top                      :0.25
# Associate_Floating object     :0.25
# NDepth_Top                    :0.0
# Behavior0_Bottom              :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# Associate0_Average            :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")
