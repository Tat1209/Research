# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level8_ml/Test_dat2_v3.csv")

df = pl.read_csv(path_total, infer_schema_length=1000)
# display(df)

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
x = df.select(df.columns[:-4])
x = x.select(~ pl.selectors.ends_with("records"))
x = x.select(~ pl.selectors.ends_with("ID"))
x = x.select(~ pl.selectors.ends_with("Scientific name"))
x = x.select(~ pl.selectors.contains("max size"))
# nullがk行を以下のカラムのみ採用
# x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100])
x = x.select([col_name for col_name in x.columns if df[col_name].null_count() <=100 or "associate" in col_name.lower()])
# associateで一部要素を除外
x = x.select(~ pl.selectors.contains("Lon"))
x = x.select(~ pl.selectors.ends_with("Associate0_Bottom"))
x = x.select(~ pl.selectors.ends_with("Associate0_Top"))

# どっちか除外
# x = x.select(~ pl.selectors.ends_with("Associate0_Average"))

# x = x.select(~ pl.selectors.ends_with("Associate_Floating object"))
# x = x.select(~ pl.selectors.ends_with("Associate_Large pelagics"))

# df = df.select([col_name for col_name in df.columns if df[col_name].null_count() <= 100 or (df.get_column_index(col_name) - df.width) >= -4])


ys = df.select(df.columns[-3:])

# # BlankをNに置き換え
# ys = ys.with_columns(
#     pl.when(pl.all().is_null())
#     .then(pl.lit("N"))
#     .otherwise(pl.all())
#     .name.keep()
# )

# NとYを0, 1に置き換え
ys = ys.with_columns(
    pl.when(pl.all() == "N")
    .then(pl.lit(2))
    .when(pl.all() == "Y")
    .then(pl.lit(1))
    .otherwise(pl.lit(0))
    .name.keep()
)

# display(x)
# display(ys)

# display(x.columns)
# display(ys.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba, optimize=False):
        self.val = val
        self.proba = proba

        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            self.pred = self.proba[:, 1] >= threshold
            self.th = threshold
        else:
            self.pred = proba.argmax(axis=1)
            self.th = 0.5

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y in enumerate(ys):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }

        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
                x_train, x_val = x[train_indices], x[val_indices]
                y_train, y_val = y[train_indices], y[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train, y_train)

                y_proba = model.predict_proba(x_val)

                r = Result(y_val, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        # print(a["logloss"][0])
        # print(a["cm"][0])

        # return a["f1"][0]
        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-04-18 14:23:07,454] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-04-18 14:23:07,669] Trial 0 finished with value: 0.4962380886802143 and parameters: {'max_depth': 2, 'colsample_bytree': 0.573699929354427, 'num_leaves': 35, 'subsample': 0.678366297472746}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:07,926] Trial 1 finished with value: 0.5724022460983907 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9957171979076247, 'num_leaves': 42, 'subsample': 0.9315492796121089}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:08,129] Trial 2 finished with value: 0.5061064549721408 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8361831000723485, 'num_leaves': 52, 'subsample': 0.8393164421695652}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:08,440] Trial 3 finished with value: 0.5981381879998462 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8914424918788131, 'num_leaves': 58, 'subsample': 0.809089622186226}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:08,712] Trial 4 finished with value: 0.5447545402740297 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5436088821891664, 'num_leaves': 29, 'subsample': 0.5566876136373077}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:09,035] Trial 5 finished with value: 0.6089680448113531 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7420467380050882, 'num_leaves': 52, 'subsample': 0.6843582723532153}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:09,261] Trial 6 finished with value: 0.49711587994126033 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5389893555259062, 'num_leaves': 26, 'subsample': 0.5304976278914706}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:09,579] Trial 7 finished with value: 0.6055878288321268 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7731048379972738, 'num_leaves': 44, 'subsample': 0.9300495658127966}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:09,770] Trial 8 finished with value: 0.5048881138895911 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8116305453744828, 'num_leaves': 29, 'subsample': 0.5288646712222715}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:10,019] Trial 9 finished with value: 0.5285675872215135 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9191378582553218, 'num_leaves': 36, 'subsample': 0.5806940902848278}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:10,221] Trial 10 finished with value: 0.505069183397742 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4079836856262574, 'num_leaves': 36, 'subsample': 0.4000949750596025}. Best is trial 0 with value: 0.4962380886802143.
# [I 2024-04-18 14:23:10,435] Trial 11 finished with value: 0.49559460541197853 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5969746474038334, 'num_leaves': 25, 'subsample': 0.6758008328826661}. Best is trial 11 with value: 0.49559460541197853.
# [I 2024-04-18 14:23:10,678] Trial 12 finished with value: 0.5261019163153193 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6257006808589267, 'num_leaves': 35, 'subsample': 0.6874288588831162}. Best is trial 11 with value: 0.49559460541197853.
# [I 2024-04-18 14:23:10,895] Trial 13 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6426840760324269, 'num_leaves': 25, 'subsample': 0.777623054350384}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:11,194] Trial 14 finished with value: 0.5801448475575719 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6760318252929404, 'num_leaves': 25, 'subsample': 0.7948461984510381}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:11,457] Trial 15 finished with value: 0.5215101571563064 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4556040379344859, 'num_leaves': 31, 'subsample': 0.7856119905609625}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:11,658] Trial 16 finished with value: 0.5044244615053605 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6775597336292142, 'num_leaves': 41, 'subsample': 0.6267219167970088}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:11,884] Trial 17 finished with value: 0.49651930489729357 and parameters: {'max_depth': 2, 'colsample_bytree': 0.47982994682923447, 'num_leaves': 25, 'subsample': 0.7460685581886034}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:12,193] Trial 18 finished with value: 0.5886982902873752 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6337978882557571, 'num_leaves': 31, 'subsample': 0.8844683650495324}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:12,449] Trial 19 finished with value: 0.5261019163153193 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6127057577126231, 'num_leaves': 50, 'subsample': 0.9971819902575919}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:12,660] Trial 20 finished with value: 0.5038171666902653 and parameters: {'max_depth': 1, 'colsample_bytree': 0.494356477636847, 'num_leaves': 31, 'subsample': 0.4517939585771259}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:12,882] Trial 21 finished with value: 0.4962380886802143 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5775916324420182, 'num_leaves': 34, 'subsample': 0.6375253364474401}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:13,122] Trial 22 finished with value: 0.4971186722963032 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7172990864807082, 'num_leaves': 39, 'subsample': 0.7314883061440611}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:13,383] Trial 23 finished with value: 0.5321625001078543 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5786203939830084, 'num_leaves': 28, 'subsample': 0.6436980946676678}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:13,611] Trial 24 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6590618761098881, 'num_leaves': 47, 'subsample': 0.7366183596618792}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:13,895] Trial 25 finished with value: 0.5619157465368386 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6711745127291389, 'num_leaves': 48, 'subsample': 0.7410749752052611}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:14,086] Trial 26 finished with value: 0.5044381362211121 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7577120886387224, 'num_leaves': 46, 'subsample': 0.8434710157465873}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:14,317] Trial 27 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.639823888076438, 'num_leaves': 40, 'subsample': 0.7338579111359298}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:14,619] Trial 28 finished with value: 0.5801448475575719 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7063756767573635, 'num_leaves': 57, 'subsample': 0.7651003805317074}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:14,844] Trial 29 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.646655740958676, 'num_leaves': 39, 'subsample': 0.7166765983565639}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:15,099] Trial 30 finished with value: 0.5227985200411406 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5275274108850616, 'num_leaves': 54, 'subsample': 0.8479391555842849}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:15,326] Trial 31 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6513009113649897, 'num_leaves': 38, 'subsample': 0.7108403723514669}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:15,524] Trial 32 finished with value: 0.5044244615053605 and parameters: {'max_depth': 1, 'colsample_bytree': 0.716385924228237, 'num_leaves': 44, 'subsample': 0.7613192206579875}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:15,753] Trial 33 finished with value: 0.49246940061022704 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6535029056266191, 'num_leaves': 40, 'subsample': 0.7138944572262271}. Best is trial 13 with value: 0.49246940061022704.
# [I 2024-04-18 14:23:15,979] Trial 34 finished with value: 0.49074250686230425 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7914223993117623, 'num_leaves': 47, 'subsample': 0.8099024221818802}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:16,261] Trial 35 finished with value: 0.5616246254380558 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8122100428941275, 'num_leaves': 47, 'subsample': 0.8926494095418546}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:16,512] Trial 36 finished with value: 0.5312661753617441 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8669860741457913, 'num_leaves': 50, 'subsample': 0.8170837429438172}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:16,784] Trial 37 finished with value: 0.5657634794635013 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9385239833816812, 'num_leaves': 43, 'subsample': 0.8776467811878994}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:17,011] Trial 38 finished with value: 0.49074250686230425 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7837244559218218, 'num_leaves': 54, 'subsample': 0.8210186586785335}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:17,221] Trial 39 finished with value: 0.5055004334236124 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7903738982292626, 'num_leaves': 60, 'subsample': 0.9448074375270921}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:17,449] Trial 40 finished with value: 0.4930058242666594 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8705331440427375, 'num_leaves': 53, 'subsample': 0.811197032423841}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:17,690] Trial 41 finished with value: 0.4969517529466807 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7389653036109123, 'num_leaves': 50, 'subsample': 0.772370347925995}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:17,909] Trial 42 finished with value: 0.5061064549721408 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8383638223026263, 'num_leaves': 57, 'subsample': 0.8258396759026733}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:18,161] Trial 43 finished with value: 0.536634000711613 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7763462922343314, 'num_leaves': 45, 'subsample': 0.8481759142376215}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:18,367] Trial 44 finished with value: 0.5044244615053605 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6989718465647954, 'num_leaves': 48, 'subsample': 0.7865396967772001}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:18,617] Trial 45 finished with value: 0.535733660468544 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7451237321725609, 'num_leaves': 42, 'subsample': 0.6652400013298227}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:18,819] Trial 46 finished with value: 0.5026485473864748 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5540628980265998, 'num_leaves': 55, 'subsample': 0.9082469674474258}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:19,040] Trial 47 finished with value: 0.49559460541197853 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6040574493578008, 'num_leaves': 51, 'subsample': 0.589481664502487}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:19,268] Trial 48 finished with value: 0.49574565990405733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9475047095230242, 'num_leaves': 33, 'subsample': 0.8633229997398372}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:19,535] Trial 49 finished with value: 0.5297541688148812 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8107232024264452, 'num_leaves': 55, 'subsample': 0.8030755768097241}. Best is trial 34 with value: 0.49074250686230425.
# [I 2024-04-18 14:23:19,559] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-04-18 14:23:19,884] Trial 0 finished with value: 0.34508835115449893 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8970333101543242, 'num_leaves': 46, 'subsample': 0.8499281787977941}. Best is trial 0 with value: 0.34508835115449893.
# [I 2024-04-18 14:23:20,210] Trial 1 finished with value: 0.3461397805229855 and parameters: {'max_depth': 6, 'colsample_bytree': 0.8383905037140371, 'num_leaves': 29, 'subsample': 0.8187442873623236}. Best is trial 0 with value: 0.34508835115449893.
# [I 2024-04-18 14:23:20,428] Trial 2 finished with value: 0.3059576862169528 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6615254518535124, 'num_leaves': 34, 'subsample': 0.5323998808541327}. Best is trial 2 with value: 0.3059576862169528.
# [I 2024-04-18 14:23:20,755] Trial 3 finished with value: 0.3647295381138655 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5107848555049462, 'num_leaves': 51, 'subsample': 0.4460478309798667}. Best is trial 2 with value: 0.3059576862169528.
# [I 2024-04-18 14:23:21,082] Trial 4 finished with value: 0.3597489839292809 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5871576300580107, 'num_leaves': 45, 'subsample': 0.7252037168431542}. Best is trial 2 with value: 0.3059576862169528.
# [I 2024-04-18 14:23:21,416] Trial 5 finished with value: 0.35349479856928145 and parameters: {'max_depth': 6, 'colsample_bytree': 0.5793125399683778, 'num_leaves': 38, 'subsample': 0.7805903592599686}. Best is trial 2 with value: 0.3059576862169528.
# [I 2024-04-18 14:23:21,638] Trial 6 finished with value: 0.29728283709777503 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4705606867475869, 'num_leaves': 32, 'subsample': 0.7545301201953901}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:21,833] Trial 7 finished with value: 0.30986860346237055 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4901748658509371, 'num_leaves': 48, 'subsample': 0.7780516919401215}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:22,141] Trial 8 finished with value: 0.34545890550113917 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7796893995853857, 'num_leaves': 56, 'subsample': 0.7994778085747791}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:22,493] Trial 9 finished with value: 0.3686064158237747 and parameters: {'max_depth': 7, 'colsample_bytree': 0.9233138221341808, 'num_leaves': 30, 'subsample': 0.475362104589523}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:22,768] Trial 10 finished with value: 0.3134452192373593 and parameters: {'max_depth': 3, 'colsample_bytree': 0.43662119983461045, 'num_leaves': 26, 'subsample': 0.9772356596167665}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:22,994] Trial 11 finished with value: 0.3059576862169528 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6716786307678057, 'num_leaves': 37, 'subsample': 0.5980459720157513}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:23,254] Trial 12 finished with value: 0.3178549678931938 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7093676497959839, 'num_leaves': 36, 'subsample': 0.6061600636859452}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:23,460] Trial 13 finished with value: 0.3108350754890119 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4034347418480176, 'num_leaves': 32, 'subsample': 0.5824271453831255}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:23,724] Trial 14 finished with value: 0.31441486051374 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6525305841433299, 'num_leaves': 41, 'subsample': 0.5336854119626808}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:23,953] Trial 15 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7579815200470951, 'num_leaves': 25, 'subsample': 0.6679520427115946}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:24,168] Trial 16 finished with value: 0.3111679217730206 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7837773158889579, 'num_leaves': 25, 'subsample': 0.6732373049441235}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:24,467] Trial 17 finished with value: 0.33221280219844856 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9652497845209909, 'num_leaves': 28, 'subsample': 0.9264554160998706}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:24,670] Trial 18 finished with value: 0.310626314108018 and parameters: {'max_depth': 1, 'colsample_bytree': 0.751376439773695, 'num_leaves': 60, 'subsample': 0.6702818309308011}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:24,951] Trial 19 finished with value: 0.3271130211468677 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6031451222121565, 'num_leaves': 41, 'subsample': 0.7124423140503642}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:25,176] Trial 20 finished with value: 0.3084130848533065 and parameters: {'max_depth': 2, 'colsample_bytree': 0.838289457603713, 'num_leaves': 33, 'subsample': 0.9038590907550385}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:25,397] Trial 21 finished with value: 0.3044934042302252 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5032657660304654, 'num_leaves': 33, 'subsample': 0.5168231224737538}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:25,660] Trial 22 finished with value: 0.32180470042077475 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5029196470038791, 'num_leaves': 25, 'subsample': 0.6426331220426357}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:25,894] Trial 23 finished with value: 0.29728283709777503 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4770068365193708, 'num_leaves': 31, 'subsample': 0.40490168456434866}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:26,099] Trial 24 finished with value: 0.30987333933444555 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4506510061102966, 'num_leaves': 29, 'subsample': 0.4053654503247276}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:26,364] Trial 25 finished with value: 0.3125079634020902 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5500591932781038, 'num_leaves': 28, 'subsample': 0.7479581201600074}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:26,591] Trial 26 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7275658476810843, 'num_leaves': 31, 'subsample': 0.8729891931581633}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:26,887] Trial 27 finished with value: 0.3271130211468677 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6257179909303137, 'num_leaves': 39, 'subsample': 0.4025877207783981}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:27,091] Trial 28 finished with value: 0.30987333933444555 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4426367140663422, 'num_leaves': 35, 'subsample': 0.634248835645439}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:27,387] Trial 29 finished with value: 0.3344081302056623 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8729250804696085, 'num_leaves': 27, 'subsample': 0.8461280525831854}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:27,613] Trial 30 finished with value: 0.3045606891881843 and parameters: {'max_depth': 2, 'colsample_bytree': 0.558553722573194, 'num_leaves': 31, 'subsample': 0.560214512564582}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:27,845] Trial 31 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7291304903633802, 'num_leaves': 31, 'subsample': 0.8876879460127757}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:28,115] Trial 32 finished with value: 0.31935766609545835 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8014743527205549, 'num_leaves': 30, 'subsample': 0.9804997297346264}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:28,341] Trial 33 finished with value: 0.309215335815063 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6948929305780138, 'num_leaves': 35, 'subsample': 0.831896144256854}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:28,543] Trial 34 finished with value: 0.310626314108018 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7516684818128946, 'num_leaves': 27, 'subsample': 0.8789526225407951}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:28,773] Trial 35 finished with value: 0.3064316068645233 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8513391782501711, 'num_leaves': 44, 'subsample': 0.9402380948069928}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:29,029] Trial 36 finished with value: 0.32024530457725636 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8128843076996729, 'num_leaves': 33, 'subsample': 0.7543059426339447}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:29,346] Trial 37 finished with value: 0.34431722393255765 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5331488538854618, 'num_leaves': 29, 'subsample': 0.6867159922681794}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:29,552] Trial 38 finished with value: 0.3105619998849945 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6325086411116113, 'num_leaves': 40, 'subsample': 0.8120052597899827}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:29,784] Trial 39 finished with value: 0.309215335815063 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6874620269431192, 'num_leaves': 48, 'subsample': 0.47792663750715025}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:30,055] Trial 40 finished with value: 0.3179317239880737 and parameters: {'max_depth': 3, 'colsample_bytree': 0.47077568801889386, 'num_leaves': 25, 'subsample': 0.8634196031311805}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:30,287] Trial 41 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7196591658960447, 'num_leaves': 31, 'subsample': 0.8889784582861053}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:30,514] Trial 42 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7228776226638308, 'num_leaves': 37, 'subsample': 0.7834445736246403}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:30,746] Trial 43 finished with value: 0.30224867230829733 and parameters: {'max_depth': 2, 'colsample_bytree': 0.747198266827795, 'num_leaves': 31, 'subsample': 0.9473562351498106}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:30,956] Trial 44 finished with value: 0.31131244174712563 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7686420731669477, 'num_leaves': 34, 'subsample': 0.7536789752425743}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:31,220] Trial 45 finished with value: 0.31441486051374 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6606974001248956, 'num_leaves': 27, 'subsample': 0.9950451858172127}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:31,431] Trial 46 finished with value: 0.3110127680699706 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9149107757397273, 'num_leaves': 53, 'subsample': 0.9133392869533675}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:31,657] Trial 47 finished with value: 0.3084130848533065 and parameters: {'max_depth': 2, 'colsample_bytree': 0.81541875220409, 'num_leaves': 37, 'subsample': 0.8241058047824541}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:32,013] Trial 48 finished with value: 0.3603879781714322 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7297428303945647, 'num_leaves': 29, 'subsample': 0.4464762815268577}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:32,283] Trial 49 finished with value: 0.3243862549679506 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4052395795560615, 'num_leaves': 31, 'subsample': 0.9575943139141713}. Best is trial 6 with value: 0.29728283709777503.
# [I 2024-04-18 14:23:32,304] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-04-18 14:23:32,553] Trial 0 finished with value: 0.36287419065510523 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6431472584826243, 'num_leaves': 28, 'subsample': 0.9489965125549656}. Best is trial 0 with value: 0.36287419065510523.
# [I 2024-04-18 14:23:32,874] Trial 1 finished with value: 0.44936848037512966 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9524919357427488, 'num_leaves': 51, 'subsample': 0.550257162472467}. Best is trial 0 with value: 0.36287419065510523.
# [I 2024-04-18 14:23:33,095] Trial 2 finished with value: 0.33803498923452785 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6369218515120263, 'num_leaves': 44, 'subsample': 0.5903021013711265}. Best is trial 2 with value: 0.33803498923452785.
# [I 2024-04-18 14:23:33,394] Trial 3 finished with value: 0.4339889523557174 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6579584861146288, 'num_leaves': 39, 'subsample': 0.9058947880940079}. Best is trial 2 with value: 0.33803498923452785.
# [I 2024-04-18 14:23:33,580] Trial 4 finished with value: 0.31080365165669105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7983241489075359, 'num_leaves': 55, 'subsample': 0.5123388456524989}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:33,795] Trial 5 finished with value: 0.338966501621977 and parameters: {'max_depth': 2, 'colsample_bytree': 0.4375687321782808, 'num_leaves': 45, 'subsample': 0.5987880498658561}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:34,114] Trial 6 finished with value: 0.4534106031865944 and parameters: {'max_depth': 7, 'colsample_bytree': 0.8460444087885912, 'num_leaves': 54, 'subsample': 0.5037149493858255}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:34,363] Trial 7 finished with value: 0.38282833976580977 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9368711182336863, 'num_leaves': 31, 'subsample': 0.8343801536532154}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:34,700] Trial 8 finished with value: 0.46253909335111393 and parameters: {'max_depth': 7, 'colsample_bytree': 0.7959911120464318, 'num_leaves': 38, 'subsample': 0.4838502307102549}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:35,005] Trial 9 finished with value: 0.41394106371833445 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5741180241499653, 'num_leaves': 52, 'subsample': 0.8906008756878296}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:35,203] Trial 10 finished with value: 0.31080365165669105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7845312460405106, 'num_leaves': 60, 'subsample': 0.40920820449317524}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:35,404] Trial 11 finished with value: 0.31080365165669105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7714523234792361, 'num_leaves': 60, 'subsample': 0.4045338287649285}. Best is trial 4 with value: 0.31080365165669105.
# [I 2024-04-18 14:23:35,603] Trial 12 finished with value: 0.31062360682778256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8622165378981776, 'num_leaves': 59, 'subsample': 0.7211477366572745}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:35,810] Trial 13 finished with value: 0.31062360682778256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8756375365094425, 'num_leaves': 56, 'subsample': 0.7135010328208092}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:36,073] Trial 14 finished with value: 0.36595247474770826 and parameters: {'max_depth': 3, 'colsample_bytree': 0.890278229151724, 'num_leaves': 49, 'subsample': 0.7344610594019285}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:36,299] Trial 15 finished with value: 0.34843610943576087 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9692308643107037, 'num_leaves': 57, 'subsample': 0.6801991198011166}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:36,590] Trial 16 finished with value: 0.4148051073498907 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8869145646163312, 'num_leaves': 48, 'subsample': 0.7241724239426037}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:36,785] Trial 17 finished with value: 0.3112990237354229 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9908391112685635, 'num_leaves': 60, 'subsample': 0.7971099990635685}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:37,016] Trial 18 finished with value: 0.3426929971878917 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7385193366410927, 'num_leaves': 39, 'subsample': 0.6248737448576576}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:37,303] Trial 19 finished with value: 0.4148051073498907 and parameters: {'max_depth': 4, 'colsample_bytree': 0.8593299101050089, 'num_leaves': 57, 'subsample': 0.7856163406131087}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:37,584] Trial 20 finished with value: 0.40289629838104457 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5444622693997726, 'num_leaves': 47, 'subsample': 0.6498377844960118}. Best is trial 12 with value: 0.31062360682778256.
# [I 2024-04-18 14:23:37,788] Trial 21 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.827341136401156, 'num_leaves': 53, 'subsample': 0.7379410528480331}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:37,994] Trial 22 finished with value: 0.31084409618338826 and parameters: {'max_depth': 1, 'colsample_bytree': 0.719974905970114, 'num_leaves': 54, 'subsample': 0.7566528117336628}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:38,228] Trial 23 finished with value: 0.3412037220484053 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9081368721497975, 'num_leaves': 57, 'subsample': 0.6833426999760084}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:38,449] Trial 24 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8334590771192281, 'num_leaves': 51, 'subsample': 0.8491160374403462}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:38,705] Trial 25 finished with value: 0.36946627593229886 and parameters: {'max_depth': 3, 'colsample_bytree': 0.836357791212187, 'num_leaves': 51, 'subsample': 0.854091824559939}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:38,936] Trial 26 finished with value: 0.33988840070940224 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7023490840449665, 'num_leaves': 52, 'subsample': 0.9539688414403892}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:39,132] Trial 27 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8358798239649029, 'num_leaves': 42, 'subsample': 0.8170348042914246}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:39,359] Trial 28 finished with value: 0.33815548186244715 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8169952743052062, 'num_leaves': 35, 'subsample': 0.8135928052529594}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:39,611] Trial 29 finished with value: 0.37070766643064973 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7471811183669645, 'num_leaves': 42, 'subsample': 0.9032903126270585}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:39,811] Trial 30 finished with value: 0.3111705965028491 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9219231412428857, 'num_leaves': 26, 'subsample': 0.9924967738031893}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:40,013] Trial 31 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8338678437174435, 'num_leaves': 41, 'subsample': 0.8621196273263123}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:40,212] Trial 32 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.820393976136604, 'num_leaves': 42, 'subsample': 0.8621965235856002}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:40,434] Trial 33 finished with value: 0.33803498923452785 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6598270416102815, 'num_leaves': 45, 'subsample': 0.7676289232355321}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:40,638] Trial 34 finished with value: 0.31084409618338826 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7514092512797772, 'num_leaves': 34, 'subsample': 0.9248939202611838}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:40,870] Trial 35 finished with value: 0.33988840070940224 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6837223271133315, 'num_leaves': 40, 'subsample': 0.8252960670965177}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:41,188] Trial 36 finished with value: 0.44232148237896807 and parameters: {'max_depth': 5, 'colsample_bytree': 0.9455935330391853, 'num_leaves': 36, 'subsample': 0.8705680038406125}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:41,390] Trial 37 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8190144610721106, 'num_leaves': 46, 'subsample': 0.9452113042095699}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:41,638] Trial 38 finished with value: 0.37825321349720514 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9083631414189796, 'num_leaves': 43, 'subsample': 0.7621893773482414}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:41,976] Trial 39 finished with value: 0.4408618906564836 and parameters: {'max_depth': 6, 'colsample_bytree': 0.6039896901771824, 'num_leaves': 49, 'subsample': 0.8378637765378387}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:42,201] Trial 40 finished with value: 0.33825833958535617 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7678704845449644, 'num_leaves': 31, 'subsample': 0.7985322719489292}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:42,422] Trial 41 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8180045806506118, 'num_leaves': 41, 'subsample': 0.8566241061329198}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:42,630] Trial 42 finished with value: 0.3104606613529497 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8370985559646236, 'num_leaves': 44, 'subsample': 0.8843594596186134}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:42,841] Trial 43 finished with value: 0.31080365165669105 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7979282630958373, 'num_leaves': 37, 'subsample': 0.9234178288078485}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:43,043] Trial 44 finished with value: 0.31062360682778256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.854606650983562, 'num_leaves': 41, 'subsample': 0.8365968430832023}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:43,270] Trial 45 finished with value: 0.33825833958535617 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7805846503671325, 'num_leaves': 43, 'subsample': 0.8778860147310923}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:43,482] Trial 46 finished with value: 0.31062360682778256 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8806945462731983, 'num_leaves': 39, 'subsample': 0.9888968197794661}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:43,688] Trial 47 finished with value: 0.3112515624723836 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4372278668181045, 'num_leaves': 33, 'subsample': 0.7478899174202203}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:43,933] Trial 48 finished with value: 0.3421421067929292 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5142312909133611, 'num_leaves': 46, 'subsample': 0.7829228428969554}. Best is trial 21 with value: 0.3104606613529497.
# [I 2024-04-18 14:23:44,130] Trial 49 finished with value: 0.3108539685760227 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9673565598005107, 'num_leaves': 50, 'subsample': 0.8200692874769873}. Best is trial 21 with value: 0.3104606613529497.

# %%
# Using scikit-learn API
df_pred = df[:-4]
df_probas = None



for y, params in zip(ys, params_list):

    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x)):
            x_train, x_val = x[train_indices], x[val_indices]
            y_train, y_val = y[train_indices], y[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train, y_train)

            y_proba = model.predict_proba(x_val)

            # r = Result(y_val, y_proba, optimize=False)
            r = Result(y_val, y_proba, optimize=True)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["th"].append(r.th)
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    se_proba = pl.Series(a["proba"][0][:, 1]).rename(y.name + "_prob")
    if df_probas is None:
        df_probas = se_proba.to_frame()
    else:
        df_probas = df_probas.with_columns(se_proba)

    print(a)

    cf = {c: f for c, f in zip(x.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=a["th"][0], color='r', linestyle='--')
    axs[1].axvline(x=a["th"][0], color='r', linestyle='--')

# Remove space between subplots
    plt.subplots_adjust(hspace=0)

# Show the plot
    plt.show()
# Out:
# acc     :0.7979487911669522
# f1      :0.7624544970140466
# th      :0.5218750000000001
# logloss :0.49074250686230425
# Behavior0_Average             :29.75
# Lat0_Top                      :24.25
# DDepth_midPoint               :23.75
# NDepth_Bottom                 :22.5
# Habitat0_Top                  :20.75
# DDepth_Top                    :16.0
# Lat0_Bottom                   :15.5
# Behavior0_Bottom              :15.0
# DDepth_Bottom                 :13.75
# Lon0_Top                      :12.75
# Habitat0_Average              :12.5
# Lon0_Bottom                   :9.75
# Habitat0_Bottom               :9.75
# TemperatureT0_Average         :8.0
# TemperatureT0_Top             :7.75
# Associate0_Average            :7.75
# NDepth_midPoint               :6.75
# NDepth_Top                    :6.25
# Behavior0_Top                 :4.5
# TemperatureT0_Bottom          :3.25
# Salinity0_Bottom              :0.0
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8710736721873216
# f1      :0.7888527809895445
# th      :0.5
# logloss :0.29728283709777503
# DDepth_midPoint               :28.5
# TemperatureT0_Average         :26.25
# Habitat0_Average              :25.0
# Lon0_Top                      :24.5
# Lat0_Top                      :21.75
# Lat0_Bottom                   :21.75
# Habitat0_Bottom               :16.25
# NDepth_midPoint               :15.0
# Associate0_Average            :13.75
# Lon0_Bottom                   :13.0
# DDepth_Bottom                 :12.5
# Behavior0_Average             :12.25
# NDepth_Bottom                 :11.75
# DDepth_Top                    :11.0
# TemperatureT0_Bottom          :7.5
# Associate_Floating object     :7.25
# Habitat0_Top                  :6.5
# Behavior0_Bottom              :3.75
# Behavior0_Top                 :2.75
# TemperatureT0_Top             :2.75
# NDepth_Top                    :1.75
# Salinity0_Average             :1.0
# Salinity0_Bottom              :0.5
# Salinity0_Top                 :0.0
# Associate_Large pelagics      :0.0
# acc     :0.8710022844089093
# f1      :0.6568056043798834
# th      :0.4390624999999999
# logloss :0.3104606613529497
# Lon0_Bottom                   :12.5
# Habitat0_Top                  :11.0
# DDepth_midPoint               :10.25
# Habitat0_Bottom               :8.75
# DDepth_Bottom                 :8.5
# Lat0_Top                      :7.5
# Salinity0_Bottom              :7.25
# NDepth_midPoint               :4.75
# Behavior0_Average             :4.75
# DDepth_Top                    :4.5
# Lat0_Bottom                   :4.25
# Habitat0_Average              :3.75
# NDepth_Bottom                 :3.25
# TemperatureT0_Average         :2.75
# Lon0_Top                      :2.25
# TemperatureT0_Bottom          :2.25
# Salinity0_Average             :1.5
# Behavior0_Bottom              :0.25
# NDepth_Top                    :0.0
# Behavior0_Top                 :0.0
# Salinity0_Top                 :0.0
# TemperatureT0_Top             :0.0
# Associate0_Average            :0.0
# Associate_Floating object     :0.0
# Associate_Large pelagics      :0.0

# %%
df_res = df_probas.with_columns(
    pl.when(pl.all() < 0.5)
    .then(pl.lit("N"))
    .otherwise(pl.lit("Y"))
    .name
    .map(lambda x: x[:-5] + "_pred")
)

df_pred = pl.concat([df, df_res], how="horizontal")
df_pred.write_csv("./prediction.csv")
