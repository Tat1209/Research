# %%
import sys
from pathlib import Path

import numpy as np
import polars as pl
import lightgbm as lgb

work_path = "/home/haselab/Documents/tat/Research/"
sys.path.append(f"{work_path}app/torch_libs/")

from run_manager_new import RunManager, RunsManager, RunViewer

# %%
path_total = Path("/home/haselab/Documents/tat/Research/app/sakana_ml/level9_ml/wkdat_240425_modified.csv")
df = pl.read_csv(path_total, infer_schema_length=1500)

# %%
def preprocess(df):

# x, yともに適用する処理
# nullが10以上ある行をdrop
# df = df.with_columns(pl.Series([row.count(None) for row in df.iter_rows()]).alias("null_count")).filter(pl.col("null_count") < 10).drop("null_count")

# x, yそれぞれに適用する処理
# df = df.select(~ pl.selectors.by_name("Tmp"))

    x = df.select(pl.exclude("acceptedNameUsageID"))
    x = x.select(pl.exclude("Scientific name"))
    x = x.select(~ pl.selectors.ends_with("records"))
    # x = x.select(~ pl.selectors.ends_with("ID"))

    x = x.select(pl.exclude("Test_dat"))
    x = x.select(pl.exclude(["Tmp", "IUCN", "Stock status"]))
    x = x.select(pl.exclude(["ICCAT Fisheries", "LL", "PS", "Others"]))


    global train_type
    # train_type = "full"
    train_type = "no_max"
    x = x.select(~ pl.selectors.contains("Max_M"))
    x = x.select(~ pl.selectors.contains("Max_F"))
    
    # x = x.select(pl.exclude(pl.Utf8))
    x = x.with_columns(
        pl.when(pl.col(pl.Utf8).is_null())
        .then(pl.lit(0))
        .when(pl.col(pl.Utf8) == "Y")
        .then(pl.lit(1))
        .name.keep()
    )

    # x = x.select([col_name for col_name in x.columns if x[col_name].null_count() <=100 or "associate" in col_name.lower()])

    ys = df.select(["LL", "PS", "Others"])

    # NとYを0, 1に置き換え
    ys = ys.with_columns(
        pl.when(pl.all().is_null())
        .then(pl.lit(0))
        .when(pl.all() == "Y")
        .then(pl.lit(1))
        .name.keep()
    )
    
    return x, ys

# %%
df_train = df.filter(pl.col("Test_dat") == "Y")
df_test = df.filter(pl.col("Test_dat").is_null())

x_train, ys_train = preprocess(df_train)
x_test, ys_test = preprocess(df_test)

# display(x_train)
# display(ys_train)
# display(x_test)
# display(ys_test)

# display(x_train.columns)
# display(ys_train.columns)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from scipy.optimize import minimize

# テストデータの評価
class Result:
    def __init__(self, val, proba, optimize=False):
        self.val = val
        self.proba = proba

        if optimize:
            def f1_opt(x):
                return -f1_score(self.val, self.proba[:, 1] >= x)
            result = minimize(f1_opt, x0=np.array([0.5]), method="Nelder-Mead")
            threshold = result["x"].item()
            self.pred = self.proba[:, 1] >= threshold
            self.th = threshold
        else:
            self.pred = proba.argmax(axis=1)
            self.th = 0.5

    def acc(self):
        return accuracy_score(self.val, self.pred)

    def f1(self):
        return f1_score(self.val, self.pred, average="macro") 

    def auc(self):
        return roc_auc_score(self.val, self.pred)
    
    def logloss(self):
        return log_loss(self.val, self.proba)

    def cm(self):
        return confusion_matrix(self.val, self.pred)


    # def acc(self):
    #     return getattr(self, "acc_tmp", self.acc_tmp := accuracy_score(self.val, self.pred))

    # def acc(self):
    #     attrname = "acc_tmp"
    #     try:
    #         return getattr(self, attrname)
    #     except:

    #         score = accuracy_score(self.val, self.pred)

    #         setattr(self, attrname, score)
    #         return getattr(self, attrname)


class Scores:
    def __init__(self):
        self.score_dict = dict()
        
    def __getitem__(self, index):
        return self.score_dict.setdefault(index, [])
    
    def __setitem__(self, key, value):
        self.score_dict[key] = value
        return self
        
    def __attr__(self, attr):
        return self.score_dict.attr

    def __or__(self, other):
        for k, v in other.score_dict.items():
            self.score_dict[k] = v
        return self
    
    def __str__(self):
        disp_str = ""
        for k, v in self.score_dict.items():
            if not isinstance(v[0], np.ndarray):
                disp_str += f"{k:8}:{v[0]}\n"
        
        return disp_str[:-1]
    
    def fold(self, val_index_key, cm_key, proba_key):
        s = Scores()
        for k, v in self.score_dict.items():
            if k == val_index_key:
                pass
            elif k == cm_key:
                s[k].append(np.sum(v, axis=0))
            elif k == proba_key:
                num_datas = sum(len(sublist) for sublist in self.score_dict[val_index_key])
                proba = [None for _ in range(num_datas)]
                for val_part, proba_part in zip(self.score_dict[val_index_key], self.score_dict[proba_key]): 
                    for i, idx in enumerate(val_part):
                        proba[idx] = proba_part[i]
                s[k].append(proba)
            else:
                s[k].append(np.mean(v, axis=0))
        return s

    def ave(self):
        s = Scores()
        for k, v in self.score_dict.items():
            s[k].append(np.mean(v, axis=0))
            # if isinstance(v[0], np.ndarray):
            #     s[k].append(np.mean(v, axis=0))
            # else:
            #     s[k].append(sum(v) / len(v))
        return s

# %%
import pathlib
import optuna
# Using scikit-learn API
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss

import matplotlib.pyplot as plt
import seaborn as sns


file_name = "db.sqlite3"
file_url = fr"sqlite:///{file_name}"
file_path = Path(fr"./{file_name}").resolve()

file_path.unlink(missing_ok=True)

params_list = []

for i, y_train in enumerate(ys_train):

    def objective(trial):
        params = {
            "boosting_type": "gbdt",
            'objective': 'binary',
            "n_estimators": 100,
            "learning_rate": 0.1,

            "max_depth": trial.suggest_int("max_depth", 1, 7), # 10
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 1.0),
            "num_leaves": trial.suggest_int("num_leaves", 25, 60), # 31
            "subsample": trial.suggest_float("subsample", 0.4, 1.0), # 1.0 bagging_fracation

            "task": "train",
            'metric':'binary_logloss',
            'seed': 0,
            'verbosity': -1,
        }
        
        global x_train
        
        f = Scores()
        for ri in range(4):
            kf = KFold(n_splits=4, shuffle=True, random_state=ri)
            
            s = Scores()
            for fold, (train_indices, val_indices) in enumerate(kf.split(x_train)):
                x_train_f, x_val_f = x_train[train_indices], x_train[val_indices]
                y_train_f, y_val_f = y_train[train_indices], y_train[val_indices]
                
                model = lgb.LGBMClassifier(**params)
                model.fit(x_train_f, y_train_f)

                y_proba = model.predict_proba(x_val_f)

                r = Result(y_val_f, y_proba)
                s["acc"].append(r.acc())
                s["f1"].append(r.f1())
                s["auc"].append(r.auc())
                s["logloss"].append(r.logloss())
                s["cm"].append(r.cm())
                s["proba"].append(r.proba)
                s["ind"].append(val_indices)
                s["feat_imp"].append(model.feature_importances_)

            f |= s.fold("ind", "cm", "proba")

        a = f.ave()

        return a["logloss"][0]


    study = optuna.create_study(
        storage=file_url,
        study_name=f"Nyaaaaaaaaaaaa{i}",
        direction='minimize',
        load_if_exists=True,
    )
    study.optimize(objective, n_trials=50)

    params = {
        "boosting_type": "gbdt",
        'objective': 'binary',
        "n_estimators": 100,
        "learning_rate": 0.1,

        "task": "train",
        'metric':'binary_logloss',
        'seed': 0,
        'verbosity': -1,
    }
    params |= study.best_params
    params_list.append(params)
# Out:
# [I 2024-05-07 01:10:55,826] A new study created in RDB with name: Nyaaaaaaaaaaaa0
# [I 2024-05-07 01:10:56,101] Trial 0 finished with value: 0.31197402472324354 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7702448105593682, 'num_leaves': 35, 'subsample': 0.813388589188811}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:56,358] Trial 1 finished with value: 0.31835181100792886 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5359596892237204, 'num_leaves': 25, 'subsample': 0.48754700757698954}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:56,592] Trial 2 finished with value: 0.32612975802602473 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6184905602654949, 'num_leaves': 47, 'subsample': 0.5004814928628171}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:56,985] Trial 3 finished with value: 0.3577435677412478 and parameters: {'max_depth': 6, 'colsample_bytree': 0.40515930321173377, 'num_leaves': 36, 'subsample': 0.49631633686443244}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:57,377] Trial 4 finished with value: 0.36609393910689425 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6156624480712923, 'num_leaves': 41, 'subsample': 0.4047873362131456}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:57,748] Trial 5 finished with value: 0.3699729970874318 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9987307373448228, 'num_leaves': 53, 'subsample': 0.7880100084028647}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:57,997] Trial 6 finished with value: 0.3139853526999838 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8933635880256574, 'num_leaves': 58, 'subsample': 0.5823839220457016}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:58,296] Trial 7 finished with value: 0.321355411831907 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8899719097212548, 'num_leaves': 58, 'subsample': 0.9287481531110363}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:58,671] Trial 8 finished with value: 0.34034383618614483 and parameters: {'max_depth': 5, 'colsample_bytree': 0.5368730566458555, 'num_leaves': 30, 'subsample': 0.8655521764766138}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:59,068] Trial 9 finished with value: 0.3685422396729205 and parameters: {'max_depth': 6, 'colsample_bytree': 0.9179610289971918, 'num_leaves': 43, 'subsample': 0.756302828269655}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:59,407] Trial 10 finished with value: 0.3273952377993159 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7596088841774672, 'num_leaves': 35, 'subsample': 0.6583826642073927}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:59,707] Trial 11 finished with value: 0.3185373144043218 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7844021942478846, 'num_leaves': 59, 'subsample': 0.6581693448151082}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:10:59,955] Trial 12 finished with value: 0.32857906542004045 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8180781545218327, 'num_leaves': 49, 'subsample': 0.609111548325126}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:11:00,264] Trial 13 finished with value: 0.3183767548298023 and parameters: {'max_depth': 3, 'colsample_bytree': 0.8429644453191121, 'num_leaves': 38, 'subsample': 0.9809983253436505}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:11:00,529] Trial 14 finished with value: 0.31634150467179 and parameters: {'max_depth': 2, 'colsample_bytree': 0.697096219938783, 'num_leaves': 30, 'subsample': 0.8229834261023268}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:11:00,891] Trial 15 finished with value: 0.3441355567534006 and parameters: {'max_depth': 4, 'colsample_bytree': 0.9919555139697872, 'num_leaves': 53, 'subsample': 0.5984719395635123}. Best is trial 0 with value: 0.31197402472324354.
# [I 2024-05-07 01:11:01,159] Trial 16 finished with value: 0.31119270715655495 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7141463603607446, 'num_leaves': 45, 'subsample': 0.7220000607680781}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:01,476] Trial 17 finished with value: 0.3222170372740757 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7006246153031249, 'num_leaves': 44, 'subsample': 0.730231906712705}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:01,808] Trial 18 finished with value: 0.3263316182806071 and parameters: {'max_depth': 4, 'colsample_bytree': 0.7251132159873809, 'num_leaves': 31, 'subsample': 0.903224271901652}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:02,060] Trial 19 finished with value: 0.32647225649272393 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6391674764792808, 'num_leaves': 39, 'subsample': 0.8293699203426335}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:02,334] Trial 20 finished with value: 0.31835181100792886 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5358102957225621, 'num_leaves': 47, 'subsample': 0.6955951785550574}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:02,592] Trial 21 finished with value: 0.3139853526999838 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8902803531288025, 'num_leaves': 54, 'subsample': 0.5735961926852368}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:02,850] Trial 22 finished with value: 0.3189890922371304 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8308964248204121, 'num_leaves': 33, 'subsample': 0.6931808211618797}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:03,153] Trial 23 finished with value: 0.3182260613328086 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9278055511594666, 'num_leaves': 56, 'subsample': 0.7572470272527179}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:03,381] Trial 24 finished with value: 0.32732130352043304 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7673731274728467, 'num_leaves': 49, 'subsample': 0.6483662609337059}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:03,654] Trial 25 finished with value: 0.31855290797486224 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6519239743972421, 'num_leaves': 60, 'subsample': 0.5295311342420552}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:04,028] Trial 26 finished with value: 0.35730859679299565 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8582325620844361, 'num_leaves': 26, 'subsample': 0.8068303774084365}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:04,318] Trial 27 finished with value: 0.3252993993737322 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7999814390291803, 'num_leaves': 41, 'subsample': 0.4137712339885104}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:04,587] Trial 28 finished with value: 0.3192492102131571 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7371841806539253, 'num_leaves': 51, 'subsample': 0.860277952121965}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:04,860] Trial 29 finished with value: 0.3213557412058398 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5636609235217181, 'num_leaves': 27, 'subsample': 0.5559289442203982}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:05,095] Trial 30 finished with value: 0.3286563635336883 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9440695166950822, 'num_leaves': 46, 'subsample': 0.7455369217473041}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:05,353] Trial 31 finished with value: 0.31605086627304524 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8635511046231402, 'num_leaves': 56, 'subsample': 0.6045491306629522}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:05,654] Trial 32 finished with value: 0.32823132070521577 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9024139407184572, 'num_leaves': 55, 'subsample': 0.45724086898143634}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:05,900] Trial 33 finished with value: 0.3286563635336883 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9521970320147419, 'num_leaves': 52, 'subsample': 0.5464034646140279}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:06,172] Trial 34 finished with value: 0.3134955375985199 and parameters: {'max_depth': 2, 'colsample_bytree': 0.41431262898847243, 'num_leaves': 57, 'subsample': 0.5867330695333645}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:06,459] Trial 35 finished with value: 0.3134955375985199 and parameters: {'max_depth': 2, 'colsample_bytree': 0.41600233769638795, 'num_leaves': 57, 'subsample': 0.4675373088645208}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:06,766] Trial 36 finished with value: 0.31769357108744334 and parameters: {'max_depth': 3, 'colsample_bytree': 0.42904202295566113, 'num_leaves': 50, 'subsample': 0.47300411834794565}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:07,026] Trial 37 finished with value: 0.3243738693605771 and parameters: {'max_depth': 1, 'colsample_bytree': 0.45422987583113184, 'num_leaves': 45, 'subsample': 0.4286897702314773}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:07,371] Trial 38 finished with value: 0.3380860632809209 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4769696432970463, 'num_leaves': 36, 'subsample': 0.7802171931108978}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:07,775] Trial 39 finished with value: 0.356528839092437 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5063053439819728, 'num_leaves': 57, 'subsample': 0.5127371662243216}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:08,165] Trial 40 finished with value: 0.33936133598154494 and parameters: {'max_depth': 5, 'colsample_bytree': 0.40922219693188006, 'num_leaves': 41, 'subsample': 0.45533233714131605}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:08,444] Trial 41 finished with value: 0.3189433311437694 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5865963378514043, 'num_leaves': 58, 'subsample': 0.6348875513587924}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:08,717] Trial 42 finished with value: 0.31819209140189975 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6662432216068254, 'num_leaves': 60, 'subsample': 0.7168239628244797}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:09,034] Trial 43 finished with value: 0.3151300811327241 and parameters: {'max_depth': 3, 'colsample_bytree': 0.47588935672560156, 'num_leaves': 58, 'subsample': 0.4996885437573036}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:09,276] Trial 44 finished with value: 0.32767451758685334 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6901533244540895, 'num_leaves': 54, 'subsample': 0.681549767108536}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:09,549] Trial 45 finished with value: 0.3192492102131571 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7415860078361094, 'num_leaves': 56, 'subsample': 0.617853810091429}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:09,863] Trial 46 finished with value: 0.3133532723071037 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4412759361716797, 'num_leaves': 33, 'subsample': 0.7755320189858785}. Best is trial 16 with value: 0.31119270715655495.
# [I 2024-05-07 01:11:10,191] Trial 47 finished with value: 0.3094061236425406 and parameters: {'max_depth': 3, 'colsample_bytree': 0.4026901099744209, 'num_leaves': 34, 'subsample': 0.7827197016554739}. Best is trial 47 with value: 0.3094061236425406.
# [I 2024-05-07 01:11:10,540] Trial 48 finished with value: 0.3269821042633564 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4472662139122687, 'num_leaves': 33, 'subsample': 0.7809871734244671}. Best is trial 47 with value: 0.3094061236425406.
# [I 2024-05-07 01:11:10,901] Trial 49 finished with value: 0.32776690078861215 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4968575457633723, 'num_leaves': 28, 'subsample': 0.8748776461842482}. Best is trial 47 with value: 0.3094061236425406.
# [I 2024-05-07 01:11:10,926] A new study created in RDB with name: Nyaaaaaaaaaaaa1
# [I 2024-05-07 01:11:11,286] Trial 0 finished with value: 0.3093570005019842 and parameters: {'max_depth': 4, 'colsample_bytree': 0.46527629632790213, 'num_leaves': 25, 'subsample': 0.6617199571320614}. Best is trial 0 with value: 0.3093570005019842.
# [I 2024-05-07 01:11:11,667] Trial 1 finished with value: 0.3480953950222912 and parameters: {'max_depth': 5, 'colsample_bytree': 0.8669253908808318, 'num_leaves': 34, 'subsample': 0.7647408378592078}. Best is trial 0 with value: 0.3093570005019842.
# [I 2024-05-07 01:11:11,962] Trial 2 finished with value: 0.29760475973825584 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6381315573640293, 'num_leaves': 40, 'subsample': 0.5174808724631249}. Best is trial 2 with value: 0.29760475973825584.
# [I 2024-05-07 01:11:12,202] Trial 3 finished with value: 0.29633883744588985 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9121639351705227, 'num_leaves': 45, 'subsample': 0.7057971752308158}. Best is trial 3 with value: 0.29633883744588985.
# [I 2024-05-07 01:11:12,555] Trial 4 finished with value: 0.3120320117648967 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5493234717114103, 'num_leaves': 44, 'subsample': 0.48679461830082815}. Best is trial 3 with value: 0.29633883744588985.
# [I 2024-05-07 01:11:12,911] Trial 5 finished with value: 0.3291962341670004 and parameters: {'max_depth': 5, 'colsample_bytree': 0.722528017549351, 'num_leaves': 47, 'subsample': 0.6987187720770011}. Best is trial 3 with value: 0.29633883744588985.
# [I 2024-05-07 01:11:13,293] Trial 6 finished with value: 0.3116117415731024 and parameters: {'max_depth': 5, 'colsample_bytree': 0.4996085207249561, 'num_leaves': 26, 'subsample': 0.4264890515812219}. Best is trial 3 with value: 0.29633883744588985.
# [I 2024-05-07 01:11:13,561] Trial 7 finished with value: 0.28883012454400114 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5209854157156906, 'num_leaves': 44, 'subsample': 0.49189677375900026}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:13,984] Trial 8 finished with value: 0.338507053940147 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5836206150681615, 'num_leaves': 25, 'subsample': 0.9700944815355277}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:14,391] Trial 9 finished with value: 0.3366389572587055 and parameters: {'max_depth': 7, 'colsample_bytree': 0.45382930425627654, 'num_leaves': 37, 'subsample': 0.5305947271709849}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:14,627] Trial 10 finished with value: 0.30972037974632205 and parameters: {'max_depth': 1, 'colsample_bytree': 0.7536315455481238, 'num_leaves': 58, 'subsample': 0.8622641975740227}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:14,862] Trial 11 finished with value: 0.3138430250192951 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9974238026567137, 'num_leaves': 51, 'subsample': 0.6154356463052787}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:15,122] Trial 12 finished with value: 0.2964301217965742 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8650391408707888, 'num_leaves': 52, 'subsample': 0.7894472659197742}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:15,380] Trial 13 finished with value: 0.30171250725809556 and parameters: {'max_depth': 2, 'colsample_bytree': 0.997606376817228, 'num_leaves': 48, 'subsample': 0.6104143379409097}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:15,643] Trial 14 finished with value: 0.296073779812299 and parameters: {'max_depth': 2, 'colsample_bytree': 0.809606211845652, 'num_leaves': 33, 'subsample': 0.8110027887474909}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:15,944] Trial 15 finished with value: 0.2960524590508313 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7826602882012889, 'num_leaves': 32, 'subsample': 0.9010999556450123}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:16,265] Trial 16 finished with value: 0.29760475973825584 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6448436417636355, 'num_leaves': 31, 'subsample': 0.9877530607302264}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:16,571] Trial 17 finished with value: 0.30110583398098834 and parameters: {'max_depth': 3, 'colsample_bytree': 0.6713281286685269, 'num_leaves': 39, 'subsample': 0.8952633048543038}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:16,932] Trial 18 finished with value: 0.3062722209230161 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5702561921067022, 'num_leaves': 30, 'subsample': 0.42917582067897486}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:17,181] Trial 19 finished with value: 0.3120814010558926 and parameters: {'max_depth': 1, 'colsample_bytree': 0.412108078183099, 'num_leaves': 58, 'subsample': 0.9004364144424681}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:17,487] Trial 20 finished with value: 0.30162370733794897 and parameters: {'max_depth': 3, 'colsample_bytree': 0.7760508142825261, 'num_leaves': 41, 'subsample': 0.5680380998791855}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:17,747] Trial 21 finished with value: 0.296073779812299 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8103631169204394, 'num_leaves': 35, 'subsample': 0.8354146418945372}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:18,001] Trial 22 finished with value: 0.2938621867980269 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8185034854833964, 'num_leaves': 30, 'subsample': 0.7790136715113427}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:18,307] Trial 23 finished with value: 0.30076755728626076 and parameters: {'max_depth': 3, 'colsample_bytree': 0.725349885278298, 'num_leaves': 29, 'subsample': 0.7550804284978074}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:18,531] Trial 24 finished with value: 0.3118751775389358 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9161542608655001, 'num_leaves': 37, 'subsample': 0.9490745480562319}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:18,779] Trial 25 finished with value: 0.29347963292722223 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8280090384035208, 'num_leaves': 30, 'subsample': 0.7261031458123215}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:19,030] Trial 26 finished with value: 0.2952503127228402 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8475468495575361, 'num_leaves': 28, 'subsample': 0.7151691778842381}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:19,249] Trial 27 finished with value: 0.3134121598713853 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9479284895526862, 'num_leaves': 37, 'subsample': 0.6170358424980773}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:19,652] Trial 28 finished with value: 0.35463841521065975 and parameters: {'max_depth': 6, 'colsample_bytree': 0.6111916277052876, 'num_leaves': 43, 'subsample': 0.6600950083601791}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:19,912] Trial 29 finished with value: 0.2935735210629603 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6864736460092896, 'num_leaves': 54, 'subsample': 0.6616129434630857}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:20,248] Trial 30 finished with value: 0.3120091692822973 and parameters: {'max_depth': 4, 'colsample_bytree': 0.5359633079811889, 'num_leaves': 55, 'subsample': 0.5627989053444385}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:20,493] Trial 31 finished with value: 0.2951294149925126 and parameters: {'max_depth': 2, 'colsample_bytree': 0.6969321386963754, 'num_leaves': 52, 'subsample': 0.6516347772710676}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:20,753] Trial 32 finished with value: 0.29347963292722223 and parameters: {'max_depth': 2, 'colsample_bytree': 0.8291448955104342, 'num_leaves': 60, 'subsample': 0.7358361018558432}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:20,984] Trial 33 finished with value: 0.31124614038555937 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9085612769108717, 'num_leaves': 60, 'subsample': 0.731681245250236}. Best is trial 7 with value: 0.28883012454400114.
# [I 2024-05-07 01:11:21,304] Trial 34 finished with value: 0.2881795149782087 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5081604826748909, 'num_leaves': 56, 'subsample': 0.4816781116391296}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:21,609] Trial 35 finished with value: 0.2881795149782087 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5135855408462927, 'num_leaves': 58, 'subsample': 0.4562916869038947}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:21,914] Trial 36 finished with value: 0.29285486917571224 and parameters: {'max_depth': 3, 'colsample_bytree': 0.49815708163135314, 'num_leaves': 47, 'subsample': 0.4722264212137981}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:22,260] Trial 37 finished with value: 0.316582366940525 and parameters: {'max_depth': 4, 'colsample_bytree': 0.49417242444993026, 'num_leaves': 47, 'subsample': 0.47012182679240777}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:22,558] Trial 38 finished with value: 0.29938615028275006 and parameters: {'max_depth': 3, 'colsample_bytree': 0.40153161499519696, 'num_leaves': 50, 'subsample': 0.46976259792584174}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:22,894] Trial 39 finished with value: 0.31576826654329065 and parameters: {'max_depth': 4, 'colsample_bytree': 0.45252988406215955, 'num_leaves': 55, 'subsample': 0.40840328936636927}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:23,256] Trial 40 finished with value: 0.3147108849590962 and parameters: {'max_depth': 5, 'colsample_bytree': 0.51983521237634, 'num_leaves': 45, 'subsample': 0.5186245757158944}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:23,566] Trial 41 finished with value: 0.2969284715963296 and parameters: {'max_depth': 3, 'colsample_bytree': 0.47353917009195096, 'num_leaves': 45, 'subsample': 0.4929101057782348}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:23,878] Trial 42 finished with value: 0.2886427175960541 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5919995405971878, 'num_leaves': 58, 'subsample': 0.4440555890748326}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:24,171] Trial 43 finished with value: 0.2940137441191835 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5667251350183947, 'num_leaves': 57, 'subsample': 0.4526057747229219}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:24,513] Trial 44 finished with value: 0.30655940454722164 and parameters: {'max_depth': 4, 'colsample_bytree': 0.6004495260747766, 'num_leaves': 57, 'subsample': 0.5546415530959281}. Best is trial 34 with value: 0.2881795149782087.
# [I 2024-05-07 01:11:24,813] Trial 45 finished with value: 0.28491481889867165 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5169805805135242, 'num_leaves': 54, 'subsample': 0.498921359114736}. Best is trial 45 with value: 0.28491481889867165.
# [I 2024-05-07 01:11:25,108] Trial 46 finished with value: 0.2959330185794966 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5441859251270614, 'num_leaves': 55, 'subsample': 0.40241604652454716}. Best is trial 45 with value: 0.28491481889867165.
# [I 2024-05-07 01:11:25,462] Trial 47 finished with value: 0.31326362606251745 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4371446554493608, 'num_leaves': 53, 'subsample': 0.439977465522729}. Best is trial 45 with value: 0.28491481889867165.
# [I 2024-05-07 01:11:25,841] Trial 48 finished with value: 0.33797853951531964 and parameters: {'max_depth': 5, 'colsample_bytree': 0.6313441839140452, 'num_leaves': 59, 'subsample': 0.49814806428119485}. Best is trial 45 with value: 0.28491481889867165.
# [I 2024-05-07 01:11:26,144] Trial 49 finished with value: 0.28491481889867165 and parameters: {'max_depth': 3, 'colsample_bytree': 0.521609240693085, 'num_leaves': 57, 'subsample': 0.5434581479499473}. Best is trial 45 with value: 0.28491481889867165.
# [I 2024-05-07 01:11:26,168] A new study created in RDB with name: Nyaaaaaaaaaaaa2
# [I 2024-05-07 01:11:26,594] Trial 0 finished with value: 0.4598490572293401 and parameters: {'max_depth': 7, 'colsample_bytree': 0.9181874290515056, 'num_leaves': 31, 'subsample': 0.641928324839717}. Best is trial 0 with value: 0.4598490572293401.
# [I 2024-05-07 01:11:26,991] Trial 1 finished with value: 0.428690805176953 and parameters: {'max_depth': 6, 'colsample_bytree': 0.4708628539064985, 'num_leaves': 47, 'subsample': 0.7581955078666356}. Best is trial 1 with value: 0.428690805176953.
# [I 2024-05-07 01:11:27,375] Trial 2 finished with value: 0.4279130334888769 and parameters: {'max_depth': 6, 'colsample_bytree': 0.44169559703442407, 'num_leaves': 52, 'subsample': 0.9746492843923815}. Best is trial 2 with value: 0.4279130334888769.
# [I 2024-05-07 01:11:27,634] Trial 3 finished with value: 0.339588436539527 and parameters: {'max_depth': 2, 'colsample_bytree': 0.9334122486002501, 'num_leaves': 57, 'subsample': 0.5367837803914096}. Best is trial 3 with value: 0.339588436539527.
# [I 2024-05-07 01:11:27,863] Trial 4 finished with value: 0.2984406080660902 and parameters: {'max_depth': 1, 'colsample_bytree': 0.602166487808367, 'num_leaves': 36, 'subsample': 0.9346753033787513}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:28,197] Trial 5 finished with value: 0.38872198585375495 and parameters: {'max_depth': 4, 'colsample_bytree': 0.44050935574954164, 'num_leaves': 51, 'subsample': 0.8137482382373761}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:28,457] Trial 6 finished with value: 0.32591664009646804 and parameters: {'max_depth': 2, 'colsample_bytree': 0.627578373414797, 'num_leaves': 53, 'subsample': 0.7680593694197638}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:28,807] Trial 7 finished with value: 0.4324802045775793 and parameters: {'max_depth': 5, 'colsample_bytree': 0.7783980140899041, 'num_leaves': 47, 'subsample': 0.7440486981463479}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:29,173] Trial 8 finished with value: 0.42490802244096637 and parameters: {'max_depth': 5, 'colsample_bytree': 0.9324094401878507, 'num_leaves': 39, 'subsample': 0.5311392540167615}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:29,472] Trial 9 finished with value: 0.362648551269787 and parameters: {'max_depth': 3, 'colsample_bytree': 0.9012350907286826, 'num_leaves': 47, 'subsample': 0.7749849213371687}. Best is trial 4 with value: 0.2984406080660902.
# [I 2024-05-07 01:11:29,708] Trial 10 finished with value: 0.29806467058543196 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6382186644835735, 'num_leaves': 25, 'subsample': 0.9678317507103287}. Best is trial 10 with value: 0.29806467058543196.
# [I 2024-05-07 01:11:29,953] Trial 11 finished with value: 0.29956210628817626 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6182143296622276, 'num_leaves': 25, 'subsample': 0.9969775958524985}. Best is trial 10 with value: 0.29806467058543196.
# [I 2024-05-07 01:11:30,204] Trial 12 finished with value: 0.2973628562334839 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5680896643643751, 'num_leaves': 36, 'subsample': 0.8788162074697923}. Best is trial 12 with value: 0.2973628562334839.
# [I 2024-05-07 01:11:30,466] Trial 13 finished with value: 0.3252012993598186 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7542487473075418, 'num_leaves': 25, 'subsample': 0.874308597543672}. Best is trial 12 with value: 0.2973628562334839.
# [I 2024-05-07 01:11:30,701] Trial 14 finished with value: 0.297282767385075 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5390095923293523, 'num_leaves': 32, 'subsample': 0.887292064642915}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:31,002] Trial 15 finished with value: 0.3454654876052484 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5425003303411657, 'num_leaves': 33, 'subsample': 0.6495598533722974}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:31,319] Trial 16 finished with value: 0.35509163038006936 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5191048926493588, 'num_leaves': 40, 'subsample': 0.8687045773740356}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:31,578] Trial 17 finished with value: 0.297282767385075 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5334883778832892, 'num_leaves': 31, 'subsample': 0.4407282850629222}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:31,842] Trial 18 finished with value: 0.3268748622193122 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7040675454772979, 'num_leaves': 32, 'subsample': 0.41920224325523864}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:32,186] Trial 19 finished with value: 0.38888775333256287 and parameters: {'max_depth': 4, 'colsample_bytree': 0.40417305561711514, 'num_leaves': 29, 'subsample': 0.4079486223954011}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:32,509] Trial 20 finished with value: 0.3529619155163509 and parameters: {'max_depth': 3, 'colsample_bytree': 0.48912993026147683, 'num_leaves': 43, 'subsample': 0.527072926382584}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:32,749] Trial 21 finished with value: 0.2973628562334839 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5722927877243356, 'num_leaves': 35, 'subsample': 0.8880883659154046}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:32,989] Trial 22 finished with value: 0.2984867131190216 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6849643433735944, 'num_leaves': 29, 'subsample': 0.8273569854462669}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:33,262] Trial 23 finished with value: 0.32589346002035635 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5391793625766449, 'num_leaves': 37, 'subsample': 0.6771027741954417}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:33,507] Trial 24 finished with value: 0.29782696164648903 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5731125328112665, 'num_leaves': 29, 'subsample': 0.9113573538480307}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:33,791] Trial 25 finished with value: 0.32683161614047457 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5030546743792829, 'num_leaves': 42, 'subsample': 0.5843530348833572}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:34,031] Trial 26 finished with value: 0.2983110504671264 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6796570275948091, 'num_leaves': 34, 'subsample': 0.4877345633050169}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:34,296] Trial 27 finished with value: 0.3243163423422011 and parameters: {'max_depth': 2, 'colsample_bytree': 0.7658025984468325, 'num_leaves': 38, 'subsample': 0.8285042393405976}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:34,514] Trial 28 finished with value: 0.29943395448433097 and parameters: {'max_depth': 1, 'colsample_bytree': 0.9904699776847703, 'num_leaves': 31, 'subsample': 0.7293177844639895}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:34,825] Trial 29 finished with value: 0.35032610268888625 and parameters: {'max_depth': 3, 'colsample_bytree': 0.5590075499043424, 'num_leaves': 29, 'subsample': 0.611999662758558}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:35,108] Trial 30 finished with value: 0.32008270668238 and parameters: {'max_depth': 2, 'colsample_bytree': 0.45651835809512714, 'num_leaves': 41, 'subsample': 0.6880558082479534}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:35,354] Trial 31 finished with value: 0.2982446594177738 and parameters: {'max_depth': 1, 'colsample_bytree': 0.582392548278916, 'num_leaves': 34, 'subsample': 0.8925123260299375}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:35,772] Trial 32 finished with value: 0.4424306292797151 and parameters: {'max_depth': 7, 'colsample_bytree': 0.6491072819383836, 'num_leaves': 35, 'subsample': 0.9354517539873747}. Best is trial 14 with value: 0.297282767385075.
# [I 2024-05-07 01:11:36,012] Trial 33 finished with value: 0.29614198695636135 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5170782119785042, 'num_leaves': 44, 'subsample': 0.8517881145885}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:36,261] Trial 34 finished with value: 0.29822014421291637 and parameters: {'max_depth': 1, 'colsample_bytree': 0.48105634162856586, 'num_leaves': 45, 'subsample': 0.801603178463158}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:36,551] Trial 35 finished with value: 0.3230464473030853 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5169730132757601, 'num_leaves': 27, 'subsample': 0.9430394312326323}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:36,819] Trial 36 finished with value: 0.2984474927026897 and parameters: {'max_depth': 1, 'colsample_bytree': 0.4387654574305949, 'num_leaves': 31, 'subsample': 0.4568172024446633}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:37,171] Trial 37 finished with value: 0.38888775333256287 and parameters: {'max_depth': 4, 'colsample_bytree': 0.4067131504493859, 'num_leaves': 44, 'subsample': 0.8532989425979949}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:37,450] Trial 38 finished with value: 0.3245139378522922 and parameters: {'max_depth': 2, 'colsample_bytree': 0.5946100919492678, 'num_leaves': 57, 'subsample': 0.8473281067720193}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:37,882] Trial 39 finished with value: 0.456472526636132 and parameters: {'max_depth': 7, 'colsample_bytree': 0.5309729718357393, 'num_leaves': 54, 'subsample': 0.7939601257740372}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:38,267] Trial 40 finished with value: 0.4034829255090852 and parameters: {'max_depth': 5, 'colsample_bytree': 0.46771388297750177, 'num_leaves': 49, 'subsample': 0.9231742808727831}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:38,513] Trial 41 finished with value: 0.2973628562334839 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5673531736674128, 'num_leaves': 37, 'subsample': 0.8914943769875825}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:38,764] Trial 42 finished with value: 0.2981755744642257 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5941100928306066, 'num_leaves': 36, 'subsample': 0.9629988484681663}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:39,024] Trial 43 finished with value: 0.29665375824858714 and parameters: {'max_depth': 1, 'colsample_bytree': 0.49709454130638564, 'num_leaves': 39, 'subsample': 0.7398495310155431}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:39,282] Trial 44 finished with value: 0.2985171284866523 and parameters: {'max_depth': 1, 'colsample_bytree': 0.43255424437738044, 'num_leaves': 60, 'subsample': 0.7395194931034619}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:39,534] Trial 45 finished with value: 0.2971982476190462 and parameters: {'max_depth': 1, 'colsample_bytree': 0.5005401910941474, 'num_leaves': 39, 'subsample': 0.7833925527390194}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:39,814] Trial 46 finished with value: 0.3254624547146673 and parameters: {'max_depth': 2, 'colsample_bytree': 0.49097783845889864, 'num_leaves': 39, 'subsample': 0.7180553396062753}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:40,051] Trial 47 finished with value: 0.29827280603604395 and parameters: {'max_depth': 1, 'colsample_bytree': 0.8542167753326793, 'num_leaves': 48, 'subsample': 0.7737391857001209}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:40,338] Trial 48 finished with value: 0.32388231550520064 and parameters: {'max_depth': 2, 'colsample_bytree': 0.46093838212569216, 'num_leaves': 40, 'subsample': 0.7082898889556791}. Best is trial 33 with value: 0.29614198695636135.
# [I 2024-05-07 01:11:40,581] Trial 49 finished with value: 0.29832063181963386 and parameters: {'max_depth': 1, 'colsample_bytree': 0.6144799519438903, 'num_leaves': 45, 'subsample': 0.6541720386138778}. Best is trial 33 with value: 0.29614198695636135.

# %%
# Using scikit-learn API
df_probas = None

ths = []

for y_train, params in zip(ys_train, params_list):

    global x_train
    
    f = Scores()
    for ri in range(4):
        kf = KFold(n_splits=4, shuffle=True, random_state=ri)
        
        s = Scores()
        for fold, (train_indices, val_indices) in enumerate(kf.split(x_train)):
            x_train_f, x_val_f = x_train[train_indices], x_train[val_indices]
            y_train_f, y_val_f = y_train[train_indices], y_train[val_indices]
            
            model = lgb.LGBMClassifier(**params)
            model.fit(x_train_f, y_train_f)
            
            y_proba = model.predict_proba(x_val_f)

            r = Result(y_val_f, y_proba, optimize=True)
            s["acc"].append(r.acc())
            s["f1"].append(r.f1())
            s["th"].append(r.th)
            s["logloss"].append(r.logloss())
            s["cm"].append(r.cm())
            s["proba"].append(r.proba)
            s["ind"].append(val_indices)
            s["feat_imp"].append(model.feature_importances_)
            

        f |= s.fold("ind", "cm", "proba")
    a = f.ave()

    ths.append(a["th"][0])


    print(f"-- {y_train.name} --")
    print(a)
    print()
    print("- importance")

    cf = {c: f for c, f in zip(x_train.columns, a["feat_imp"][0])}
    cf = {k: v for k, v in sorted(cf.items(), key=lambda item: item[1], reverse=True)}

    for c, f in cf.items():
        print(f"{c:30}:{f}")

    Path(f"./{train_type}").mkdir(parents=True, exist_ok=True)
    with open(file=f"./{train_type}/metrics_{y_train.name}.txt", mode="w") as fh:
        print(f"-- {y_train.name} --", file=fh)
        print(a, file=fh)

        print(file=fh)
        print("- importance", file=fh)
        for c, f in cf.items():
            print(f"{c:30}:{f}", file=fh)


    fig, ax = plt.subplots()
    fig.set_figwidth(3)
    fig.set_figheight(2.25)

    ax = sns.heatmap(a["cm"][0], annot=True, cbar=True, square=True, fmt=".0f", cmap="Blues_r", xticklabels=list(range(a["cm"][0].shape[0])), yticklabels=list(range(a["cm"][0].shape[1])))
    fig.savefig(f"./{train_type}/cv_{y_train.name}.png")
    fig.show()
    ax.set_xlabel("pred_label")
    ax.set_ylabel("true_label")


    fig, axs = plt.subplots(2, sharex=True, gridspec_kw={'hspace': 0})

    axs[0].set_ylim(0, 30)  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y_train == 0], ax=axs[0], color='blue', bins=50)
    axs[0].xaxis.tick_top()  # and move the X-Axis

    axs[1].set_ylim(axs[0].get_ylim()[::-1])  # invert the axis
    sns.histplot(a["proba"][0][:, 1][y_train == 1], ax=axs[1], color='red', bins=50)
    axs[1].xaxis.tick_top()  # and move the X-Axis
    
    axs[0].axvline(x=a["th"][0], color='r', linestyle='--')
    axs[1].axvline(x=a["th"][0], color='r', linestyle='--')

# Remove space between subplots
    fig.subplots_adjust(hspace=0)

# Show the plot
    fig.savefig(f"./{train_type}/dist_{y_train.name}.png")
    fig.show()


    df_proba = pl.Series(a["proba"][0][:, 1]).rename(y_train.name + "_prob").to_frame()
    df_proba = df_proba.with_columns(
        pl.when(pl.all() < a["th"][0])
        .then(pl.lit("N"))
        .otherwise(pl.lit("Y"))
        .name
        .map(lambda x: x[:-5] + "_pred")
    )
    if df_probas is None:
        df_probas = df_proba
    else:
        df_probas = pl.concat([df_probas, df_proba], how="horizontal")

df_pred_train = pl.concat([df_train, df_probas], how="horizontal")
# Out:
# -- LL --
# acc     :0.8807824100513991
# f1      :0.864208478099688
# th      :0.48750000000000004
# logloss :0.3094061236425406
#
# - importance
# Mat_F                         :36.0
# Lat_Top                       :26.25
# NDepth_Bottom                 :25.75
# Genus_ID                      :23.75
# Mat_M                         :23.25
# Food_Average                  :22.75
# Behavior_top                  :20.25
# DDepth_Bottom                 :19.25
# Distribution                  :17.25
# Food_Top                      :16.25
# Av_F                          :15.75
# Family_ID                     :15.5
# Lat_Bottom                    :14.5
# Behavior_Average              :14.0
# DDepth_midPoint               :11.0
# Commercial importance         :10.75
# Habitat0_Average              :10.0
# DDepth_Top                    :9.25
# Lon0_Top                      :9.0
# Av_M                          :8.75
# Lon0_Bottom                   :8.5
# NDepth_midPoint               :7.75
# Behavior_bottom               :7.75
# Max_age_bottom                :7.25
# Migration_Average             :6.75
# Depth_bottom                  :6.75
# Temperature_Bottom            :6.5
# Com/Mat_F                     :6.25
# Associate_Large pelagics      :6.0
# Habitat0_Bottom               :5.75
# Temperature_midPoint          :5.25
# Depth_Average                 :5.25
# Food_Bottom                   :5.25
# Temperature0_midPoint         :5.0
# Max_age_top                   :4.5
# Associate_Floating object     :4.5
# Breeding_cycle                :4.5
# Reproduction                  :4.0
# Mature_age                    :3.75
# Temperature0_Bottom           :3.75
# Salinity0_Bottom              :3.5
# Occurrence                    :3.5
# NDepth_Top                    :2.75
# Temperature_Top               :2.75
# Temperature0_Top              :2.75
# Generation_mid                :2.0
# Depth_top                     :1.75
# Aggregation0_Top              :1.75
# Lon1_Top                      :1.5
# Habitat0_Top                  :1.5
# Salinity0_Average             :1.25
# Aggregation0_Average          :1.25
# Egg&larvae                    :1.25
# Associate0_Average            :1.0
# Associate_Coral               :0.5
# Lon1_Bottom                   :0.25
# Diel vertical migration       :0.25
# Associate_Floating object_duplicated_0:0.25
# Breeding_relation             :0.25
# Lat_no_top                    :0.0
# Lat_no_bottom                 :0.0
# Generation_top                :0.0
# Generation_bottom             :0.0
# Salinity0_Top                 :0.0
# Associate_Vegetatation        :0.0
# Associate_Large pelagics/ship :0.0
# -- PS --
# acc     :0.8807824100513992
# f1      :0.8122769084938026
# th      :0.4312499999999999
# logloss :0.28491481889867165
#
# - importance
# DDepth_midPoint               :30.75
# Lat_Bottom                    :24.0
# Genus_ID                      :22.5
# Temperature0_midPoint         :22.5
# DDepth_Top                    :20.25
# Lon0_Top                      :19.5
# Com/Mat_F                     :19.5
# Mat_M                         :17.5
# Lat_Top                       :17.0
# Food_Average                  :16.5
# Habitat0_Average              :16.5
# Lon0_Bottom                   :15.5
# Av_M                          :14.75
# Mat_F                         :14.5
# Av_F                          :14.25
# Mature_age                    :13.75
# Behavior_Average              :13.0
# Family_ID                     :12.25
# NDepth_midPoint               :11.25
# Associate_Large pelagics      :10.25
# DDepth_Bottom                 :9.75
# Aggregation0_Average          :9.0
# Migration_Average             :8.75
# Aggregation0_Top              :8.25
# Associate_Floating object     :8.25
# NDepth_Bottom                 :8.0
# Habitat0_Bottom               :8.0
# Distribution                  :7.5
# Breeding_cycle                :7.25
# Generation_mid                :6.25
# Food_Bottom                   :6.0
# Commercial importance         :5.75
# Temperature0_Top              :5.0
# Behavior_bottom               :4.75
# Behavior_top                  :4.75
# Depth_Average                 :4.75
# NDepth_Top                    :4.5
# Occurrence                    :4.5
# Temperature_Bottom            :4.25
# Food_Top                      :4.25
# Reproduction                  :3.75
# Max_age_top                   :3.5
# Max_age_bottom                :3.0
# Temperature0_Bottom           :3.0
# Associate_Floating object_duplicated_0:2.75
# Lon1_Top                      :2.5
# Depth_top                     :2.5
# Habitat0_Top                  :2.5
# Associate0_Average            :2.0
# Breeding_relation             :1.75
# Temperature_midPoint          :1.5
# Depth_bottom                  :1.5
# Generation_top                :1.25
# Generation_bottom             :0.5
# Lon1_Bottom                   :0.25
# Temperature_Top               :0.25
# Salinity0_Bottom              :0.25
# Salinity0_Average             :0.25
# Associate_Vegetatation        :0.25
# Egg&larvae                    :0.25
# Lat_no_top                    :0.0
# Lat_no_bottom                 :0.0
# Diel vertical migration       :0.0
# Salinity0_Top                 :0.0
# Associate_Coral               :0.0
# Associate_Large pelagics/ship :0.0
# -- Others --
# acc     :0.8952979249952409
# f1      :0.7571883748319526
# th      :0.5
# logloss :0.29614198695636135
#
# - importance
# Family_ID                     :9.5
# Mat_F                         :7.0
# NDepth_Bottom                 :6.5
# Generation_top                :5.75
# Commercial importance         :5.75
# Com/Mat_F                     :4.25
# Av_F                          :4.0
# Habitat0_Average              :4.0
# Lon0_Bottom                   :3.5
# Mat_M                         :3.5
# Genus_ID                      :3.25
# Lat_Bottom                    :3.25
# Lon1_Top                      :3.25
# Migration_Average             :3.25
# DDepth_midPoint               :3.0
# Associate_Floating object_duplicated_0:3.0
# Occurrence                    :3.0
# Diel vertical migration       :2.75
# Lon0_Top                      :2.0
# Temperature_Bottom            :2.0
# Behavior_Average              :1.75
# Habitat0_Bottom               :1.75
# Lat_Top                       :1.5
# Av_M                          :1.5
# Associate_Floating object     :1.5
# Temperature_midPoint          :1.25
# Food_Top                      :1.0
# Food_Average                  :1.0
# DDepth_Bottom                 :0.75
# Lon1_Bottom                   :0.75
# Generation_bottom             :0.75
# Behavior_top                  :0.75
# Temperature0_Top              :0.75
# NDepth_Top                    :0.5
# Generation_mid                :0.5
# Temperature0_midPoint         :0.5
# Breeding_cycle                :0.5
# Salinity0_Bottom              :0.25
# Associate_Large pelagics      :0.25
# DDepth_Top                    :0.0
# NDepth_midPoint               :0.0
# Lat_no_top                    :0.0
# Lat_no_bottom                 :0.0
# Max_age_top                   :0.0
# Max_age_bottom                :0.0
# Mature_age                    :0.0
# Temperature_Top               :0.0
# Behavior_bottom               :0.0
# Depth_bottom                  :0.0
# Depth_top                     :0.0
# Depth_Average                 :0.0
# Food_Bottom                   :0.0
# Habitat0_Top                  :0.0
# Salinity0_Top                 :0.0
# Salinity0_Average             :0.0
# Temperature0_Bottom           :0.0
# Aggregation0_Top              :0.0
# Aggregation0_Average          :0.0
# Associate0_Average            :0.0
# Associate_Vegetatation        :0.0
# Associate_Coral               :0.0
# Associate_Large pelagics/ship :0.0
# Breeding_relation             :0.0
# Reproduction                  :0.0
# Egg&larvae                    :0.0
# Distribution                  :0.0

# %%
# Using scikit-learn API
df_probas = None

for y_train, y_test, params, th in zip(ys_train, ys_test, params_list, ths):
    model = lgb.LGBMClassifier(**params)
    model.fit(x_train, y_train)

    y_proba = model.predict_proba(x_test)

    a_test = Scores()
    r = Result(y_test, y_proba)
    a_test["proba"].append(r.proba)

    df_proba = pl.Series(a_test["proba"][0][:, 1]).rename(y_test.name + "_prob").to_frame()
    df_proba = df_proba.with_columns(
        pl.when(pl.all() < th)
        .then(pl.lit("N"))
        .otherwise(pl.lit("Y"))
        .name
        .map(lambda x: x[:-5] + "_pred")

    )
    if df_probas is None:
        df_probas = df_proba
    else:
        df_probas = pl.concat([df_probas, df_proba], how="horizontal")

df_pred_test = pl.concat([df_test, df_probas], how="horizontal")


df_pred_test = pl.concat([df_pred_train, df_pred_test], how="vertical").sort("acceptedNameUsageID")
df_pred_test.write_csv(f"./{train_type}/prediction_{train_type}.csv")
